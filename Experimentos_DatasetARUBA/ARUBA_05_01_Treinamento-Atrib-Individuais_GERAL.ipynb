# %% [markdown]
# # PPD dos dados para treinamento, validação e teste

# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import random
from numpy import median, mean
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import LocalOutlierFactor
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest

# %% [markdown]
# * Outlier =  1 normal
# * Outlier = -1 anormal

# %% [markdown]
# ## IMPORTANDO dados treinamento, validacao e teste

# %%
# atributo DURACAO

# %%
## importando dataset TREINAMENTO
df_dur_trein = pd.read_csv('datasetaruba/pp4/aruba-dur-trein56.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_trein.shape)
df_dur_trein.head()
# Out:
# (56, 8)
#    dia  dia_semana  fim_semana  BedToToilet  Eating  MealPreparation    Relax  \
# 0    1           3           0        158.0   626.0           4000.0  14000.0
# 1    2           4           0        160.0   209.0           1500.0  14000.0
# 2    3           5           1        189.0  1795.0           1500.0  14000.0
# 3    4           6           1        348.0  3500.0           1898.0  28849.0
# 4    5           0           0        184.0  3224.0           2118.0  25717.0
#
#    Sleeping
# 0   28459.0
# 1   48019.0
# 2   16215.0
# 3   47460.0
# 4   10732.0

# %%
## importando dataset VALIDACAO
df_dur_valid = pd.read_csv('datasetaruba/pp4/aruba-dur-valid28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_valid.shape)
df_dur_valid.head()
# Out:
# (28, 15)
#    dia  dia_semana  fim_semana  BedToToilet  Eating  MealPreparation    Relax  \
# 0    1           0           0        141.0   412.0           2955.0  31844.0
# 1    2           2           0        161.0   211.0           4000.0  21767.0
# 2    3           0           0        157.0  3500.0           1938.0  26205.0
# 3    4           3           0        302.0   206.0           2469.0  22814.0
# 4    5           0           0        148.0   287.0           1500.0  37472.0
#
#    Sleeping  var_BedToToilet  var_Eating  var_MealPreparation  var_Relax  \
# 0   51599.0                1           1                    1          1
# 1   31365.0                1           1                    1          1
# 2   56579.0                1           1                    1          1
# 3   30680.0                1           1                    1          1
# 4     737.0                1           1                    1          1
#
#    var_Sleeping  outlier  variacao
# ...

# %%
## importando dataset de TESTE
df_dur_test2035 = pd.read_csv('datasetaruba/pp4/aruba-dur-var20-35-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_test2035.shape)
df_dur_test2035.head()

df_dur_test4055 = pd.read_csv('datasetaruba/pp4/aruba-dur-var40-55-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_test4055.shape)
df_dur_test4055.head()

df_dur_test6075 = pd.read_csv('datasetaruba/pp4/aruba-dur-var60-75-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_test6075.shape)
df_dur_test6075.head()

df_dur_test8095 = pd.read_csv('datasetaruba/pp4/aruba-dur-var80-95-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_test8095.shape)
df_dur_test8095.head()

df_dur_test2095 = pd.read_csv('datasetaruba/pp4/aruba-dur-var20-95-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dur_test2095.shape)
df_dur_test2095.head()
# Out:
# (28, 15)
# (28, 15)
# (28, 15)
# (28, 15)
# (28, 15)
#    dia  dia_semana  fim_semana  BedToToilet  Eating  MealPreparation    Relax  \
# 0    1           0           0        108.0   317.0           2955.0  24519.0
# 1    2           2           0        161.0   211.0           7800.0  42445.0
# 2    3           0           0        197.0  2590.0           2441.0  26205.0
# 3    4           3           0        534.0   364.0            567.0   5247.0
# 4    5           0           0        148.0   106.0            555.0  61079.0
#
#    Sleeping  var_BedToToilet  var_Eating  var_MealPreparation  var_Relax  \
# 0   63466.0               -1          -1                    1         -1
# 1   61161.0                1           1                   -1         -1
# 2   41868.0               -1          -1                   -1          1
# 3   54303.0               -1          -1                   -1         -1
# 4     272.0                1          -1                   -1         -1
#
# ...

# %%
# atributo FREQUENCIA

# %%
## importando dataset TREINAMENTO
df_freq_trein = pd.read_csv('datasetaruba/pp4/aruba-freq-trein56.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_freq_trein.shape)
df_freq_trein.head()
# Out:
# (56, 8)
#    dia  dia_semana  fim_semana  BedToToilet    Eating  MealPreparation  Relax  \
# 0    1           3           0          1.0  4.000000              9.0    9.0
# 1    2           4           0          1.0  1.000000              4.0    9.0
# 2    3           5           1          1.0  3.000000              4.0    9.0
# 3    4           6           1          2.0  2.933333              9.0   17.0
# 4    5           0           0          1.0  4.000000              9.0   13.0
#
#    Sleeping
# 0       2.0
# 1       3.0
# 2       1.0
# 3       5.0
# 4       2.0

# %%
## importando dataset de TESTE
df_freq_test2035 = pd.read_csv('datasetaruba/pp4/aruba-freq-var20-35-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_freq_test2035.shape)
df_freq_test2035.head()

df_freq_test4055 = pd.read_csv('datasetaruba/pp4/aruba-freq-var40-55-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_freq_test4055.shape)
df_freq_test4055.head()

df_freq_test6075 = pd.read_csv('datasetaruba/pp4/aruba-freq-var60-75-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_freq_test6075.shape)
df_freq_test6075.head()

df_freq_test8095 = pd.read_csv('datasetaruba/pp4/aruba-freq-var80-95-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_freq_test8095.shape)
df_freq_test8095.head()

df_freq_test2095 = pd.read_csv('datasetaruba/pp4/aruba-freq-var20-95-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_freq_test2095.shape)
df_freq_test2095.head()
# Out:
# (28, 15)
# (28, 15)
# (28, 15)
# (28, 15)
# (28, 15)
#    dia  dia_semana  fim_semana  BedToToilet  Eating  MealPreparation  Relax  \
# 0    1           0           0          7.0     7.0              6.0   23.0
# 1    2           2           0          1.0     1.0              4.0    4.0
# 2    3           0           0          6.0     9.0              7.0   17.0
# 3    4           3           0          6.0     6.0             11.0   27.0
# 4    5           0           0          1.0     8.0             12.0   10.0
#
#    Sleeping  var_BedToToilet  var_Eating  var_MealPreparation  var_Relax  \
# 0       6.0               -1          -1                    1         -1
# 1       6.0                1           1                   -1         -1
# 2       7.0               -1          -1                   -1          1
# 3       6.0               -1          -1                   -1         -1
# 4       7.0                1          -1                   -1         -1
#
# ...

# %%
# atributo DFREQ

# %%
## importando dataset TREINAMENTO
df_dfreq_trein = pd.read_csv('datasetaruba/pp4/aruba-dfreq-trein56.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dfreq_trein.shape)
df_dfreq_trein.head()
# Out:
# (56, 8)
#    dia  dia_semana  fim_semana  BedToToilet  Eating  MealPreparation  Relax  \
# 0    1           3           0          158     156              444   1555
# 1    2           4           0          160     209              375   1555
# 2    3           5           1          189     598              375   1555
# 3    4           6           1          174    1193              210   1697
# 4    5           0           0          184     806              235   1978
#
#    Sleeping
# 0     14229
# 1     16006
# 2     16215
# 3      9492
# 4      5366

# %%
## importando dataset de TESTE
df_dfreq_test2035 = pd.read_csv('datasetaruba/pp4/aruba-dfreq-var20-35-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dfreq_test2035.shape)
df_dfreq_test2035.head()

df_dfreq_test4055 = pd.read_csv('datasetaruba/pp4/aruba-dfreq-var40-55-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dfreq_test4055.shape)
df_dfreq_test4055.head()

df_dfreq_test6075 = pd.read_csv('datasetaruba/pp4/aruba-dfreq-var60-75-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dfreq_test6075.shape)
df_dfreq_test6075.head()

df_dfreq_test8095 = pd.read_csv('datasetaruba/pp4/aruba-dfreq-var80-95-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dfreq_test8095.shape)
df_dfreq_test8095.head()

df_dfreq_test2095 = pd.read_csv('datasetaruba/pp4/aruba-dfreq-var20-95-test28.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_dfreq_test2095.shape)
df_dfreq_test2095.head()
# Out:
# (28, 15)
# (28, 15)
# (28, 15)
# (28, 15)
# (28, 15)
#    dia  dia_semana  fim_semana  BedToToilet  Eating  MealPreparation  Relax  \
# 0    1           0           0           15      45              492   1066
# 1    2           2           0          161     211             1950  10611
# 2    3           0           0           32     287              348   1541
# 3    4           3           0           89      60               51    194
# 4    5           0           0          148      13               46   6107
#
#    Sleeping  var_BedToToilet  var_Eating  var_MealPreparation  var_Relax  \
# 0     10577               -1          -1                    1         -1
# 1     10193                1           1                   -1         -1
# 2      5981               -1          -1                   -1          1
# 3      9050               -1          -1                   -1         -1
# 4        38                1          -1                   -1         -1
#
# ...

# %% [markdown]
# ## Treinando MODELOS (4) para SEMANAS (18) para DURACAO

# %%
# inicializando listas para armazenar as métricas

for k in range (1,6): #iterando variacoes
    for z in range (1,4): #iterando atributos
        for y in range (1,5): #iteracao modelos

            #pulando a primeira semana "0" semana = x+1
            csemana = []
            cvariacao = []
            cvp = []
            cvn = []
            cfp = []
            cfn = []
            cacuracia = []
            cprecisao = []
            csensibilidade = []
            cf1escore = []
            for x in range(1,9): #iterando semanas
                semana = x
                # ATRIBUTO DURACAO
                if (z == 1) & (k == 1): #duracao 20-35
                    df_test  = df_dur_test2035.iloc[:, [3,4,5,6,7]].copy()
                    df_dur_test = df_dur_test2035.copy()
                    df_trein = df_dur_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'duracao'
                    variacao = '20-35'
                if (z == 1) & (k == 2): #duracao 40-55
                    df_test  = df_dur_test4055.iloc[:, [3,4,5,6,7]].copy()
                    df_dur_test = df_dur_test4055.copy()
                    df_trein = df_dur_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'duracao'
                    variacao = '40-55'
                if (z == 1) & (k == 3): #duracao 60-75
                    df_test  = df_dur_test6075.iloc[:, [3,4,5,6,7]].copy()
                    df_dur_test = df_dur_test6075.copy()
                    df_trein = df_dur_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'duracao'
                    variacao = '60-75'
                if (z == 1) & (k == 4): #duracao 80-95
                    df_test  = df_dur_test8095.iloc[:, [3,4,5,6,7]].copy()
                    df_dur_test = df_dur_test8095.copy()
                    df_trein = df_dur_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'duracao'
                    variacao = '80-95'  
                if (z == 1) & (k == 5): #duracao 20-95
                    df_test  = df_dur_test2095.iloc[:, [3,4,5,6,7]].copy()
                    df_dur_test = df_dur_test2095.copy()
                    df_trein = df_dur_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'duracao'
                    variacao = '20-95'                      
                    
                # ATRIBUTO FREQUENCIA
                if (z == 2) & (k == 1): #freq 20-35
                    df_test  = df_freq_test2035.iloc[:, [3,4,5,6,7]].copy()
                    df_freq_test = df_freq_test2035.copy()
                    df_trein = df_freq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'frequencia'
                    variacao = '20-35'
                if (z == 2) & (k == 2): #duracao 40-55
                    df_test  = df_freq_test4055.iloc[:, [3,4,5,6,7]].copy()
                    df_freq_test = df_freq_test4055.copy()
                    df_trein = df_freq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'frequencia'
                    variacao = '40-55'
                if (z == 2) & (k == 3): #duracao 60-75
                    df_test  = df_freq_test6075.iloc[:, [3,4,5,6,7]].copy()
                    df_freq_test = df_freq_test6075.copy()
                    df_trein = df_freq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'frequencia'
                    variacao = '60-75'
                if (z == 2) & (k == 4): #duracao 80-95
                    df_test  = df_freq_test8095.iloc[:, [3,4,5,6,7]].copy()
                    df_freq_test = df_freq_test8095.copy()
                    df_trein = df_freq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'frequencia'
                    variacao = '80-95'          
                if (z == 2) & (k == 5): #duracao 20-95
                    df_test  = df_freq_test2095.iloc[:, [3,4,5,6,7]].copy()
                    df_freq_test = df_freq_test2095.copy()
                    df_trein = df_freq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'frequencia'
                    variacao = '20-95'                        
                    
                # ATRIBUTO DFREQ
                if (z == 3) & (k == 1): #dfreq 20-35
                    df_test  = df_dfreq_test2035.iloc[:, [3,4,5,6,7]].copy()
                    df_dfreq_test = df_dfreq_test2035.copy()
                    df_trein = df_dfreq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'dfreq'
                    variacao = '20-35'
                if (z == 3) & (k == 2): #dfreq 40-55
                    df_test  = df_dfreq_test4055.iloc[:, [3,4,5,6,7]].copy()
                    df_dfreq_test = df_dfreq_test4055.copy()
                    df_trein = df_dfreq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'dfreq'
                    variacao = '40-55'
                if (z == 3) & (k == 3): #duracao 60-75
                    df_test  = df_dfreq_test6075.iloc[:, [3,4,5,6,7]].copy()
                    df_dfreq_test = df_dfreq_test6075.copy()
                    df_trein = df_dfreq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'dfreq'
                    variacao = '60-75'
                if (z == 3) & (k == 4): #duracao 80-95
                    df_test  = df_dfreq_test8095.iloc[:, [3,4,5,6,7]].copy()
                    df_dfreq_test = df_dfreq_test8095.copy()
                    df_trein = df_dfreq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'dfreq'
                    variacao = '80-95'        
                if (z == 3) & (k == 5): #duracao 20-95
                    df_test  = df_dfreq_test2095.iloc[:, [3,4,5,6,7]].copy()
                    df_dfreq_test = df_dfreq_test2095.copy()
                    df_trein = df_dfreq_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5,6,7]]
                    atributo = 'dfreq'
                    variacao = '20-95'                            
                    
                #standarização
                scaler = StandardScaler().fit(df_trein)
                df_trein = scaler.transform(df_trein).copy()
                df_test = scaler.transform(df_test).copy()

                # aplicando o primeiro algoritmo o OSMV
                # fit the model
                if y == 1:
                    clf = svm.OneClassSVM(nu=0.1, kernel='rbf', gamma='scale')
                    algoritmo = 'ocsvm'
                if y == 2:
                    clf = LocalOutlierFactor(n_neighbors=10, novelty=True)
                    algoritmo = 'lof'
                if y == 3:
                    clf = IsolationForest(contamination= 0.01, random_state=1)
                    algoritmo = 'iforest'
                if y == 4:
                    clf = EllipticEnvelope(contamination= 0.01, random_state=0, support_fraction= 0.9)
                    algoritmo = 'rce'

                clf.fit(df_trein)
                y_pred_train = clf.predict(df_trein)
                y_pred_teste = clf.predict(df_test)
                n_error_train = y_pred_train[y_pred_train == -1].size

                # calculando métricas
                if z == 1 : #duracao
                    df_dur_test['predicao'] = y_pred_teste
                    df_dur_test['vp'] = np.where((df_dur_test['outlier'] == -1) & (df_dur_test['predicao'] == -1), 1,0)
                    df_dur_test['vn'] = np.where((df_dur_test['outlier'] == 1) & (df_dur_test['predicao'] == 1), 1,0)
                    df_dur_test['fp'] = np.where((df_dur_test['outlier'] == -1) & (df_dur_test['predicao'] == 1), 1,0)
                    df_dur_test['fn'] = np.where((df_dur_test['outlier'] == 1) & (df_dur_test['predicao'] == -1), 1,0)
                    VP = df_dur_test['vp'].sum()
                    VN = df_dur_test['vn'].sum()
                    FP = df_dur_test['fp'].sum()
                    FN = df_dur_test['fn'].sum()
                if z == 2 : #freq
                    df_freq_test['predicao'] = y_pred_teste
                    df_freq_test['vp'] = np.where((df_freq_test['outlier'] == -1) & (df_freq_test['predicao'] == -1), 1,0)
                    df_freq_test['vn'] = np.where((df_freq_test['outlier'] == 1) & (df_freq_test['predicao'] == 1), 1,0)
                    df_freq_test['fp'] = np.where((df_freq_test['outlier'] == -1) & (df_freq_test['predicao'] == 1), 1,0)
                    df_freq_test['fn'] = np.where((df_freq_test['outlier'] == 1) & (df_freq_test['predicao'] == -1), 1,0)
                    VP = df_freq_test['vp'].sum()
                    VN = df_freq_test['vn'].sum()
                    FP = df_freq_test['fp'].sum()
                    FN = df_freq_test['fn'].sum()                
                if z == 3 : #dfreq
                    df_dfreq_test['predicao'] = y_pred_teste
                    df_dfreq_test['vp'] = np.where((df_dfreq_test['outlier'] == -1) & (df_dfreq_test['predicao'] == -1), 1,0)
                    df_dfreq_test['vn'] = np.where((df_dfreq_test['outlier'] == 1) & (df_dfreq_test['predicao'] == 1), 1,0)
                    df_dfreq_test['fp'] = np.where((df_dfreq_test['outlier'] == -1) & (df_dfreq_test['predicao'] == 1), 1,0)
                    df_dfreq_test['fn'] = np.where((df_dfreq_test['outlier'] == 1) & (df_dfreq_test['predicao'] == -1), 1,0)
                    VP = df_dfreq_test['vp'].sum()
                    VN = df_dfreq_test['vn'].sum()
                    FP = df_dfreq_test['fp'].sum()
                    FN = df_dfreq_test['fn'].sum()                

                erro = (FP+FN)/(VP+VN+FP+FN) #erro
                acuracia =  (VP+VN)/(VP+VN+FP+FN) # accuracy
                precisao = (VP)/(FP+VP) # precision
                sensibilidade = VP/(FN+VP) #recall
                f1escore = 2 * ((precisao * sensibilidade)/(precisao + sensibilidade))
                #armazenando metricas temp
                csemana.append(semana)
                cvariacao.append(variacao)
                cvp.append(VP)
                cvn.append(VN)
                cfp.append(FP)
                cfn.append(FN)
                cacuracia.append(acuracia)
                cprecisao.append(precisao)
                csensibilidade.append(sensibilidade)
                cf1escore.append(f1escore)
                # dentro do for X SEMANAS

            #criando um dataframe a partir das métricas    
            zipped = list(zip(csemana,cvariacao,cvp,cvn,cfp,cfn,cacuracia, cprecisao, csensibilidade, cf1escore))    
            dfmetricas = pd.DataFrame(zipped, columns=['semanas','variacao','vp', 'vn', 'fp', 'fn','acuracia','precisao','sensibilidade','f1score'])
            dfmetricas['algoritmo'] = algoritmo
            dfmetricas['variavel'] = atributo
            dfmetricas['variacao'] = variacao
            dfmetricas= dfmetricas.replace(np.nan,0)
            #print(dfmetricas.head(20))
            #exportando dataframes para datasets

            dfmetricas.to_csv(r'datasetaruba/results/armetricas-indivatrib-'+algoritmo+'-'+atributo+'-var-'+variacao+'-trein8.csv', sep=';', index=False, decimal=',')

            #dentro do for Y MODELOS
        #dentro do for Z ATRIBUTOS
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_lof.py:284: UserWarning: n_neighbors (10) is greater than the total number of samples (7). n_neighbors will be set to (n_samples - 1) for estimation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_lof.py:284: UserWarning: n_neighbors (10) is greater than the total number of samples (7). n_neighbors will be set to (n_samples - 1) for estimation.
#   warnings.warn(
# C:\Users\mauri\AppData\Local\Temp\ipykernel_16264\1956788887.py:191: RuntimeWarning: invalid value encountered in longlong_scalars
#   sensibilidade = VP/(FN+VP) #recall
# C:\Users\mauri\AppData\Local\Temp\ipykernel_16264\1956788887.py:191: RuntimeWarning: invalid value encountered in longlong_scalars
#   sensibilidade = VP/(FN+VP) #recall
# C:\Users\mauri\AppData\Local\Temp\ipykernel_16264\1956788887.py:191: RuntimeWarning: invalid value encountered in longlong_scalars
#   sensibilidade = VP/(FN+VP) #recall
# ...

# %%
print('DONE')
# Out:
# DONE
