# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ### Importando dataset metricas para 9 atividades

# %%
## importando dataset
df_metricas = pd.read_csv('datasetaruba/results/armetricas-atividades-geral.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
df_metricas = df_metricas.fillna(0)
print(df_metricas.shape)
df_metricas.head()
# Out:
# (800, 12)
#    vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 0  10   3   0  15  0.464286       1.0       0.400000  0.571429     ocsvm
# 1  10  12   0   6  0.785714       1.0       0.625000  0.769231     ocsvm
# 2  10  15   0   3  0.892857       1.0       0.769231  0.869565     ocsvm
# 3  10  17   0   1  0.964286       1.0       0.909091  0.952381     ocsvm
# 4  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
#
#   variacao    atividade  semana
# 0    20-35  BedToToilet       1
# 1    20-35  BedToToilet       2
# 2    20-35  BedToToilet       3
# 3    20-35  BedToToilet       4
# 4    20-35  BedToToilet       5

# %% [markdown]
# ## LOF

# %%
# BedToToilet LOF

# %%
dfm_BedToToilet_lof = df_metricas[(df_metricas['atividade'] == "BedToToilet") & (df_metricas['algoritmo'] == "lof")]
print(dfm_BedToToilet_lof.shape)
dfm_BedToToilet_lof.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 8    9  18   1   0  0.964286       0.9       1.000000  0.947368       lof
# 9    7  18   3   0  0.892857       0.7       1.000000  0.823529       lof
# 10   7  18   3   0  0.892857       0.7       1.000000  0.823529       lof
# 11   9  16   1   2  0.892857       0.9       0.818182  0.857143       lof
# 12   8  16   2   2  0.857143       0.8       0.800000  0.800000       lof
#
#    variacao    atividade  semana
# 8     20-35  BedToToilet       1
# 9     20-35  BedToToilet       2
# 10    20-35  BedToToilet       3
# 11    20-35  BedToToilet       4
# 12    20-35  BedToToilet       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# EATING LOF

# %%
dfm_Eating_lof = df_metricas[(df_metricas['atividade'] == "Eating") & (df_metricas['algoritmo'] == "lof")]
print(dfm_Eating_lof.shape)
dfm_Eating_lof.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 40   0  16  12   0  0.571429  0.000000       0.000000  0.000000       lof
# 41   0  16  12   0  0.571429  0.000000       0.000000  0.000000       lof
# 42   0  16  12   0  0.571429  0.000000       0.000000  0.000000       lof
# 43   1  15  11   1  0.571429  0.083333       0.500000  0.142857       lof
# 44   2  15  10   1  0.607143  0.166667       0.666667  0.266667       lof
#
#    variacao atividade  semana
# 40    20-35    Eating       1
# 41    20-35    Eating       2
# 42    20-35    Eating       3
# 43    20-35    Eating       4
# 44    20-35    Eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# MealPreparation - LOF

# %%
dfm_MealPreparation_lof = df_metricas[(df_metricas['atividade'] == "MealPreparation") & (df_metricas['algoritmo'] == "lof")]
print(dfm_MealPreparation_lof.shape)
dfm_MealPreparation_lof.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 72   4  16   7   1  0.714286  0.363636       0.800000  0.500000       lof
# 73   4  16   7   1  0.714286  0.363636       0.800000  0.500000       lof
# 74   4  15   7   2  0.678571  0.363636       0.666667  0.470588       lof
# 75   4  15   7   2  0.678571  0.363636       0.666667  0.470588       lof
# 76   2  17   9   0  0.678571  0.181818       1.000000  0.307692       lof
#
#    variacao        atividade  semana
# 72    20-35  MealPreparation       1
# 73    20-35  MealPreparation       2
# 74    20-35  MealPreparation       3
# 75    20-35  MealPreparation       4
# 76    20-35  MealPreparation       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Relax - LOF
dfm_Relax_lof = df_metricas[(df_metricas['atividade'] == "Relax") & (df_metricas['algoritmo'] == "lof")]
print(dfm_Relax_lof.shape)
dfm_Relax_lof.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 104   6  16   5   1  0.785714  0.545455       0.857143  0.666667       lof
# 105   6  14   5   3  0.714286  0.545455       0.666667  0.600000       lof
# 106   6  16   5   1  0.785714  0.545455       0.857143  0.666667       lof
# 107   6  16   5   1  0.785714  0.545455       0.857143  0.666667       lof
# 108   6  16   5   1  0.785714  0.545455       0.857143  0.666667       lof
#
#     variacao atividade  semana
# 104    20-35     Relax       1
# 105    20-35     Relax       2
# 106    20-35     Relax       3
# 107    20-35     Relax       4
# 108    20-35     Relax       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Sleeping - LOF
dfm_Sleeping_lof = df_metricas[(df_metricas['atividade'] == "Sleeping") & (df_metricas['algoritmo'] == "lof")]
print(dfm_Sleeping_lof.shape)
dfm_Sleeping_lof.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 136   0  15  12   1  0.535714  0.000000       0.000000  0.000000       lof
# 137   2  15  10   1  0.607143  0.166667       0.666667  0.266667       lof
# 138   2  15  10   1  0.607143  0.166667       0.666667  0.266667       lof
# 139   2  15  10   1  0.607143  0.166667       0.666667  0.266667       lof
# 140   3  13   9   3  0.571429  0.250000       0.500000  0.333333       lof
#
#     variacao atividade  semana
# 136    20-35  Sleeping       1
# 137    20-35  Sleeping       2
# 138    20-35  Sleeping       3
# 139    20-35  Sleeping       4
# 140    20-35  Sleeping       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## RCE

# %%
# BedToToilet RCE

# %%
dfm_BedToToilet_rce = df_metricas[(df_metricas['atividade'] == "BedToToilet") & (df_metricas['algoritmo'] == "rce")]
print(dfm_BedToToilet_rce.shape)
dfm_BedToToilet_rce.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 24  10   8   0  10  0.642857       1.0       0.500000  0.666667       rce
# 25  10  12   0   6  0.785714       1.0       0.625000  0.769231       rce
# 26   9  10   1   8  0.678571       0.9       0.529412  0.666667       rce
# 27  10  17   0   1  0.964286       1.0       0.909091  0.952381       rce
# 28  10  17   0   1  0.964286       1.0       0.909091  0.952381       rce
#
#    variacao    atividade  semana
# 24    20-35  BedToToilet       1
# 25    20-35  BedToToilet       2
# 26    20-35  BedToToilet       3
# 27    20-35  BedToToilet       4
# 28    20-35  BedToToilet       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# EATING RCE

# %%
dfm_Eating_rce = df_metricas[(df_metricas['atividade'] == "Eating") & (df_metricas['algoritmo'] == "rce")]
print(dfm_Eating_rce.shape)
dfm_Eating_rce.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 56   4  10   8   6  0.500000  0.333333       0.400000  0.363636       rce
# 57   0  14  12   2  0.500000  0.000000       0.000000  0.000000       rce
# 58   1  15  11   1  0.571429  0.083333       0.500000  0.142857       rce
# 59   2  14  10   2  0.571429  0.166667       0.500000  0.250000       rce
# 60   2  15  10   1  0.607143  0.166667       0.666667  0.266667       rce
#
#    variacao atividade  semana
# 56    20-35    Eating       1
# 57    20-35    Eating       2
# 58    20-35    Eating       3
# 59    20-35    Eating       4
# 60    20-35    Eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# MealPreparation - RCE
dfm_MealPreparation_rce = df_metricas[(df_metricas['atividade'] == "MealPreparation") & (df_metricas['algoritmo'] == "rce")]
print(dfm_MealPreparation_rce.shape)
dfm_MealPreparation_rce.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 88  10   4   1  13  0.500000  0.909091       0.434783  0.588235       rce
# 89   4   9   7   8  0.464286  0.363636       0.333333  0.347826       rce
# 90   4   9   7   8  0.464286  0.363636       0.333333  0.347826       rce
# 91   4  11   7   6  0.535714  0.363636       0.400000  0.380952       rce
# 92   6  12   5   5  0.642857  0.545455       0.545455  0.545455       rce
#
#    variacao        atividade  semana
# 88    20-35  MealPreparation       1
# 89    20-35  MealPreparation       2
# 90    20-35  MealPreparation       3
# 91    20-35  MealPreparation       4
# 92    20-35  MealPreparation       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Relax - RCE
dfm_Relax_rce = df_metricas[(df_metricas['atividade'] == "Relax") & (df_metricas['algoritmo'] == "rce")]
print(dfm_Relax_rce.shape)
dfm_Relax_rce.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 120  11   1   0  16  0.428571  1.000000       0.407407  0.578947       rce
# 121  10  10   1   7  0.714286  0.909091       0.588235  0.714286       rce
# 122  10  12   1   5  0.785714  0.909091       0.666667  0.769231       rce
# 123   9  12   2   5  0.750000  0.818182       0.642857  0.720000       rce
# 124   9  12   2   5  0.750000  0.818182       0.642857  0.720000       rce
#
#     variacao atividade  semana
# 120    20-35     Relax       1
# 121    20-35     Relax       2
# 122    20-35     Relax       3
# 123    20-35     Relax       4
# 124    20-35     Relax       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Sleeping - RCE
dfm_Sleeping_rce = df_metricas[(df_metricas['atividade'] == "Sleeping") & (df_metricas['algoritmo'] == "rce")]
print(dfm_Sleeping_rce.shape)
dfm_Sleeping_rce.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 152   6  14   6   2  0.714286  0.500000       0.750000  0.600000       rce
# 153   6  14   6   2  0.714286  0.500000       0.750000  0.600000       rce
# 154   5  15   7   1  0.714286  0.416667       0.833333  0.555556       rce
# 155   8  15   4   1  0.821429  0.666667       0.888889  0.761905       rce
# 156   8  14   4   2  0.785714  0.666667       0.800000  0.727273       rce
#
#     variacao atividade  semana
# 152    20-35  Sleeping       1
# 153    20-35  Sleeping       2
# 154    20-35  Sleeping       3
# 155    20-35  Sleeping       4
# 156    20-35  Sleeping       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## IFOREST

# %%
# BedToToilet iForest

# %%
dfm_BedToToilet_if = df_metricas[(df_metricas['atividade'] == "BedToToilet") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_BedToToilet_if.shape)
dfm_BedToToilet_if.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 16   1  17   9   1  0.642857       0.1       0.500000  0.166667   iforest
# 17   1  17   9   1  0.642857       0.1       0.500000  0.166667   iforest
# 18   5  15   5   3  0.714286       0.5       0.625000  0.555556   iforest
# 19   5  14   5   4  0.678571       0.5       0.555556  0.526316   iforest
# 20   9  14   1   4  0.821429       0.9       0.692308  0.782609   iforest
#
#    variacao    atividade  semana
# 16    20-35  BedToToilet       1
# 17    20-35  BedToToilet       2
# 18    20-35  BedToToilet       3
# 19    20-35  BedToToilet       4
# 20    20-35  BedToToilet       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# EATING IF

# %%
dfm_Eating_if = df_metricas[(df_metricas['atividade'] == "Eating") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_Eating_if.shape)
dfm_Eating_if.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 48   0  13  12   3  0.464286  0.000000       0.000000  0.000000   iforest
# 49   1  14  11   2  0.535714  0.083333       0.333333  0.133333   iforest
# 50   1  14  11   2  0.535714  0.083333       0.333333  0.133333   iforest
# 51   0  14  12   2  0.500000  0.000000       0.000000  0.000000   iforest
# 52   0  14  12   2  0.500000  0.000000       0.000000  0.000000   iforest
#
#    variacao atividade  semana
# 48    20-35    Eating       1
# 49    20-35    Eating       2
# 50    20-35    Eating       3
# 51    20-35    Eating       4
# 52    20-35    Eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# MealPreparation - IFOREST
dfm_MealPreparation_if = df_metricas[(df_metricas['atividade'] == "MealPreparation") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_MealPreparation_if.shape)
dfm_MealPreparation_if.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 80   4   9   7   8  0.464286  0.363636       0.333333  0.347826   iforest
# 81   3   9   8   8  0.428571  0.272727       0.272727  0.272727   iforest
# 82   5   8   6   9  0.464286  0.454545       0.357143  0.400000   iforest
# 83   5   9   6   8  0.500000  0.454545       0.384615  0.416667   iforest
# 84   4  13   7   4  0.607143  0.363636       0.500000  0.421053   iforest
#
#    variacao        atividade  semana
# 80    20-35  MealPreparation       1
# 81    20-35  MealPreparation       2
# 82    20-35  MealPreparation       3
# 83    20-35  MealPreparation       4
# 84    20-35  MealPreparation       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Relax - IFOREST
dfm_Relax_if = df_metricas[(df_metricas['atividade'] == "Relax") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_Relax_if.shape)
dfm_Relax_if.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 112   1  16  10   1  0.607143  0.090909       0.500000  0.153846   iforest
# 113   9  10   2   7  0.678571  0.818182       0.562500  0.666667   iforest
# 114   9  12   2   5  0.750000  0.818182       0.642857  0.720000   iforest
# 115   9  11   2   6  0.714286  0.818182       0.600000  0.692308   iforest
# 116   9  11   2   6  0.714286  0.818182       0.600000  0.692308   iforest
#
#     variacao atividade  semana
# 112    20-35     Relax       1
# 113    20-35     Relax       2
# 114    20-35     Relax       3
# 115    20-35     Relax       4
# 116    20-35     Relax       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Sleeping - IFOREST
dfm_Sleeping_if = df_metricas[(df_metricas['atividade'] == "Sleeping") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_Sleeping_if.shape)
dfm_Sleeping_if.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 144   3  12   9   4  0.535714  0.250000       0.428571  0.315789   iforest
# 145   6  11   6   5  0.607143  0.500000       0.545455  0.521739   iforest
# 146   0  15  12   1  0.535714  0.000000       0.000000  0.000000   iforest
# 147   6  15   6   1  0.750000  0.500000       0.857143  0.631579   iforest
# 148   5  15   7   1  0.714286  0.416667       0.833333  0.555556   iforest
#
#     variacao atividade  semana
# 144    20-35  Sleeping       1
# 145    20-35  Sleeping       2
# 146    20-35  Sleeping       3
# 147    20-35  Sleeping       4
# 148    20-35  Sleeping       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## OCSVM

# %%
# BedToToilet OCSVM

# %%
dfm_BedToToilet_ocsvm = df_metricas[(df_metricas['atividade'] == "BedToToilet") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_BedToToilet_ocsvm.shape)
dfm_BedToToilet_ocsvm.head()
# Out:
# (40, 12)
#    vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 0  10   3   0  15  0.464286       1.0       0.400000  0.571429     ocsvm
# 1  10  12   0   6  0.785714       1.0       0.625000  0.769231     ocsvm
# 2  10  15   0   3  0.892857       1.0       0.769231  0.869565     ocsvm
# 3  10  17   0   1  0.964286       1.0       0.909091  0.952381     ocsvm
# 4  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
#
#   variacao    atividade  semana
# 0    20-35  BedToToilet       1
# 1    20-35  BedToToilet       2
# 2    20-35  BedToToilet       3
# 3    20-35  BedToToilet       4
# 4    20-35  BedToToilet       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_BedToToilet_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# EATING OCSVM

# %%
dfm_Eating_ocsvm = df_metricas[(df_metricas['atividade'] == "Eating") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_Eating_ocsvm.shape)
dfm_Eating_ocsvm.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 32   8   2   4  14  0.357143  0.666667       0.363636  0.470588     ocsvm
# 33   4   8   8   8  0.428571  0.333333       0.333333  0.333333     ocsvm
# 34   4  11   8   5  0.535714  0.333333       0.444444  0.380952     ocsvm
# 35   4  11   8   5  0.535714  0.333333       0.444444  0.380952     ocsvm
# 36   4  13   8   3  0.607143  0.333333       0.571429  0.421053     ocsvm
#
#    variacao atividade  semana
# 32    20-35    Eating       1
# 33    20-35    Eating       2
# 34    20-35    Eating       3
# 35    20-35    Eating       4
# 36    20-35    Eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Eating_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# MealPreparation - OCSVM
dfm_MealPreparation_ocsvm = df_metricas[(df_metricas['atividade'] == "MealPreparation") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_MealPreparation_ocsvm.shape)
dfm_MealPreparation_ocsvm.head()
# Out:
# (40, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 64   9   3   2  14  0.428571  0.818182       0.391304  0.529412     ocsvm
# 65   7   7   4  10  0.500000  0.636364       0.411765  0.500000     ocsvm
# 66   7  11   4   6  0.642857  0.636364       0.538462  0.583333     ocsvm
# 67   6   8   5   9  0.500000  0.545455       0.400000  0.461538     ocsvm
# 68   6  14   5   3  0.714286  0.545455       0.666667  0.600000     ocsvm
#
#    variacao        atividade  semana
# 64    20-35  MealPreparation       1
# 65    20-35  MealPreparation       2
# 66    20-35  MealPreparation       3
# 67    20-35  MealPreparation       4
# 68    20-35  MealPreparation       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_MealPreparation_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Relax - OCSVM
dfm_Relax_ocsvm = df_metricas[(df_metricas['atividade'] == "Relax") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_Relax_ocsvm.shape)
dfm_Relax_ocsvm.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 96   11   1   0  16  0.428571  1.000000       0.407407  0.578947     ocsvm
# 97   11   8   0   9  0.678571  1.000000       0.550000  0.709677     ocsvm
# 98    8  10   3   7  0.642857  0.727273       0.533333  0.615385     ocsvm
# 99    8  12   3   5  0.714286  0.727273       0.615385  0.666667     ocsvm
# 100   7  12   4   5  0.678571  0.636364       0.583333  0.608696     ocsvm
#
#     variacao atividade  semana
# 96     20-35     Relax       1
# 97     20-35     Relax       2
# 98     20-35     Relax       3
# 99     20-35     Relax       4
# 100    20-35     Relax       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Relax_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# Sleeping - OCSVM
dfm_Sleeping_ocsvm = df_metricas[(df_metricas['atividade'] == "Sleeping") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_Sleeping_ocsvm.shape)
dfm_Sleeping_ocsvm.head()
# Out:
# (40, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 128   9   8   3   8  0.607143  0.750000       0.529412  0.620690     ocsvm
# 129   9  10   3   6  0.678571  0.750000       0.600000  0.666667     ocsvm
# 130   9  14   3   2  0.821429  0.750000       0.818182  0.782609     ocsvm
# 131   9  14   3   2  0.821429  0.750000       0.818182  0.782609     ocsvm
# 132  10  12   2   4  0.785714  0.833333       0.714286  0.769231     ocsvm
#
#     variacao atividade  semana
# 128    20-35  Sleeping       1
# 129    20-35  Sleeping       2
# 130    20-35  Sleeping       3
# 131    20-35  Sleeping       4
# 132    20-35  Sleeping       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_Sleeping_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## ATIVIDADES INDIVIDUAIS DAIXAS

# %%
#BedToToilet  LOF
dfm_BedToToilet_lof_2035 = dfm_BedToToilet_lof[(dfm_BedToToilet_lof['variacao'] == "20-35")]
dfm_BedToToilet_lof_4055 = dfm_BedToToilet_lof[(dfm_BedToToilet_lof['variacao'] == "40-55")]
dfm_BedToToilet_lof_6075 = dfm_BedToToilet_lof[(dfm_BedToToilet_lof['variacao'] == "60-75")]
dfm_BedToToilet_lof_8095 = dfm_BedToToilet_lof[(dfm_BedToToilet_lof['variacao'] == "80-95")]
dfm_BedToToilet_lof_2095 = dfm_BedToToilet_lof[(dfm_BedToToilet_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_btt_lof.svg')

# %%
dfm_BedToToilet_lof_2035.head(10)
dfm_BedToToilet_lof_4055.head(10)
dfm_BedToToilet_lof_6075.head(10)
dfm_BedToToilet_lof_8095.head(10)
dfm_BedToToilet_lof_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 648  12  16   0   0  1.000000       1.0       1.000000  1.000000       lof
# 649  12  16   0   0  1.000000       1.0       1.000000  1.000000       lof
# 650  12  16   0   0  1.000000       1.0       1.000000  1.000000       lof
# 651  12  15   0   1  0.964286       1.0       0.923077  0.960000       lof
# 652  12  15   0   1  0.964286       1.0       0.923077  0.960000       lof
# 653  12  16   0   0  1.000000       1.0       1.000000  1.000000       lof
# 654  12  11   0   5  0.821429       1.0       0.705882  0.827586       lof
# 655  12  11   0   5  0.821429       1.0       0.705882  0.827586       lof
#
#     variacao    atividade  semana
# 648    20-95  BedToToilet       1
# 649    20-95  BedToToilet       2
# 650    20-95  BedToToilet       3
# 651    20-95  BedToToilet       4
# 652    20-95  BedToToilet       5
# 653    20-95  BedToToilet       6
# 654    20-95  BedToToilet       7
# ...

# %%
#BedToToilet  if
dfm_BedToToilet_if_2035 = dfm_BedToToilet_if[(dfm_BedToToilet_if['variacao'] == "20-35")]
dfm_BedToToilet_if_4055 = dfm_BedToToilet_if[(dfm_BedToToilet_if['variacao'] == "40-55")]
dfm_BedToToilet_if_6075 = dfm_BedToToilet_if[(dfm_BedToToilet_if['variacao'] == "60-75")]
dfm_BedToToilet_if_8095 = dfm_BedToToilet_if[(dfm_BedToToilet_if['variacao'] == "80-95")]
dfm_BedToToilet_if_2095 = dfm_BedToToilet_if[(dfm_BedToToilet_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_btt_if.svg')

# %%
dfm_BedToToilet_if_2035.head(10)
# dfm_BedToToilet_if_4055.head(10)
# dfm_BedToToilet_if_6075.head(10)
# dfm_BedToToilet_if_8095.head(10)
# dfm_BedToToilet_if_2095.head(10)
# Out:
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 16   1  17   9   1  0.642857       0.1       0.500000  0.166667   iforest
# 17   1  17   9   1  0.642857       0.1       0.500000  0.166667   iforest
# 18   5  15   5   3  0.714286       0.5       0.625000  0.555556   iforest
# 19   5  14   5   4  0.678571       0.5       0.555556  0.526316   iforest
# 20   9  14   1   4  0.821429       0.9       0.692308  0.782609   iforest
# 21   9  13   1   5  0.785714       0.9       0.642857  0.750000   iforest
# 22  10  13   0   5  0.821429       1.0       0.666667  0.800000   iforest
# 23  10  16   0   2  0.928571       1.0       0.833333  0.909091   iforest
#
#    variacao    atividade  semana
# 16    20-35  BedToToilet       1
# 17    20-35  BedToToilet       2
# 18    20-35  BedToToilet       3
# 19    20-35  BedToToilet       4
# 20    20-35  BedToToilet       5
# 21    20-35  BedToToilet       6
# 22    20-35  BedToToilet       7
# ...

# %%
#BedToToilet  ocsvm
dfm_BedToToilet_ocsvm_2035 = dfm_BedToToilet_ocsvm[(dfm_BedToToilet_ocsvm['variacao'] == "20-35")]
dfm_BedToToilet_ocsvm_4055 = dfm_BedToToilet_ocsvm[(dfm_BedToToilet_ocsvm['variacao'] == "40-55")]
dfm_BedToToilet_ocsvm_6075 = dfm_BedToToilet_ocsvm[(dfm_BedToToilet_ocsvm['variacao'] == "60-75")]
dfm_BedToToilet_ocsvm_8095 = dfm_BedToToilet_ocsvm[(dfm_BedToToilet_ocsvm['variacao'] == "80-95")]
dfm_BedToToilet_ocsvm_2095 = dfm_BedToToilet_ocsvm[(dfm_BedToToilet_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_btt_oc.svg')

# %%
dfm_BedToToilet_ocsvm_2035.head(10)
# dfm_BedToToilet_ocsvm_4055.head(10)
# dfm_BedToToilet_ocsvm_6075.head(10)
# dfm_BedToToilet_ocsvm_8095.head(10)
# dfm_BedToToilet_ocsvm_2095.head(10)
# Out:
#    vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 0  10   3   0  15  0.464286       1.0       0.400000  0.571429     ocsvm
# 1  10  12   0   6  0.785714       1.0       0.625000  0.769231     ocsvm
# 2  10  15   0   3  0.892857       1.0       0.769231  0.869565     ocsvm
# 3  10  17   0   1  0.964286       1.0       0.909091  0.952381     ocsvm
# 4  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
# 5  10  12   0   6  0.785714       1.0       0.625000  0.769231     ocsvm
# 6  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
# 7  10  14   0   4  0.857143       1.0       0.714286  0.833333     ocsvm
#
#   variacao    atividade  semana
# 0    20-35  BedToToilet       1
# 1    20-35  BedToToilet       2
# 2    20-35  BedToToilet       3
# 3    20-35  BedToToilet       4
# 4    20-35  BedToToilet       5
# 5    20-35  BedToToilet       6
# 6    20-35  BedToToilet       7
# 7    20-35  BedToToilet       8

# %%
#BedToToilet  rce
dfm_BedToToilet_rce_2035 = dfm_BedToToilet_rce[(dfm_BedToToilet_rce['variacao'] == "20-35")]
dfm_BedToToilet_rce_4055 = dfm_BedToToilet_rce[(dfm_BedToToilet_rce['variacao'] == "40-55")]
dfm_BedToToilet_rce_6075 = dfm_BedToToilet_rce[(dfm_BedToToilet_rce['variacao'] == "60-75")]
dfm_BedToToilet_rce_8095 = dfm_BedToToilet_rce[(dfm_BedToToilet_rce['variacao'] == "80-95")]
dfm_BedToToilet_rce_2095 = dfm_BedToToilet_rce[(dfm_BedToToilet_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_BedToToilet_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_btt_rce.svg')

# %%
dfm_BedToToilet_rce_2035.head(10)
dfm_BedToToilet_rce_4055.head(10)
dfm_BedToToilet_rce_6075.head(10)
dfm_BedToToilet_rce_8095.head(10)
dfm_BedToToilet_rce_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 664  12   9   0   7  0.750000  1.000000       0.631579  0.774194       rce
# 665  11  12   1   4  0.821429  0.916667       0.733333  0.814815       rce
# 666  11  10   1   6  0.750000  0.916667       0.647059  0.758621       rce
# 667  12  15   0   1  0.964286  1.000000       0.923077  0.960000       rce
# 668  12  15   0   1  0.964286  1.000000       0.923077  0.960000       rce
# 669  11  10   1   6  0.750000  0.916667       0.647059  0.758621       rce
# 670  11  13   1   3  0.857143  0.916667       0.785714  0.846154       rce
# 671  11  15   1   1  0.928571  0.916667       0.916667  0.916667       rce
#
#     variacao    atividade  semana
# 664    20-95  BedToToilet       1
# 665    20-95  BedToToilet       2
# 666    20-95  BedToToilet       3
# 667    20-95  BedToToilet       4
# 668    20-95  BedToToilet       5
# 669    20-95  BedToToilet       6
# 670    20-95  BedToToilet       7
# ...

# %%
#MealPreparation  LOF
dfm_MealPreparation_lof_2035 = dfm_MealPreparation_lof[(dfm_MealPreparation_lof['variacao'] == "20-35")]
dfm_MealPreparation_lof_4055 = dfm_MealPreparation_lof[(dfm_MealPreparation_lof['variacao'] == "40-55")]
dfm_MealPreparation_lof_6075 = dfm_MealPreparation_lof[(dfm_MealPreparation_lof['variacao'] == "60-75")]
dfm_MealPreparation_lof_8095 = dfm_MealPreparation_lof[(dfm_MealPreparation_lof['variacao'] == "80-95")]
dfm_MealPreparation_lof_2095 = dfm_MealPreparation_lof[(dfm_MealPreparation_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_mp_lof.svg')

# %%
dfm_MealPreparation_lof_2035.head(10)
dfm_MealPreparation_lof_4055.head(10)
dfm_MealPreparation_lof_6075.head(10)
dfm_MealPreparation_lof_8095.head(10)
dfm_MealPreparation_lof_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 712   3  16   8   1  0.678571  0.272727       0.750000  0.400000       lof
# 713   6  16   5   1  0.785714  0.545455       0.857143  0.666667       lof
# 714   8  16   3   1  0.857143  0.727273       0.888889  0.800000       lof
# 715   8  16   3   1  0.857143  0.727273       0.888889  0.800000       lof
# 716   8  17   3   0  0.892857  0.727273       1.000000  0.842105       lof
# 717   8  16   3   1  0.857143  0.727273       0.888889  0.800000       lof
# 718   8  16   3   1  0.857143  0.727273       0.888889  0.800000       lof
# 719   8  15   3   2  0.821429  0.727273       0.800000  0.761905       lof
#
#     variacao        atividade  semana
# 712    20-95  MealPreparation       1
# 713    20-95  MealPreparation       2
# 714    20-95  MealPreparation       3
# 715    20-95  MealPreparation       4
# 716    20-95  MealPreparation       5
# 717    20-95  MealPreparation       6
# ...

# %%
#MealPreparation  if
dfm_MealPreparation_if_2035 = dfm_MealPreparation_if[(dfm_MealPreparation_if['variacao'] == "20-35")]
dfm_MealPreparation_if_4055 = dfm_MealPreparation_if[(dfm_MealPreparation_if['variacao'] == "40-55")]
dfm_MealPreparation_if_6075 = dfm_MealPreparation_if[(dfm_MealPreparation_if['variacao'] == "60-75")]
dfm_MealPreparation_if_8095 = dfm_MealPreparation_if[(dfm_MealPreparation_if['variacao'] == "80-95")]
dfm_MealPreparation_if_2095 = dfm_MealPreparation_if[(dfm_MealPreparation_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_mp_if.svg')

# %%
dfm_MealPreparation_if_2035.head(10)
dfm_MealPreparation_if_4055.head(10)
dfm_MealPreparation_if_6075.head(10)
# dfm_MealPreparation_if_8095.head(10)
# dfm_MealPreparation_if_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 400   2   8  10   8  0.357143  0.166667       0.200000  0.181818   iforest
# 401   2   8  10   8  0.357143  0.166667       0.200000  0.181818   iforest
# 402   3   7   9   9  0.357143  0.250000       0.250000  0.250000   iforest
# 403   3   7   9   9  0.357143  0.250000       0.250000  0.250000   iforest
# 404  12  11   0   5  0.821429  1.000000       0.705882  0.827586   iforest
# 405  12  13   0   3  0.892857  1.000000       0.800000  0.888889   iforest
# 406  12  15   0   1  0.964286  1.000000       0.923077  0.960000   iforest
# 407  12  15   0   1  0.964286  1.000000       0.923077  0.960000   iforest
#
#     variacao        atividade  semana
# 400    60-75  MealPreparation       1
# 401    60-75  MealPreparation       2
# 402    60-75  MealPreparation       3
# 403    60-75  MealPreparation       4
# 404    60-75  MealPreparation       5
# 405    60-75  MealPreparation       6
# ...

# %%
#MealPreparation  ocsvm
dfm_MealPreparation_ocsvm_2035 = dfm_MealPreparation_ocsvm[(dfm_MealPreparation_ocsvm['variacao'] == "20-35")]
dfm_MealPreparation_ocsvm_4055 = dfm_MealPreparation_ocsvm[(dfm_MealPreparation_ocsvm['variacao'] == "40-55")]
dfm_MealPreparation_ocsvm_6075 = dfm_MealPreparation_ocsvm[(dfm_MealPreparation_ocsvm['variacao'] == "60-75")]
dfm_MealPreparation_ocsvm_8095 = dfm_MealPreparation_ocsvm[(dfm_MealPreparation_ocsvm['variacao'] == "80-95")]
dfm_MealPreparation_ocsvm_2095 = dfm_MealPreparation_ocsvm[(dfm_MealPreparation_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_mp_oc.svg')

# %%
dfm_MealPreparation_ocsvm_2035.head(10)
dfm_MealPreparation_ocsvm_4055.head(10)
# dfm_MealPreparation_ocsvm_6075.head(10)
# dfm_MealPreparation_ocsvm_8095.head(10)
# dfm_MealPreparation_ocsvm_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 224  10   3   0  15  0.464286       1.0       0.400000  0.571429     ocsvm
# 225  10   8   0  10  0.642857       1.0       0.500000  0.666667     ocsvm
# 226  10  12   0   6  0.785714       1.0       0.625000  0.769231     ocsvm
# 227  10   8   0  10  0.642857       1.0       0.500000  0.666667     ocsvm
# 228  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
# 229  10  12   0   6  0.785714       1.0       0.625000  0.769231     ocsvm
# 230  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
# 231  10  16   0   2  0.928571       1.0       0.833333  0.909091     ocsvm
#
#     variacao        atividade  semana
# 224    40-55  MealPreparation       1
# 225    40-55  MealPreparation       2
# 226    40-55  MealPreparation       3
# 227    40-55  MealPreparation       4
# 228    40-55  MealPreparation       5
# 229    40-55  MealPreparation       6
# ...

# %%
#MealPreparation  rce
dfm_MealPreparation_rce_2035 = dfm_MealPreparation_rce[(dfm_MealPreparation_rce['variacao'] == "20-35")]
dfm_MealPreparation_rce_4055 = dfm_MealPreparation_rce[(dfm_MealPreparation_rce['variacao'] == "40-55")]
dfm_MealPreparation_rce_6075 = dfm_MealPreparation_rce[(dfm_MealPreparation_rce['variacao'] == "60-75")]
dfm_MealPreparation_rce_8095 = dfm_MealPreparation_rce[(dfm_MealPreparation_rce['variacao'] == "80-95")]
dfm_MealPreparation_rce_2095 = dfm_MealPreparation_rce[(dfm_MealPreparation_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_MealPreparation_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_mp_rce.svg')

# %%
dfm_MealPreparation_rce_2035.head(10)
dfm_MealPreparation_rce_4055.head(10)
dfm_MealPreparation_rce_6075.head(10)
dfm_MealPreparation_rce_8095.head(10)
dfm_MealPreparation_rce_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 728  10   4   1  13  0.500000  0.909091       0.434783  0.588235       rce
# 729   8   9   3   8  0.607143  0.727273       0.500000  0.592593       rce
# 730   8   9   3   8  0.607143  0.727273       0.500000  0.592593       rce
# 731   8  10   3   7  0.642857  0.727273       0.533333  0.615385       rce
# 732   8  11   3   6  0.678571  0.727273       0.571429  0.640000       rce
# 733   8  16   3   1  0.857143  0.727273       0.888889  0.800000       rce
# 734   8  16   3   1  0.857143  0.727273       0.888889  0.800000       rce
# 735   8  16   3   1  0.857143  0.727273       0.888889  0.800000       rce
#
#     variacao        atividade  semana
# 728    20-95  MealPreparation       1
# 729    20-95  MealPreparation       2
# 730    20-95  MealPreparation       3
# 731    20-95  MealPreparation       4
# 732    20-95  MealPreparation       5
# 733    20-95  MealPreparation       6
# ...

# %%
#Eating  LOF
dfm_Eating_lof_2035 = dfm_Eating_lof[(dfm_Eating_lof['variacao'] == "20-35")]
dfm_Eating_lof_4055 = dfm_Eating_lof[(dfm_Eating_lof['variacao'] == "40-55")]
dfm_Eating_lof_6075 = dfm_Eating_lof[(dfm_Eating_lof['variacao'] == "60-75")]
dfm_Eating_lof_8095 = dfm_Eating_lof[(dfm_Eating_lof['variacao'] == "80-95")]
dfm_Eating_lof_2095 = dfm_Eating_lof[(dfm_Eating_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_eat_lof.svg')

# %%
dfm_Eating_lof_2035.head(10)
dfm_Eating_lof_4055.head(10)
dfm_Eating_lof_6075.head(10)
dfm_Eating_lof_8095.head(10)
dfm_Eating_lof_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 680   0  16  12   0  0.571429  0.000000       0.000000  0.000000       lof
# 681   7  16   5   0  0.821429  0.583333       1.000000  0.736842       lof
# 682  11  16   1   0  0.964286  0.916667       1.000000  0.956522       lof
# 683  12  15   0   1  0.964286  1.000000       0.923077  0.960000       lof
# 684  12  15   0   1  0.964286  1.000000       0.923077  0.960000       lof
# 685  12  13   0   3  0.892857  1.000000       0.800000  0.888889       lof
# 686  11  14   1   2  0.892857  0.916667       0.846154  0.880000       lof
# 687  12  13   0   3  0.892857  1.000000       0.800000  0.888889       lof
#
#     variacao atividade  semana
# 680    20-95    Eating       1
# 681    20-95    Eating       2
# 682    20-95    Eating       3
# 683    20-95    Eating       4
# 684    20-95    Eating       5
# 685    20-95    Eating       6
# 686    20-95    Eating       7
# 687    20-95    Eating       8

# %%
#Eating  if
dfm_Eating_if_2035 = dfm_Eating_if[(dfm_Eating_if['variacao'] == "20-35")]
dfm_Eating_if_4055 = dfm_Eating_if[(dfm_Eating_if['variacao'] == "40-55")]
dfm_Eating_if_6075 = dfm_Eating_if[(dfm_Eating_if['variacao'] == "60-75")]
dfm_Eating_if_8095 = dfm_Eating_if[(dfm_Eating_if['variacao'] == "80-95")]
dfm_Eating_if_2095 = dfm_Eating_if[(dfm_Eating_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_eat_if.svg')

# %%
dfm_Eating_if_2035.head(10)
dfm_Eating_if_4055.head(10)
dfm_Eating_if_6075.head(10)
dfm_Eating_if_8095.head(10)
# dfm_Eating_if_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 528   0  13  12   3  0.464286  0.000000       0.000000  0.000000   iforest
# 529   8  13   4   3  0.750000  0.666667       0.727273  0.695652   iforest
# 530   9  15   3   1  0.857143  0.750000       0.900000  0.818182   iforest
# 531   0  15  12   1  0.535714  0.000000       0.000000  0.000000   iforest
# 532   1  14  11   2  0.535714  0.083333       0.333333  0.133333   iforest
# 533   9  15   3   1  0.857143  0.750000       0.900000  0.818182   iforest
# 534   9  15   3   1  0.857143  0.750000       0.900000  0.818182   iforest
# 535   9  15   3   1  0.857143  0.750000       0.900000  0.818182   iforest
#
#     variacao atividade  semana
# 528    80-95    Eating       1
# 529    80-95    Eating       2
# 530    80-95    Eating       3
# 531    80-95    Eating       4
# 532    80-95    Eating       5
# 533    80-95    Eating       6
# 534    80-95    Eating       7
# 535    80-95    Eating       8

# %%
#Eating  ocsvm
dfm_Eating_ocsvm_2035 = dfm_Eating_ocsvm[(dfm_Eating_ocsvm['variacao'] == "20-35")]
dfm_Eating_ocsvm_4055 = dfm_Eating_ocsvm[(dfm_Eating_ocsvm['variacao'] == "40-55")]
dfm_Eating_ocsvm_6075 = dfm_Eating_ocsvm[(dfm_Eating_ocsvm['variacao'] == "60-75")]
dfm_Eating_ocsvm_8095 = dfm_Eating_ocsvm[(dfm_Eating_ocsvm['variacao'] == "80-95")]
dfm_Eating_ocsvm_2095 = dfm_Eating_ocsvm[(dfm_Eating_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_eat_oc.svg')

# %%
dfm_Eating_ocsvm_2035.head(10)
dfm_Eating_ocsvm_4055.head(10)
dfm_Eating_ocsvm_6075.head(10)
dfm_Eating_ocsvm_8095.head(10)
# dfm_Eating_ocsvm_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 512  11   2   1  14  0.464286  0.916667       0.440000  0.594595     ocsvm
# 513  11   9   1   7  0.714286  0.916667       0.611111  0.733333     ocsvm
# 514  11  12   1   4  0.821429  0.916667       0.733333  0.814815     ocsvm
# 515  11  12   1   4  0.821429  0.916667       0.733333  0.814815     ocsvm
# 516  11  13   1   3  0.857143  0.916667       0.785714  0.846154     ocsvm
# 517  11  12   1   4  0.821429  0.916667       0.733333  0.814815     ocsvm
# 518  11  13   1   3  0.857143  0.916667       0.785714  0.846154     ocsvm
# 519  11  13   1   3  0.857143  0.916667       0.785714  0.846154     ocsvm
#
#     variacao atividade  semana
# 512    80-95    Eating       1
# 513    80-95    Eating       2
# 514    80-95    Eating       3
# 515    80-95    Eating       4
# 516    80-95    Eating       5
# 517    80-95    Eating       6
# 518    80-95    Eating       7
# 519    80-95    Eating       8

# %%
#Eating  rce
dfm_Eating_rce_2035 = dfm_Eating_rce[(dfm_Eating_rce['variacao'] == "20-35")]
dfm_Eating_rce_4055 = dfm_Eating_rce[(dfm_Eating_rce['variacao'] == "40-55")]
dfm_Eating_rce_6075 = dfm_Eating_rce[(dfm_Eating_rce['variacao'] == "60-75")]
dfm_Eating_rce_8095 = dfm_Eating_rce[(dfm_Eating_rce['variacao'] == "80-95")]
dfm_Eating_rce_2095 = dfm_Eating_rce[(dfm_Eating_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Eating_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_eat_rce.svg')

# %%
dfm_Eating_rce_2035.head(10)
dfm_Eating_rce_4055.head(10)
dfm_Eating_rce_6075.head(10)
dfm_Eating_rce_8095.head(10)
dfm_Eating_rce_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 696  11   9   1   7  0.714286  0.916667       0.611111  0.733333       rce
# 697  11  13   1   3  0.857143  0.916667       0.785714  0.846154       rce
# 698  12  15   0   1  0.964286  1.000000       0.923077  0.960000       rce
# 699  12  14   0   2  0.928571  1.000000       0.857143  0.923077       rce
# 700  12  15   0   1  0.964286  1.000000       0.923077  0.960000       rce
# 701  12  14   0   2  0.928571  1.000000       0.857143  0.923077       rce
# 702  12  15   0   1  0.964286  1.000000       0.923077  0.960000       rce
# 703  12  16   0   0  1.000000  1.000000       1.000000  1.000000       rce
#
#     variacao atividade  semana
# 696    20-95    Eating       1
# 697    20-95    Eating       2
# 698    20-95    Eating       3
# 699    20-95    Eating       4
# 700    20-95    Eating       5
# 701    20-95    Eating       6
# 702    20-95    Eating       7
# 703    20-95    Eating       8

# %%
#Relax  LOF
dfm_Relax_lof_2035 = dfm_Relax_lof[(dfm_Relax_lof['variacao'] == "20-35")]
dfm_Relax_lof_4055 = dfm_Relax_lof[(dfm_Relax_lof['variacao'] == "40-55")]
dfm_Relax_lof_6075 = dfm_Relax_lof[(dfm_Relax_lof['variacao'] == "60-75")]
dfm_Relax_lof_8095 = dfm_Relax_lof[(dfm_Relax_lof['variacao'] == "80-95")]
dfm_Relax_lof_2095 = dfm_Relax_lof[(dfm_Relax_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_rlx_lof.svg')

# %%
dfm_Relax_lof_2035.head(10)
dfm_Relax_lof_4055.head(10)
dfm_Relax_lof_6075.head(10)
dfm_Relax_lof_8095.head(10)
dfm_Relax_lof_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 744   7  16   4   1  0.821429  0.636364       0.875000  0.736842       lof
# 745  10  14   1   3  0.857143  0.909091       0.769231  0.833333       lof
# 746  10  16   1   1  0.928571  0.909091       0.909091  0.909091       lof
# 747  10  16   1   1  0.928571  0.909091       0.909091  0.909091       lof
# 748  10  16   1   1  0.928571  0.909091       0.909091  0.909091       lof
# 749  10  16   1   1  0.928571  0.909091       0.909091  0.909091       lof
# 750  10  13   1   4  0.821429  0.909091       0.714286  0.800000       lof
# 751  10  13   1   4  0.821429  0.909091       0.714286  0.800000       lof
#
#     variacao atividade  semana
# 744    20-95     Relax       1
# 745    20-95     Relax       2
# 746    20-95     Relax       3
# 747    20-95     Relax       4
# 748    20-95     Relax       5
# 749    20-95     Relax       6
# 750    20-95     Relax       7
# 751    20-95     Relax       8

# %%
#Relax  if
dfm_Relax_if_2035 = dfm_Relax_if[(dfm_Relax_if['variacao'] == "20-35")]
dfm_Relax_if_4055 = dfm_Relax_if[(dfm_Relax_if['variacao'] == "40-55")]
dfm_Relax_if_6075 = dfm_Relax_if[(dfm_Relax_if['variacao'] == "60-75")]
dfm_Relax_if_8095 = dfm_Relax_if[(dfm_Relax_if['variacao'] == "80-95")]
dfm_Relax_if_2095 = dfm_Relax_if[(dfm_Relax_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_rlx_if.svg')

# %%
dfm_Relax_if_2035.head(10)
dfm_Relax_if_4055.head(10)
dfm_Relax_if_6075.head(10)
#dfm_Relax_if_8095.head(10)
# dfm_Relax_if_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 432   0  15  13   0  0.535714       0.0       0.000000  0.000000   iforest
# 433  13   9   0   6  0.785714       1.0       0.684211  0.812500   iforest
# 434  13  10   0   5  0.821429       1.0       0.722222  0.838710   iforest
# 435  13   9   0   6  0.785714       1.0       0.684211  0.812500   iforest
# 436  13   9   0   6  0.785714       1.0       0.684211  0.812500   iforest
# 437  13   9   0   6  0.785714       1.0       0.684211  0.812500   iforest
# 438  13   9   0   6  0.785714       1.0       0.684211  0.812500   iforest
# 439  13   8   0   7  0.750000       1.0       0.650000  0.787879   iforest
#
#     variacao atividade  semana
# 432    60-75     Relax       1
# 433    60-75     Relax       2
# 434    60-75     Relax       3
# 435    60-75     Relax       4
# 436    60-75     Relax       5
# 437    60-75     Relax       6
# 438    60-75     Relax       7
# 439    60-75     Relax       8

# %%
#Relax  ocsvm
dfm_Relax_ocsvm_2035 = dfm_Relax_ocsvm[(dfm_Relax_ocsvm['variacao'] == "20-35")]
dfm_Relax_ocsvm_4055 = dfm_Relax_ocsvm[(dfm_Relax_ocsvm['variacao'] == "40-55")]
dfm_Relax_ocsvm_6075 = dfm_Relax_ocsvm[(dfm_Relax_ocsvm['variacao'] == "60-75")]
dfm_Relax_ocsvm_8095 = dfm_Relax_ocsvm[(dfm_Relax_ocsvm['variacao'] == "80-95")]
dfm_Relax_ocsvm_2095 = dfm_Relax_ocsvm[(dfm_Relax_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_rlx_oc.svg')

# %%
dfm_Relax_ocsvm_2035.head(10)
dfm_Relax_ocsvm_4055.head(10)
dfm_Relax_ocsvm_6075.head(10)
# dfm_Relax_ocsvm_8095.head(10)
# dfm_Relax_ocsvm_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 416  13   1   0  14  0.500000       1.0       0.481481  0.650000     ocsvm
# 417  13   7   0   8  0.714286       1.0       0.619048  0.764706     ocsvm
# 418  13   9   0   6  0.785714       1.0       0.684211  0.812500     ocsvm
# 419  13  10   0   5  0.821429       1.0       0.722222  0.838710     ocsvm
# 420  13  10   0   5  0.821429       1.0       0.722222  0.838710     ocsvm
# 421  13  11   0   4  0.857143       1.0       0.764706  0.866667     ocsvm
# 422  13  11   0   4  0.857143       1.0       0.764706  0.866667     ocsvm
# 423  13  11   0   4  0.857143       1.0       0.764706  0.866667     ocsvm
#
#     variacao atividade  semana
# 416    60-75     Relax       1
# 417    60-75     Relax       2
# 418    60-75     Relax       3
# 419    60-75     Relax       4
# 420    60-75     Relax       5
# 421    60-75     Relax       6
# 422    60-75     Relax       7
# 423    60-75     Relax       8

# %%
#Relax  rce
dfm_Relax_rce_2035 = dfm_Relax_rce[(dfm_Relax_rce['variacao'] == "20-35")]
dfm_Relax_rce_4055 = dfm_Relax_rce[(dfm_Relax_rce['variacao'] == "40-55")]
dfm_Relax_rce_6075 = dfm_Relax_rce[(dfm_Relax_rce['variacao'] == "60-75")]
dfm_Relax_rce_8095 = dfm_Relax_rce[(dfm_Relax_rce['variacao'] == "80-95")]
dfm_Relax_rce_2095 = dfm_Relax_rce[(dfm_Relax_rce['variacao'] == "20-95")]


#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Relax_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_rlx_rce.svg')

# %%
dfm_Relax_rce_2035.head(10)
dfm_Relax_rce_4055.head(10)
dfm_Relax_rce_6075.head(10)
# dfm_Relax_rce_8095.head(10)
# dfm_Relax_rce_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 440  13   1   0  14  0.500000       1.0       0.481481  0.650000       rce
# 441  13   8   0   7  0.750000       1.0       0.650000  0.787879       rce
# 442  13  10   0   5  0.821429       1.0       0.722222  0.838710       rce
# 443  13  10   0   5  0.821429       1.0       0.722222  0.838710       rce
# 444  13  10   0   5  0.821429       1.0       0.722222  0.838710       rce
# 445  13  10   0   5  0.821429       1.0       0.722222  0.838710       rce
# 446  13  10   0   5  0.821429       1.0       0.722222  0.838710       rce
# 447  13  10   0   5  0.821429       1.0       0.722222  0.838710       rce
#
#     variacao atividade  semana
# 440    60-75     Relax       1
# 441    60-75     Relax       2
# 442    60-75     Relax       3
# 443    60-75     Relax       4
# 444    60-75     Relax       5
# 445    60-75     Relax       6
# 446    60-75     Relax       7
# 447    60-75     Relax       8

# %%
#Sleeping  LOF
dfm_Sleeping_lof_2035 = dfm_Sleeping_lof[(dfm_Sleeping_lof['variacao'] == "20-35")]
dfm_Sleeping_lof_4055 = dfm_Sleeping_lof[(dfm_Sleeping_lof['variacao'] == "40-55")]
dfm_Sleeping_lof_6075 = dfm_Sleeping_lof[(dfm_Sleeping_lof['variacao'] == "60-75")]
dfm_Sleeping_lof_8095 = dfm_Sleeping_lof[(dfm_Sleeping_lof['variacao'] == "80-95")]
dfm_Sleeping_lof_2095 = dfm_Sleeping_lof[(dfm_Sleeping_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_slp_lof.svg')

# %%
dfm_Sleeping_lof_2035.head(10)
dfm_Sleeping_lof_4055.head(10)
dfm_Sleeping_lof_6075.head(10)
dfm_Sleeping_lof_8095.head(10)
dfm_Sleeping_lof_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 776   1  16  10   1  0.607143  0.090909       0.500000  0.153846       lof
# 777  10  16   1   1  0.928571  0.909091       0.909091  0.909091       lof
# 778  11  16   0   1  0.964286  1.000000       0.916667  0.956522       lof
# 779  11  16   0   1  0.964286  1.000000       0.916667  0.956522       lof
# 780  11  15   0   2  0.928571  1.000000       0.846154  0.916667       lof
# 781  11  15   0   2  0.928571  1.000000       0.846154  0.916667       lof
# 782  11  13   0   4  0.857143  1.000000       0.733333  0.846154       lof
# 783  11  14   0   3  0.892857  1.000000       0.785714  0.880000       lof
#
#     variacao atividade  semana
# 776    20-95  Sleeping       1
# 777    20-95  Sleeping       2
# 778    20-95  Sleeping       3
# 779    20-95  Sleeping       4
# 780    20-95  Sleeping       5
# 781    20-95  Sleeping       6
# 782    20-95  Sleeping       7
# 783    20-95  Sleeping       8

# %%
#Sleeping  if
dfm_Sleeping_if_2035 = dfm_Sleeping_if[(dfm_Sleeping_if['variacao'] == "20-35")]
dfm_Sleeping_if_4055 = dfm_Sleeping_if[(dfm_Sleeping_if['variacao'] == "40-55")]
dfm_Sleeping_if_6075 = dfm_Sleeping_if[(dfm_Sleeping_if['variacao'] == "60-75")]
dfm_Sleeping_if_8095 = dfm_Sleeping_if[(dfm_Sleeping_if['variacao'] == "80-95")]
dfm_Sleeping_if_2095 = dfm_Sleeping_if[(dfm_Sleeping_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_slp_if.svg')

# %%
dfm_Sleeping_if_2035.head(10)
dfm_Sleeping_if_4055.head(10)
dfm_Sleeping_if_6075.head(10)
# dfm_Sleeping_if_8095.head(10)
# dfm_Sleeping_if_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 464   7  11   6   4  0.642857  0.538462       0.636364  0.583333   iforest
# 465   9  11   4   4  0.714286  0.692308       0.692308  0.692308   iforest
# 466   9  14   4   1  0.821429  0.692308       0.900000  0.782609   iforest
# 467  10  14   3   1  0.857143  0.769231       0.909091  0.833333   iforest
# 468  10  14   3   1  0.857143  0.769231       0.909091  0.833333   iforest
# 469  10  14   3   1  0.857143  0.769231       0.909091  0.833333   iforest
# 470  10  13   3   2  0.821429  0.769231       0.833333  0.800000   iforest
# 471  11  13   2   2  0.857143  0.846154       0.846154  0.846154   iforest
#
#     variacao atividade  semana
# 464    60-75  Sleeping       1
# 465    60-75  Sleeping       2
# 466    60-75  Sleeping       3
# 467    60-75  Sleeping       4
# 468    60-75  Sleeping       5
# 469    60-75  Sleeping       6
# 470    60-75  Sleeping       7
# 471    60-75  Sleeping       8

# %%
#Sleeping  ocsvm
dfm_Sleeping_ocsvm_2035 = dfm_Sleeping_ocsvm[(dfm_Sleeping_ocsvm['variacao'] == "20-35")]
dfm_Sleeping_ocsvm_4055 = dfm_Sleeping_ocsvm[(dfm_Sleeping_ocsvm['variacao'] == "40-55")]
dfm_Sleeping_ocsvm_6075 = dfm_Sleeping_ocsvm[(dfm_Sleeping_ocsvm['variacao'] == "60-75")]
dfm_Sleeping_ocsvm_8095 = dfm_Sleeping_ocsvm[(dfm_Sleeping_ocsvm['variacao'] == "80-95")]
dfm_Sleeping_ocsvm_2095 = dfm_Sleeping_ocsvm[(dfm_Sleeping_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_slp_oc.svg')

# %%
dfm_Sleeping_ocsvm_2035.head(10)
dfm_Sleeping_ocsvm_4055.head(10)
dfm_Sleeping_ocsvm_6075.head(10)
dfm_Sleeping_ocsvm_8095.head(10)
# dfm_Sleeping_ocsvm_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 608  12   9   0   7  0.750000  1.000000       0.631579  0.774194     ocsvm
# 609  11  11   1   5  0.785714  0.916667       0.687500  0.785714     ocsvm
# 610  12  14   0   2  0.928571  1.000000       0.857143  0.923077     ocsvm
# 611  12  14   0   2  0.928571  1.000000       0.857143  0.923077     ocsvm
# 612  12  13   0   3  0.892857  1.000000       0.800000  0.888889     ocsvm
# 613  12  13   0   3  0.892857  1.000000       0.800000  0.888889     ocsvm
# 614  12  14   0   2  0.928571  1.000000       0.857143  0.923077     ocsvm
# 615  12  14   0   2  0.928571  1.000000       0.857143  0.923077     ocsvm
#
#     variacao atividade  semana
# 608    80-95  Sleeping       1
# 609    80-95  Sleeping       2
# 610    80-95  Sleeping       3
# 611    80-95  Sleeping       4
# 612    80-95  Sleeping       5
# 613    80-95  Sleeping       6
# 614    80-95  Sleeping       7
# 615    80-95  Sleeping       8

# %%
#Sleeping  rce
dfm_Sleeping_rce_2035 = dfm_Sleeping_rce[(dfm_Sleeping_rce['variacao'] == "20-35")]
dfm_Sleeping_rce_4055 = dfm_Sleeping_rce[(dfm_Sleeping_rce['variacao'] == "40-55")]
dfm_Sleeping_rce_6075 = dfm_Sleeping_rce[(dfm_Sleeping_rce['variacao'] == "60-75")]
dfm_Sleeping_rce_8095 = dfm_Sleeping_rce[(dfm_Sleeping_rce['variacao'] == "80-95")]
dfm_Sleeping_rce_2095 = dfm_Sleeping_rce[(dfm_Sleeping_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_Sleeping_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ar_slp_rce.svg')

# %%
dfm_Sleeping_rce_2035.head(10)
dfm_Sleeping_rce_4055.head(10)
dfm_Sleeping_rce_6075.head(10)
dfm_Sleeping_rce_8095.head(10)
dfm_Sleeping_rce_2095.head(10)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 792  11  15   0   2  0.928571  1.000000       0.846154  0.916667       rce
# 793  11  15   0   2  0.928571  1.000000       0.846154  0.916667       rce
# 794   9  16   2   1  0.892857  0.818182       0.900000  0.857143       rce
# 795  11  16   0   1  0.964286  1.000000       0.916667  0.956522       rce
# 796  11  15   0   2  0.928571  1.000000       0.846154  0.916667       rce
# 797  11  15   0   2  0.928571  1.000000       0.846154  0.916667       rce
# 798  11  14   0   3  0.892857  1.000000       0.785714  0.880000       rce
# 799  11  14   0   3  0.892857  1.000000       0.785714  0.880000       rce
#
#     variacao atividade  semana
# 792    20-95  Sleeping       1
# 793    20-95  Sleeping       2
# 794    20-95  Sleeping       3
# 795    20-95  Sleeping       4
# 796    20-95  Sleeping       5
# 797    20-95  Sleeping       6
# 798    20-95  Sleeping       7
# 799    20-95  Sleeping       8
