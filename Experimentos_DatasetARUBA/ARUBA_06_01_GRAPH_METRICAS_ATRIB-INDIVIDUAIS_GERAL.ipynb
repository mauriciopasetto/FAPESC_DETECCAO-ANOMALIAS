# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Importando dataset metricas para 9 atividades

# %%
#METRICAS LOF

# %%
## importando dataset
df_lof_dur2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-duracao-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur2035.shape)
df_lof_dur2035.head()

df_lof_dur4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-duracao-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur4055.shape)
df_lof_dur4055.head()

df_lof_dur6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-duracao-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur6075.shape)
df_lof_dur6075.head()

df_lof_dur8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-duracao-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur8095.shape)
df_lof_dur8095.head()

df_lof_dur2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-duracao-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur2095.shape)
df_lof_dur2095.head()

df_lof_dur_geral = pd.concat([df_lof_dur2035, df_lof_dur4055,df_lof_dur6075,df_lof_dur8095,df_lof_dur2095],ignore_index=True)
print(df_lof_dur_geral.shape)
df_lof_dur_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   1  14  13   0  0.535714  0.071429           1.00
# 1        2    20-35   3  13  11   1  0.571429  0.214286           0.75
# 2        3    20-35   3  13  11   1  0.571429  0.214286           0.75
# 3        4    20-35   3  13  11   1  0.571429  0.214286           0.75
# 4        5    20-35   3  13  11   1  0.571429  0.214286           0.75
#
#     f1score algoritmo variavel
# 0  0.133333       lof  duracao
# 1  0.333333       lof  duracao
# 2  0.333333       lof  duracao
# 3  0.333333       lof  duracao
# 4  0.333333       lof  duracao

# %%
df_lof_dur2035.head(10)
df_lof_dur4055.head(10)
df_lof_dur6075.head(10)
df_lof_dur8095.head(10)
df_lof_dur2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95   3  14  11   0  0.607143  0.214286       1.000000
# 1        2    20-95   7  13   7   1  0.714286  0.500000       0.875000
# 2        3    20-95   7  13   7   1  0.714286  0.500000       0.875000
# 3        4    20-95   6  13   8   1  0.678571  0.428571       0.857143
# 4        5    20-95   5  13   9   1  0.642857  0.357143       0.833333
# 5        6    20-95   5  13   9   1  0.642857  0.357143       0.833333
# 6        7    20-95   5  13   9   1  0.642857  0.357143       0.833333
# 7        8    20-95   5  13   9   1  0.642857  0.357143       0.833333
#
#     f1score algoritmo variavel
# 0  0.352941       lof  duracao
# 1  0.636364       lof  duracao
# 2  0.636364       lof  duracao
# 3  0.571429       lof  duracao
# 4  0.500000       lof  duracao
# 5  0.500000       lof  duracao
# 6  0.500000       lof  duracao
# 7  0.500000       lof  duracao

# %%
## importando dataset
df_lof_freq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-frequencia-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq2035.shape)
df_lof_freq2035.head()

df_lof_freq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-frequencia-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq4055.shape)
df_lof_freq4055.head()

df_lof_freq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-frequencia-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq6075.shape)
df_lof_freq6075.head()

df_lof_freq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-frequencia-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq8095.shape)
df_lof_freq8095.head()

df_lof_freq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-frequencia-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq2095.shape)
df_lof_freq2095.head()

df_lof_freq_geral = pd.concat([df_lof_freq2035, df_lof_freq4055,df_lof_freq6075,df_lof_freq8095,df_lof_freq2095],ignore_index=True)
print(df_lof_freq_geral.shape)
df_lof_freq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   0  14  14   0  0.500000  0.000000            0.0
# 1        2    20-35   0  14  14   0  0.500000  0.000000            0.0
# 2        3    20-35   0  14  14   0  0.500000  0.000000            0.0
# 3        4    20-35   1  14  13   0  0.535714  0.071429            1.0
# 4        5    20-35   1  14  13   0  0.535714  0.071429            1.0
#
#     f1score algoritmo    variavel
# 0  0.000000       lof  frequencia
# 1  0.000000       lof  frequencia
# 2  0.000000       lof  frequencia
# 3  0.133333       lof  frequencia
# 4  0.133333       lof  frequencia

# %%
df_lof_freq2035.head(10)
df_lof_freq4055.head(10)
df_lof_freq6075.head(10)
df_lof_freq8095.head(10)
df_lof_freq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  12  14   2   0  0.928571  0.857143            1.0
# 1        2    20-95  13  14   1   0  0.964286  0.928571            1.0
# 2        3    20-95  14  14   0   0  1.000000  1.000000            1.0
# 3        4    20-95  14  14   0   0  1.000000  1.000000            1.0
# 4        5    20-95  14  14   0   0  1.000000  1.000000            1.0
# 5        6    20-95  14  14   0   0  1.000000  1.000000            1.0
# 6        7    20-95  14  14   0   0  1.000000  1.000000            1.0
# 7        8    20-95  14  14   0   0  1.000000  1.000000            1.0
#
#     f1score algoritmo    variavel
# 0  0.923077       lof  frequencia
# 1  0.962963       lof  frequencia
# 2  1.000000       lof  frequencia
# 3  1.000000       lof  frequencia
# 4  1.000000       lof  frequencia
# 5  1.000000       lof  frequencia
# 6  1.000000       lof  frequencia
# 7  1.000000       lof  frequencia

# %%
## importando dataset
df_lof_dfreq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-dfreq-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq2035.shape)
df_lof_dfreq2035.head()

df_lof_dfreq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-dfreq-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq4055.shape)
df_lof_dfreq4055.head()

df_lof_dfreq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-dfreq-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq6075.shape)
df_lof_dfreq6075.head()

df_lof_dfreq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-dfreq-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq8095.shape)
df_lof_dfreq8095.head()

df_lof_dfreq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-lof-dfreq-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq2095.shape)
df_lof_dfreq2095.head()

df_lof_dfreq_geral = pd.concat([df_lof_dfreq2035, df_lof_dfreq4055,df_lof_dfreq6075,df_lof_dfreq8095,df_lof_dfreq2095],ignore_index=True)
print(df_lof_dfreq_geral.shape)
df_lof_dfreq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  10  12   4   2  0.785714  0.714286       0.833333
# 1        2    20-35   9  13   5   1  0.785714  0.642857       0.900000
# 2        3    20-35   9  14   5   0  0.821429  0.642857       1.000000
# 3        4    20-35  10  13   4   1  0.821429  0.714286       0.909091
# 4        5    20-35  10  12   4   2  0.785714  0.714286       0.833333
#
#     f1score algoritmo variavel
# 0  0.769231       lof    dfreq
# 1  0.750000       lof    dfreq
# 2  0.782609       lof    dfreq
# 3  0.800000       lof    dfreq
# 4  0.769231       lof    dfreq

# %%
df_lof_dfreq2035.head(10)
df_lof_dfreq4055.head(10)
df_lof_dfreq6075.head(10)
df_lof_dfreq8095.head(10)
df_lof_dfreq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  14  12   0   2  0.928571  1.000000       0.875000
# 1        2    20-95  10  13   4   1  0.821429  0.714286       0.909091
# 2        3    20-95   9  14   5   0  0.821429  0.642857       1.000000
# 3        4    20-95  13  13   1   1  0.928571  0.928571       0.928571
# 4        5    20-95  14  12   0   2  0.928571  1.000000       0.875000
# 5        6    20-95  14  13   0   1  0.964286  1.000000       0.933333
# 6        7    20-95  14  12   0   2  0.928571  1.000000       0.875000
# 7        8    20-95  14  11   0   3  0.892857  1.000000       0.823529
#
#     f1score algoritmo variavel
# 0  0.933333       lof    dfreq
# 1  0.800000       lof    dfreq
# 2  0.782609       lof    dfreq
# 3  0.928571       lof    dfreq
# 4  0.933333       lof    dfreq
# 5  0.965517       lof    dfreq
# 6  0.933333       lof    dfreq
# 7  0.903226       lof    dfreq

# %%
#METRICAS iFOREST

# %%
## importando dataset
df_if_dur2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-duracao-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur2035.shape)
df_if_dur2035.head()

df_if_dur4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-duracao-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur4055.shape)
df_if_dur4055.head()

df_if_dur6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-duracao-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur6075.shape)
df_if_dur6075.head()

df_if_dur8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-duracao-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur8095.shape)
df_if_dur8095.head()

df_if_dur2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-duracao-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur2095.shape)
df_if_dur2095.head()

df_if_dur_geral = pd.concat([df_if_dur2035, df_if_dur4055,df_if_dur6075,df_if_dur8095,df_if_dur2095],ignore_index=True)
print(df_if_dur_geral.shape)
df_if_dur_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   4  10  10   4  0.500000  0.285714       0.500000
# 1        2    20-35   3  10  11   4  0.464286  0.214286       0.428571
# 2        3    20-35   6  13   8   1  0.678571  0.428571       0.857143
# 3        4    20-35   7  13   7   1  0.714286  0.500000       0.875000
# 4        5    20-35   5  13   9   1  0.642857  0.357143       0.833333
#
#     f1score algoritmo variavel
# 0  0.363636   iforest  duracao
# 1  0.285714   iforest  duracao
# 2  0.571429   iforest  duracao
# 3  0.636364   iforest  duracao
# 4  0.500000   iforest  duracao

# %%
df_if_dur2035.head(10)
df_if_dur4055.head(10)
df_if_dur6075.head(10)
df_if_dur8095.head(10)
df_if_dur2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95   5  10   9   4  0.535714  0.357143       0.555556
# 1        2    20-95   4  10  10   4  0.500000  0.285714       0.500000
# 2        3    20-95   4  13  10   1  0.607143  0.285714       0.800000
# 3        4    20-95   6  13   8   1  0.678571  0.428571       0.857143
# 4        5    20-95   2  13  12   1  0.535714  0.142857       0.666667
# 5        6    20-95   2  14  12   0  0.571429  0.142857       1.000000
# 6        7    20-95   4  13  10   1  0.607143  0.285714       0.800000
# 7        8    20-95   3  13  11   1  0.571429  0.214286       0.750000
#
#     f1score algoritmo variavel
# 0  0.434783   iforest  duracao
# 1  0.363636   iforest  duracao
# 2  0.421053   iforest  duracao
# 3  0.571429   iforest  duracao
# 4  0.235294   iforest  duracao
# 5  0.250000   iforest  duracao
# 6  0.421053   iforest  duracao
# 7  0.333333   iforest  duracao

# %%
## importando dataset
df_if_freq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-frequencia-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq2035.shape)
df_if_freq2035.head()

df_if_freq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-frequencia-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq4055.shape)
df_if_freq4055.head()

df_if_freq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-frequencia-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq6075.shape)
df_if_freq6075.head()

df_if_freq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-frequencia-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq8095.shape)
df_if_freq8095.head()

df_if_freq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-frequencia-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq2095.shape)
df_if_freq2095.head()

df_if_freq_geral = pd.concat([df_if_freq2035, df_if_freq4055,df_if_freq6075,df_if_freq8095,df_if_freq2095],ignore_index=True)
print(df_if_freq_geral.shape)
df_if_freq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   2  13  12   1  0.535714  0.142857       0.666667
# 1        2    20-35   1  14  13   0  0.535714  0.071429       1.000000
# 2        3    20-35   1  13  13   1  0.500000  0.071429       0.500000
# 3        4    20-35   0  14  14   0  0.500000  0.000000       0.000000
# 4        5    20-35   1  14  13   0  0.535714  0.071429       1.000000
#
#     f1score algoritmo    variavel
# 0  0.235294   iforest  frequencia
# 1  0.133333   iforest  frequencia
# 2  0.125000   iforest  frequencia
# 3  0.000000   iforest  frequencia
# 4  0.133333   iforest  frequencia

# %%
df_if_freq2035.head(10)
df_if_freq4055.head(10)
df_if_freq6075.head(10)
df_if_freq8095.head(10)
df_if_freq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95   3  13  11   1  0.571429  0.214286       0.750000
# 1        2    20-95   8  14   6   0  0.785714  0.571429       1.000000
# 2        3    20-95  10  13   4   1  0.821429  0.714286       0.909091
# 3        4    20-95   6  14   8   0  0.714286  0.428571       1.000000
# 4        5    20-95   9  14   5   0  0.821429  0.642857       1.000000
# 5        6    20-95  10  13   4   1  0.821429  0.714286       0.909091
# 6        7    20-95  10  13   4   1  0.821429  0.714286       0.909091
# 7        8    20-95  11  13   3   1  0.857143  0.785714       0.916667
#
#     f1score algoritmo    variavel
# 0  0.333333   iforest  frequencia
# 1  0.727273   iforest  frequencia
# 2  0.800000   iforest  frequencia
# 3  0.600000   iforest  frequencia
# 4  0.782609   iforest  frequencia
# 5  0.800000   iforest  frequencia
# 6  0.800000   iforest  frequencia
# 7  0.846154   iforest  frequencia

# %%
## importando dataset
df_if_dfreq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-dfreq-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq2035.shape)
df_if_dfreq2035.head()

df_if_dfreq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-dfreq-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq4055.shape)
df_if_dfreq4055.head()

df_if_dfreq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-dfreq-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq6075.shape)
df_if_dfreq6075.head()

df_if_dfreq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-dfreq-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq8095.shape)
df_if_dfreq8095.head()

df_if_dfreq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-iforest-dfreq-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq2095.shape)
df_if_dfreq2095.head()

df_if_dfreq_geral = pd.concat([df_if_dfreq2035, df_if_dfreq4055,df_if_dfreq6075,df_if_dfreq8095,df_if_dfreq2095],ignore_index=True)
print(df_if_dfreq_geral.shape)
df_if_dfreq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   7   7   7   7  0.500000  0.500000       0.500000
# 1        2    20-35   3  11  11   3  0.500000  0.214286       0.500000
# 2        3    20-35   5  12   9   2  0.607143  0.357143       0.714286
# 3        4    20-35   6  14   8   0  0.714286  0.428571       1.000000
# 4        5    20-35   5  13   9   1  0.642857  0.357143       0.833333
#
#    f1score algoritmo variavel
# 0  0.50000   iforest    dfreq
# 1  0.30000   iforest    dfreq
# 2  0.47619   iforest    dfreq
# 3  0.60000   iforest    dfreq
# 4  0.50000   iforest    dfreq

# %%
df_if_dfreq2035.head(10)
df_if_dfreq4055.head(10)
df_if_dfreq6075.head(10)
df_if_dfreq8095.head(10)
df_if_dfreq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  10   7   4   7  0.607143  0.714286       0.588235
# 1        2    20-95   7  11   7   3  0.642857  0.500000       0.700000
# 2        3    20-95   8  12   6   2  0.714286  0.571429       0.800000
# 3        4    20-95   8  14   6   0  0.785714  0.571429       1.000000
# 4        5    20-95   8  13   6   1  0.750000  0.571429       0.888889
# 5        6    20-95   8  13   6   1  0.750000  0.571429       0.888889
# 6        7    20-95   8  13   6   1  0.750000  0.571429       0.888889
# 7        8    20-95   8  13   6   1  0.750000  0.571429       0.888889
#
#     f1score algoritmo variavel
# 0  0.645161   iforest    dfreq
# 1  0.583333   iforest    dfreq
# 2  0.666667   iforest    dfreq
# 3  0.727273   iforest    dfreq
# 4  0.695652   iforest    dfreq
# 5  0.695652   iforest    dfreq
# 6  0.695652   iforest    dfreq
# 7  0.695652   iforest    dfreq

# %%
#METRICAS OCSVM

# %%
## importando dataset
df_ocsvm_dur2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-duracao-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur2035.shape)
df_ocsvm_dur2035.head()

df_ocsvm_dur4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-duracao-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur4055.shape)
df_ocsvm_dur4055.head()

df_ocsvm_dur6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-duracao-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur6075.shape)
df_ocsvm_dur6075.head()

df_ocsvm_dur8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-duracao-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur8095.shape)
df_ocsvm_dur8095.head()

df_ocsvm_dur2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-duracao-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur2095.shape)
df_ocsvm_dur2095.head()

df_ocsvm_dur_geral = pd.concat([df_ocsvm_dur2035, df_ocsvm_dur4055,df_ocsvm_dur6075,df_ocsvm_dur8095,df_ocsvm_dur2095],ignore_index=True)
print(df_ocsvm_dur_geral.shape)
df_ocsvm_dur_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  14   0   0  14  0.500000  1.000000       0.500000
# 1        2    20-35  14   1   0  13  0.535714  1.000000       0.518519
# 2        3    20-35  12   3   2  11  0.535714  0.857143       0.521739
# 3        4    20-35  12   3   2  11  0.535714  0.857143       0.521739
# 4        5    20-35  12   4   2  10  0.571429  0.857143       0.545455
#
#     f1score algoritmo variavel
# 0  0.666667     ocsvm  duracao
# 1  0.682927     ocsvm  duracao
# 2  0.648649     ocsvm  duracao
# 3  0.648649     ocsvm  duracao
# 4  0.666667     ocsvm  duracao

# %%
df_ocsvm_dur2035.head(10)
df_ocsvm_dur4055.head(10)
df_ocsvm_dur6075.head(10)
df_ocsvm_dur8095.head(10)
df_ocsvm_dur2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  13   0   1  14  0.464286  0.928571       0.481481
# 1        2    20-95  13   1   1  13  0.500000  0.928571       0.500000
# 2        3    20-95  12   3   2  11  0.535714  0.857143       0.521739
# 3        4    20-95  12   3   2  11  0.535714  0.857143       0.521739
# 4        5    20-95  12   4   2  10  0.571429  0.857143       0.545455
# 5        6    20-95  12   5   2   9  0.607143  0.857143       0.571429
# 6        7    20-95  12   5   2   9  0.607143  0.857143       0.571429
# 7        8    20-95  12   5   2   9  0.607143  0.857143       0.571429
#
#     f1score algoritmo variavel
# 0  0.634146     ocsvm  duracao
# 1  0.650000     ocsvm  duracao
# 2  0.648649     ocsvm  duracao
# 3  0.648649     ocsvm  duracao
# 4  0.666667     ocsvm  duracao
# 5  0.685714     ocsvm  duracao
# 6  0.685714     ocsvm  duracao
# 7  0.685714     ocsvm  duracao

# %%
## importando dataset
df_ocsvm_freq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-frequencia-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq2035.shape)
df_ocsvm_freq2035.head()

df_ocsvm_freq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-frequencia-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq4055.shape)
df_ocsvm_freq4055.head()

df_ocsvm_freq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-frequencia-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq6075.shape)
df_ocsvm_freq6075.head()

df_ocsvm_freq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-frequencia-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq8095.shape)
df_ocsvm_freq8095.head()

df_ocsvm_freq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-frequencia-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq2095.shape)
df_ocsvm_freq2095.head()

df_ocsvm_freq_geral = pd.concat([df_ocsvm_freq2035, df_ocsvm_freq4055,df_ocsvm_freq6075,df_ocsvm_freq8095,df_ocsvm_freq2095],ignore_index=True)
print(df_ocsvm_freq_geral.shape)
df_ocsvm_freq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  14   3   0  11  0.607143  1.000000       0.560000
# 1        2    20-35  12   5   2   9  0.607143  0.857143       0.571429
# 2        3    20-35  12   7   2   7  0.678571  0.857143       0.631579
# 3        4    20-35  12   7   2   7  0.678571  0.857143       0.631579
# 4        5    20-35  11   7   3   7  0.642857  0.785714       0.611111
#
#     f1score algoritmo    variavel
# 0  0.717949     ocsvm  frequencia
# 1  0.685714     ocsvm  frequencia
# 2  0.727273     ocsvm  frequencia
# 3  0.727273     ocsvm  frequencia
# 4  0.687500     ocsvm  frequencia

# %%
df_ocsvm_freq2035.head(10)
df_ocsvm_freq4055.head(10)
df_ocsvm_freq6075.head(10)
df_ocsvm_freq8095.head(10)
df_ocsvm_freq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  14   3   0  11  0.607143       1.0       0.560000
# 1        2    20-95  14   5   0   9  0.678571       1.0       0.608696
# 2        3    20-95  14   7   0   7  0.750000       1.0       0.666667
# 3        4    20-95  14   7   0   7  0.750000       1.0       0.666667
# 4        5    20-95  14   7   0   7  0.750000       1.0       0.666667
# 5        6    20-95  14   7   0   7  0.750000       1.0       0.666667
# 6        7    20-95  14   8   0   6  0.785714       1.0       0.700000
# 7        8    20-95  14   8   0   6  0.785714       1.0       0.700000
#
#     f1score algoritmo    variavel
# 0  0.717949     ocsvm  frequencia
# 1  0.756757     ocsvm  frequencia
# 2  0.800000     ocsvm  frequencia
# 3  0.800000     ocsvm  frequencia
# 4  0.800000     ocsvm  frequencia
# 5  0.800000     ocsvm  frequencia
# 6  0.823529     ocsvm  frequencia
# 7  0.823529     ocsvm  frequencia

# %%
## importando dataset
df_ocsvm_dfreq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-dfreq-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq2035.shape)
df_ocsvm_dfreq2035.head()

df_ocsvm_dfreq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-dfreq-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq4055.shape)
df_ocsvm_dfreq4055.head()

df_ocsvm_dfreq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-dfreq-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq6075.shape)
df_ocsvm_dfreq6075.head()

df_ocsvm_dfreq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-dfreq-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq8095.shape)
df_ocsvm_dfreq8095.head()

df_ocsvm_dfreq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-ocsvm-dfreq-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq2095.shape)
df_ocsvm_dfreq2095.head()

df_ocsvm_dfreq_geral = pd.concat([df_ocsvm_dfreq2035, df_ocsvm_dfreq4055,df_ocsvm_dfreq6075,df_ocsvm_dfreq8095,df_ocsvm_dfreq2095],ignore_index=True)
print(df_ocsvm_dfreq_geral.shape)
df_ocsvm_dfreq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  14   1   0  13  0.535714       1.0       0.518519
# 1        2    20-35  14   2   0  12  0.571429       1.0       0.538462
# 2        3    20-35  14   7   0   7  0.750000       1.0       0.666667
# 3        4    20-35  14   7   0   7  0.750000       1.0       0.666667
# 4        5    20-35  14   7   0   7  0.750000       1.0       0.666667
#
#     f1score algoritmo variavel
# 0  0.682927     ocsvm    dfreq
# 1  0.700000     ocsvm    dfreq
# 2  0.800000     ocsvm    dfreq
# 3  0.800000     ocsvm    dfreq
# 4  0.800000     ocsvm    dfreq

# %%
df_ocsvm_dfreq2035.head(10)
df_ocsvm_dfreq4055.head(10)
df_ocsvm_dfreq6075.head(10)
df_ocsvm_dfreq8095.head(10)
df_ocsvm_dfreq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  14   1   0  13  0.535714       1.0       0.518519
# 1        2    20-95  14   2   0  12  0.571429       1.0       0.538462
# 2        3    20-95  14   7   0   7  0.750000       1.0       0.666667
# 3        4    20-95  14   7   0   7  0.750000       1.0       0.666667
# 4        5    20-95  14   7   0   7  0.750000       1.0       0.666667
# 5        6    20-95  14   7   0   7  0.750000       1.0       0.666667
# 6        7    20-95  14   8   0   6  0.785714       1.0       0.700000
# 7        8    20-95  14   9   0   5  0.821429       1.0       0.736842
#
#     f1score algoritmo variavel
# 0  0.682927     ocsvm    dfreq
# 1  0.700000     ocsvm    dfreq
# 2  0.800000     ocsvm    dfreq
# 3  0.800000     ocsvm    dfreq
# 4  0.800000     ocsvm    dfreq
# 5  0.800000     ocsvm    dfreq
# 6  0.823529     ocsvm    dfreq
# 7  0.848485     ocsvm    dfreq

# %%
#METRICAS REC

# %%
## importando dataset
df_rce_dur2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-duracao-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur2035.shape)
df_rce_dur2035.head()

df_rce_dur4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-duracao-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur4055.shape)
df_rce_dur4055.head()

df_rce_dur6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-duracao-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur6075.shape)
df_rce_dur6075.head()

df_rce_dur8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-duracao-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur8095.shape)
df_rce_dur8095.head()

df_rce_dur2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-duracao-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur2095.shape)
df_rce_dur2095.head()

df_rce_dur_geral = pd.concat([df_rce_dur2035, df_rce_dur4055,df_rce_dur6075,df_rce_dur8095,df_rce_dur2095],ignore_index=True)
print(df_rce_dur_geral.shape)
df_rce_dur_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  11   7   3   7  0.642857  0.785714       0.611111
# 1        2    20-35   5  12   9   2  0.607143  0.357143       0.714286
# 2        3    20-35   5  13   9   1  0.642857  0.357143       0.833333
# 3        4    20-35   8  12   6   2  0.714286  0.571429       0.800000
# 4        5    20-35   7  13   7   1  0.714286  0.500000       0.875000
#
#     f1score algoritmo variavel
# 0  0.687500       rce  duracao
# 1  0.476190       rce  duracao
# 2  0.500000       rce  duracao
# 3  0.666667       rce  duracao
# 4  0.636364       rce  duracao
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  11   7   3   7  0.642857  0.785714       0.611111
# 1        2    20-35   5  12   9   2  0.607143  0.357143       0.714286
# ...

# %%
df_rce_dur2035.head(10)
df_rce_dur4055.head(10)
df_rce_dur6075.head(10)
df_rce_dur8095.head(10)
df_rce_dur2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95   9   7   5   7  0.571429  0.642857       0.562500
# 1        2    20-95   9  12   5   2  0.750000  0.642857       0.818182
# 2        3    20-95   7  13   7   1  0.714286  0.500000       0.875000
# 3        4    20-95   7  12   7   2  0.678571  0.500000       0.777778
# 4        5    20-95   8  13   6   1  0.750000  0.571429       0.888889
# 5        6    20-95   7  13   7   1  0.714286  0.500000       0.875000
# 6        7    20-95   7  13   7   1  0.714286  0.500000       0.875000
# 7        8    20-95   6  13   8   1  0.678571  0.428571       0.857143
#
#     f1score algoritmo variavel
# 0  0.600000       rce  duracao
# 1  0.720000       rce  duracao
# 2  0.636364       rce  duracao
# 3  0.608696       rce  duracao
# 4  0.695652       rce  duracao
# 5  0.636364       rce  duracao
# 6  0.636364       rce  duracao
# 7  0.571429       rce  duracao
# ...

# %%
## importando dataset
df_rce_freq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-frequencia-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq2035.shape)
df_rce_freq2035.head()

df_rce_freq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-frequencia-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq4055.shape)
df_rce_freq4055.head()

df_rce_freq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-frequencia-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq6075.shape)
df_rce_freq6075.head()

df_rce_freq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-frequencia-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq8095.shape)
df_rce_freq8095.head()

df_rce_freq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-frequencia-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq2095.shape)
df_rce_freq2095.head()

df_rce_freq_geral = pd.concat([df_rce_freq2035, df_rce_freq4055,df_rce_freq6075,df_rce_freq8095,df_rce_freq2095],ignore_index=True)
print(df_rce_freq_geral.shape)
df_rce_freq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   7  10   7   4  0.607143  0.500000       0.636364
# 1        2    20-35   9  12   5   2  0.750000  0.642857       0.818182
# 2        3    20-35   5  12   9   2  0.607143  0.357143       0.714286
# 3        4    20-35   5  12   9   2  0.607143  0.357143       0.714286
# 4        5    20-35   6  12   8   2  0.642857  0.428571       0.750000
#
#     f1score algoritmo    variavel
# 0  0.560000       rce  frequencia
# 1  0.720000       rce  frequencia
# 2  0.476190       rce  frequencia
# 3  0.476190       rce  frequencia
# 4  0.545455       rce  frequencia
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   7  10   7   4  0.607143  0.500000       0.636364
# ...

# %%
df_rce_freq2035.head(10)
df_rce_freq4055.head(10)
df_rce_freq6075.head(10)
df_rce_freq8095.head(10)
df_rce_freq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  14  10   0   4  0.857143       1.0       0.777778
# 1        2    20-95  14  12   0   2  0.928571       1.0       0.875000
# 2        3    20-95  14  12   0   2  0.928571       1.0       0.875000
# 3        4    20-95  14  12   0   2  0.928571       1.0       0.875000
# 4        5    20-95  14  12   0   2  0.928571       1.0       0.875000
# 5        6    20-95  14  13   0   1  0.964286       1.0       0.933333
# 6        7    20-95  14  13   0   1  0.964286       1.0       0.933333
# 7        8    20-95  14  13   0   1  0.964286       1.0       0.933333
#
#     f1score algoritmo    variavel
# 0  0.875000       rce  frequencia
# 1  0.933333       rce  frequencia
# 2  0.933333       rce  frequencia
# 3  0.933333       rce  frequencia
# 4  0.933333       rce  frequencia
# 5  0.965517       rce  frequencia
# 6  0.965517       rce  frequencia
# 7  0.965517       rce  frequencia
# ...

# %%
## importando dataset
df_rce_dfreq2035 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-dfreq-var-20-35-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq2035.shape)
df_rce_dfreq2035.head()

df_rce_dfreq4055 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-dfreq-var-40-55-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq4055.shape)
df_rce_dfreq4055.head()

df_rce_dfreq6075 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-dfreq-var-60-75-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq6075.shape)
df_rce_dfreq6075.head()

df_rce_dfreq8095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-dfreq-var-80-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq8095.shape)
df_rce_dfreq8095.head()

df_rce_dfreq2095 = pd.read_csv('datasetaruba/results/armetricas-indivatrib-rce-dfreq-var-20-95-trein8.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq2095.shape)
df_rce_dfreq2095.head()

df_rce_dfreq_geral = pd.concat([df_rce_dfreq2035, df_rce_dfreq4055,df_rce_dfreq6075,df_rce_dfreq8095,df_rce_dfreq2095],ignore_index=True)
print(df_rce_dfreq_geral.shape)
df_rce_dfreq_geral.head()
# Out:
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  13   7   1   7  0.714286  0.928571       0.650000
# 1        2    20-35   8  13   6   1  0.750000  0.571429       0.888889
# 2        3    20-35   8  10   6   4  0.642857  0.571429       0.666667
# 3        4    20-35   8  12   6   2  0.714286  0.571429       0.800000
# 4        5    20-35   8  13   6   1  0.750000  0.571429       0.888889
#
#     f1score algoritmo variavel
# 0  0.764706       rce    dfreq
# 1  0.695652       rce    dfreq
# 2  0.615385       rce    dfreq
# 3  0.666667       rce    dfreq
# 4  0.695652       rce    dfreq
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (8, 12)
# (40, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  13   7   1   7  0.714286  0.928571       0.650000
# 1        2    20-35   8  13   6   1  0.750000  0.571429       0.888889
# ...

# %%
df_rce_dfreq2035.head(10)
df_rce_dfreq4055.head(10)
df_rce_dfreq6075.head(10)
df_rce_dfreq8095.head(10)
df_rce_dfreq2095.head(10)
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-95  13   7   1   7  0.714286  0.928571       0.650000
# 1        2    20-95   7  13   7   1  0.714286  0.500000       0.875000
# 2        3    20-95  11  10   3   4  0.750000  0.785714       0.733333
# 3        4    20-95  12  12   2   2  0.857143  0.857143       0.857143
# 4        5    20-95  10  13   4   1  0.821429  0.714286       0.909091
# 5        6    20-95  12  12   2   2  0.857143  0.857143       0.857143
# 6        7    20-95   6  14   8   0  0.714286  0.428571       1.000000
# 7        8    20-95   5  14   9   0  0.678571  0.357143       1.000000
#
#     f1score algoritmo variavel
# 0  0.764706       rce    dfreq
# 1  0.636364       rce    dfreq
# 2  0.758621       rce    dfreq
# 3  0.857143       rce    dfreq
# 4  0.800000       rce    dfreq
# 5  0.857143       rce    dfreq
# 6  0.600000       rce    dfreq
# 7  0.526316       rce    dfreq
# ...

# %% [markdown]
# ### Desempenho individual algoritmos

# %%
#LOF
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('lof_ar_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('lof_ar_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('lof_ar_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_lof_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_lof_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_lof_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
#iFOREST

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('if_ar_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('if_ar_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('if_ar_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('oc_ar_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('oc_ar_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('oc_ar_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
#RCE

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('rce_ar_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('rce_ar_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('rce_ar_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')
# Text(0, 0.5, 'Acurácia')

# %%
df_rce_dfreq_geral.head()
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  13   7   1   7  0.714286  0.928571       0.650000
# 1        2    20-35   8  13   6   1  0.750000  0.571429       0.888889
# 2        3    20-35   8  10   6   4  0.642857  0.571429       0.666667
# 3        4    20-35   8  12   6   2  0.714286  0.571429       0.800000
# 4        5    20-35   8  13   6   1  0.750000  0.571429       0.888889
#
#     f1score algoritmo variavel
# 0  0.764706       rce    dfreq
# 1  0.695652       rce    dfreq
# 2  0.615385       rce    dfreq
# 3  0.666667       rce    dfreq
# 4  0.695652       rce    dfreq
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  13   7   1   7  0.714286  0.928571       0.650000
# 1        2    20-35   8  13   6   1  0.750000  0.571429       0.888889
# 2        3    20-35   8  10   6   4  0.642857  0.571429       0.666667
# ...

# %%
print('DONE')
# Out:
# DONE
# DONE
