# %% [markdown]
# # PPD dos dados para treinamento, validação e teste

# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import random
from numpy import median, mean
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import LocalOutlierFactor
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest

# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# * Outlier =  1 normal
# * Outlier = -1 anormal

# %% [markdown]
# ## IMPORTANDO dados treinamento, validacao e teste

# %%
#BedToToilet

# %%
## importando dataset TREINAMENTO
df_cclothes_trein = pd.read_csv('dataseteh/pp4/eh-ativ-cclothes-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_cclothes_trein.shape)
df_cclothes_trein.head()

## importando dataset de TESTE
df_cclothes_test2035 = pd.read_csv('dataseteh/pp4/eh-ativ-cclothes-var20-35-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_cclothes_test2035.shape)
df_cclothes_test2035.head()

df_cclothes_test4055 = pd.read_csv('dataseteh/pp4/eh-ativ-cclothes-var40-55-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_cclothes_test4055.shape)
df_cclothes_test4055.head()

df_cclothes_test6075 = pd.read_csv('dataseteh/pp4/eh-ativ-cclothes-var60-75-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_cclothes_test6075.shape)
df_cclothes_test6075.head()

df_cclothes_test8095 = pd.read_csv('dataseteh/pp4/eh-ativ-cclothes-var80-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_cclothes_test8095.shape)
df_cclothes_test8095.head()

df_cclothes_test2095 = pd.read_csv('dataseteh/pp4/eh-ativ-cclothes-var20-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_cclothes_test2095.shape)
df_cclothes_test2095.head()
# Out:
# (126, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
#    dia  dia_semana  fim_semana  duracao  frequencia  durfreq  outlier
# 0    1           0           0   1352.0         7.0    193.0       -1
# 1    2           1           0    944.0         2.0    472.0        1
# 2    3           2           0   2631.0         4.0    657.0       -1
# 3    4           3           0   1335.0         3.0    445.0        1
# 4    5           4           0   1005.0         7.0    143.0       -1

# %%
#eating

# %%
## importando dataset TREINAMENTO
df_eating_trein = pd.read_csv('dataseteh/pp4/eh-ativ-eating-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_eating_trein.shape)
df_eating_trein.head()

## importando dataset de TESTE
df_eating_test2035 = pd.read_csv('dataseteh/pp4/eh-ativ-eating-var20-35-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_eating_test2035.shape)
df_eating_test2035.head()

df_eating_test4055 = pd.read_csv('dataseteh/pp4/eh-ativ-eating-var40-55-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_eating_test4055.shape)
df_eating_test4055.head()

df_eating_test6075 = pd.read_csv('dataseteh/pp4/eh-ativ-eating-var60-75-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_eating_test6075.shape)
df_eating_test6075.head()

df_eating_test8095 = pd.read_csv('dataseteh/pp4/eh-ativ-eating-var80-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_eating_test8095.shape)
df_eating_test8095.head()

df_eating_test2095 = pd.read_csv('dataseteh/pp4/eh-ativ-eating-var20-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_eating_test2095.shape)
df_eating_test2095.head()
# Out:
# (126, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
#    dia  dia_semana  fim_semana  duracao  frequencia  durfreq  outlier
# 0    1           0           0   3913.0         2.0   1956.5        1
# 1    2           1           0  12674.0         5.0   2534.0       -1
# 2    3           2           0   5348.0         2.0   2674.0        1
# 3    4           3           0   6244.0         6.0   1040.0       -1
# 4    5           4           0  11595.0         5.0   2319.0       -1

# %%
#mcoffe

# %%
## importando dataset TREINAMENTO
df_mcoffe_trein = pd.read_csv('dataseteh/pp4/eh-ativ-mcoffe-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mcoffe_trein.shape)
df_mcoffe_trein.head()

## importando dataset de TESTE
df_mcoffe_test2035 = pd.read_csv('dataseteh/pp4/eh-ativ-mcoffe-var20-35-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mcoffe_test2035.shape)
df_mcoffe_test2035.head()

df_mcoffe_test4055 = pd.read_csv('dataseteh/pp4/eh-ativ-mcoffe-var40-55-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mcoffe_test4055.shape)
df_mcoffe_test4055.head()

df_mcoffe_test6075 = pd.read_csv('dataseteh/pp4/eh-ativ-mcoffe-var60-75-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mcoffe_test6075.shape)
df_mcoffe_test6075.head()

df_mcoffe_test8095 = pd.read_csv('dataseteh/pp4/eh-ativ-mcoffe-var80-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mcoffe_test8095.shape)
df_mcoffe_test8095.head()

df_mcoffe_test2095 = pd.read_csv('dataseteh/pp4/eh-ativ-mcoffe-var20-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mcoffe_test2095.shape)
df_mcoffe_test2095.head()
# Out:
# (126, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
#    dia  dia_semana  fim_semana  duracao  frequencia  durfreq  outlier
# 0    1           0           0    890.0         2.0    445.0        1
# 1    2           1           0   1666.0         4.0    416.5        1
# 2    3           2           0   1031.0         6.0    171.0       -1
# 3    4           3           0    652.0         8.0     81.0       -1
# 4    5           4           0    784.0         8.0     98.0       -1

# %%
#mhotfood

# %%
## importando dataset TREINAMENTO
df_mhotfood_trein = pd.read_csv('dataseteh/pp4/eh-ativ-mhotfood-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mhotfood_trein.shape)
df_mhotfood_trein.head()

## importando dataset de TESTE
df_mhotfood_test2035 = pd.read_csv('dataseteh/pp4/eh-ativ-mhotfood-var20-35-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mhotfood_test2035.shape)
df_mhotfood_test2035.head()

df_mhotfood_test4055 = pd.read_csv('dataseteh/pp4/eh-ativ-mhotfood-var40-55-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mhotfood_test4055.shape)
df_mhotfood_test4055.head()

df_mhotfood_test6075 = pd.read_csv('dataseteh/pp4/eh-ativ-mhotfood-var60-75-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mhotfood_test6075.shape)
df_mhotfood_test6075.head()

df_mhotfood_test8095 = pd.read_csv('dataseteh/pp4/eh-ativ-mhotfood-var80-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mhotfood_test8095.shape)
df_mhotfood_test8095.head()

df_mhotfood_test2095 = pd.read_csv('dataseteh/pp4/eh-ativ-mhotfood-var20-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_mhotfood_test2095.shape)
df_mhotfood_test2095.head()
# Out:
# (126, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
#    dia  dia_semana  fim_semana  duracao  frequencia  durfreq  outlier
# 0    1           0           0   7244.0         7.0   1034.0       -1
# 1    2           1           0   3664.0         6.0    610.0       -1
# 2    3           2           0   2430.0         1.0   2430.0        1
# 3    4           3           0   4841.0         6.0    806.0       -1
# 4    5           4           0   7579.0         7.0   1082.0       -1

# %%
#toileting

# %%
## importando dataset TREINAMENTO
df_toileting_trein = pd.read_csv('dataseteh/pp4/eh-ativ-toileting-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_toileting_trein.shape)
df_toileting_trein.head()

## importando dataset de TESTE
df_toileting_test2035 = pd.read_csv('dataseteh/pp4/eh-ativ-toileting-var20-35-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_toileting_test2035.shape)
df_toileting_test2035.head()

df_toileting_test4055 = pd.read_csv('dataseteh/pp4/eh-ativ-toileting-var40-55-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_toileting_test4055.shape)
df_toileting_test4055.head()

df_toileting_test6075 = pd.read_csv('dataseteh/pp4/eh-ativ-toileting-var60-75-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_toileting_test6075.shape)
df_toileting_test6075.head()

df_toileting_test8095 = pd.read_csv('dataseteh/pp4/eh-ativ-toileting-var80-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_toileting_test8095.shape)
df_toileting_test8095.head()

df_toileting_test2095 = pd.read_csv('dataseteh/pp4/eh-ativ-toileting-var20-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_toileting_test2095.shape)
df_toileting_test2095.head()
# Out:
# (126, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
#    dia  dia_semana  fim_semana  duracao  frequencia     durfreq  outlier
# 0    1           0           0   2480.0         6.0  413.333333        1
# 1    2           1           0    947.0        11.0   86.000000       -1
# 2    3           2           0    217.0         9.0   24.000000       -1
# 3    4           3           0   1183.0        15.0   78.000000       -1
# 4    5           4           0   1462.0        12.0  121.000000       -1

# %%
#whandface

# %%
## importando dataset TREINAMENTO
df_whandface_trein = pd.read_csv('dataseteh/pp4/eh-ativ-whandface-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_whandface_trein.shape)
df_whandface_trein.head()

## importando dataset de TESTE
df_whandface_test2035 = pd.read_csv('dataseteh/pp4/eh-ativ-whandface-var20-35-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_whandface_test2035.shape)
df_whandface_test2035.head()

df_whandface_test4055 = pd.read_csv('dataseteh/pp4/eh-ativ-whandface-var40-55-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_whandface_test4055.shape)
df_whandface_test4055.head()

df_whandface_test6075 = pd.read_csv('dataseteh/pp4/eh-ativ-whandface-var60-75-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_whandface_test6075.shape)
df_whandface_test6075.head()

df_whandface_test8095 = pd.read_csv('dataseteh/pp4/eh-ativ-whandface-var80-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_whandface_test8095.shape)
df_whandface_test8095.head()

df_whandface_test2095 = pd.read_csv('dataseteh/pp4/eh-ativ-whandface-var20-95-test70.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_whandface_test2095.shape)
df_whandface_test2095.head()
# Out:
# (126, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
# (70, 7)
#    dia  dia_semana  fim_semana  duracao  frequencia  durfreq  outlier
# 0    1           0           0   2072.0         8.0    259.0       -1
# 1    2           1           0    918.0        16.0     57.0       -1
# 2    3           2           0   1756.0         8.0    219.5        1
# 3    4           3           0   1142.0        21.0     54.0       -1
# 4    5           4           0   3395.0         9.0    377.0       -1

# %%
## Treinando MODELOS

# %%
dfc_metricas = pd.DataFrame()

for k in range (1,6): #ITERANDO VARIACOES
    
    for z in range (1,7): #ITERANDO ATIVIDADES

        for y in range (1,5): #ITERANDO ALGORITMOS    
            
            for semana in range(1,19): #iterando semanas
                cont_semana = str(semana)+''
                
                # inicializando listas para armazenar as métricas
                cvp = []
                cvn = []
                cfp = []
                cfn = []
                cacuracia = []
                cprecisao = []
                csensibilidade = []
                cf1escore = []
                cvariavel = []
                csemana = []

                #cclothes
                if (z==1) & (k==1): #cclothes 20-35
                    df_test = df_cclothes_test2035.iloc[:, [3,4,5]].copy()
                    df_trein = df_cclothes_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_cclothes_test = df_cclothes_test2035.copy()
                    variacao = '20-35'
                    atividade = 'cclothes'
                if (z==1) & (k==2): #cclothes 40-55
                    df_test = df_cclothes_test4055.iloc[:, [3,4,5]].copy()
                    df_trein = df_cclothes_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_cclothes_test = df_cclothes_test4055.copy()
                    variacao = '40-55'
                    atividade = 'cclothes'
                if (z==1) & (k==3): #cclothes 60-75
                    df_test = df_cclothes_test6075.iloc[:, [3,4,5]].copy()
                    df_trein = df_cclothes_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()                   
                    df_cclothes_test = df_cclothes_test6075.copy()
                    variacao = '60-75'
                    atividade = 'cclothes'
                if (z==1) & (k==4): #cclothes 80-95
                    df_test = df_cclothes_test8095.iloc[:, [3,4,5]].copy()
                    df_trein = df_cclothes_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()                   
                    df_cclothes_test = df_cclothes_test8095.copy()
                    variacao = '80-95'
                    atividade = 'cclothes'
                if (z==1) & (k==5): #cclothes 20-95
                    df_test = df_cclothes_test2095.iloc[:, [3,4,5]].copy()
                    df_trein = df_cclothes_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()                   
                    df_cclothes_test = df_cclothes_test2095.copy()
                    variacao = '20-95'
                    atividade = 'cclothes'                    

                #eating    
                if (z==2) & (k==1): #eating 20-35
                    df_test = df_eating_test2035.iloc[:, [3,4,5]].copy()
                    df_trein = df_eating_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()                   
                    df_eating_test = df_eating_test2035.copy()
                    variacao = '20-35'
                    atividade = 'eating'
                if (z==2) & (k==2): #eating 40-55
                    df_test = df_eating_test4055.iloc[:, [3,4,5]].copy()
                    df_trein = df_eating_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_eating_test = df_eating_test4055.copy()
                    variacao = '40-55'
                    atividade = 'eating'
                if (z==2) & (k==3): #eating 60-75
                    df_test = df_eating_test6075.iloc[:, [3,4,5]].copy()
                    df_trein = df_eating_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_eating_test = df_eating_test6075.copy()
                    variacao = '60-75'
                    atividade = 'eating'
                if (z==2) & (k==4): #eating 80-95
                    df_test = df_eating_test8095.iloc[:, [3,4,5]].copy()
                    df_trein = df_eating_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_eating_test = df_eating_test8095.copy()
                    variacao = '80-95'
                    atividade = 'eating'        
                if (z==2) & (k==5): #eating 20-95
                    df_test = df_eating_test2095.iloc[:, [3,4,5]].copy()
                    df_trein = df_eating_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_eating_test = df_eating_test2095.copy()
                    variacao = '20-95'
                    atividade = 'eating'                       

                #mcoffe    
                if (z==3) & (k==1): #mcoffe 20-35
                    df_test = df_mcoffe_test2035.iloc[:, [3,4,5]].copy()
                    df_trein = df_mcoffe_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_mcoffe_test = df_mcoffe_test2035.copy()
                    variacao = '20-35'
                    atividade = 'mcoffe'
                if (z==3) & (k==2): #mcoffe 40-55
                    df_test = df_mcoffe_test4055.iloc[:, [3,4,5]].copy()
                    df_trein = df_mcoffe_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_mcoffe_test = df_mcoffe_test4055.copy()
                    variacao = '40-55'
                    atividade = 'mcoffe'
                if (z==3) & (k==3): #mcoffe 60-75
                    df_test = df_mcoffe_test6075.iloc[:, [3,4,5]].copy()
                    df_trein = df_mcoffe_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_mcoffe_test = df_mcoffe_test6075.copy()
                    variacao = '60-75'
                    atividade = 'mcoffe'
                if (z==3) & (k==4): #mcoffe 80-95
                    df_test = df_mcoffe_test8095.iloc[:, [3,4,5]].copy()
                    df_trein = df_mcoffe_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_mcoffe_test = df_mcoffe_test8095.copy()
                    variacao = '80-95'
                    atividade = 'mcoffe'      
                if (z==3) & (k==5): #mcoffe 20-95
                    df_test = df_mcoffe_test2095.iloc[:, [3,4,5]].copy()
                    df_trein = df_mcoffe_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_mcoffe_test = df_mcoffe_test2095.copy()
                    variacao = '20-95'
                    atividade = 'mcoffe'
                    
                #mhotfood    
                if (z==4) & (k==1): #mhotfood 20-35
                    df_test = df_mhotfood_test2035.iloc[:, [3,4,5]].copy()
                    df_trein = df_mhotfood_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_SpareTimeTV_test = df_mhotfood_test2035.copy()
                    variacao = '20-35'
                    atividade = 'mhotfood'
                if (z==4) & (k==2): #mhotfood 40-55
                    df_test = df_mhotfood_test4055.iloc[:, [3,4,5]].copy()
                    df_trein = df_mhotfood_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_SpareTimeTV_test = df_mhotfood_test4055.copy()
                    variacao = '40-55'
                    atividade = 'mhotfood'
                if (z==4) & (k==3): #mhotfood 60-75
                    df_test = df_mhotfood_test6075.iloc[:, [3,4,5]].copy()
                    df_trein = df_mhotfood_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_SpareTimeTV_test = df_mhotfood_test6075.copy()
                    variacao = '60-75'
                    atividade = 'mhotfood'
                if (z==4) & (k==4): #mhotfood 80-95
                    df_test = df_mhotfood_test8095.iloc[:, [3,4,5]].copy()
                    df_trein = df_mhotfood_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_SpareTimeTV_test = df_mhotfood_test8095.copy()
                    variacao = '80-95'
                    atividade = 'mhotfood'                
                if (z==4) & (k==5): #mhotfood 20-95
                    df_test = df_mhotfood_test2095.iloc[:, [3,4,5]].copy()
                    df_trein = df_mhotfood_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_SpareTimeTV_test = df_mhotfood_test2095.copy()
                    variacao = '20-95'
                    atividade = 'mhotfood' 
                    
                #toileting    
                if (z==5) & (k==1): #toileting 20-35
                    df_test = df_toileting_test2035.iloc[:, [3,4,5]].copy()
                    df_trein = df_toileting_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_toileting_test = df_toileting_test2035.copy()
                    variacao = '20-35'
                    atividade = 'toileting'
                if (z==5) & (k==2): #toileting 40-55
                    df_test = df_toileting_test4055.iloc[:, [3,4,5]].copy()
                    df_trein = df_toileting_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_toileting_test = df_toileting_test4055.copy()
                    variacao = '40-55'
                    atividade = 'toileting'
                if (z==5) & (k==3): #toileting 60-75
                    df_test = df_toileting_test6075.iloc[:, [3,4,5]].copy()
                    df_trein = df_toileting_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_toileting_test = df_toileting_test6075.copy()
                    variacao = '60-75'
                    atividade = 'toileting'
                if (z==5) & (k==4): #toileting 80-95
                    df_test = df_toileting_test8095.iloc[:, [3,4,5]].copy()
                    df_trein = df_toileting_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_toileting_test = df_toileting_test8095.copy()
                    variacao = '80-95'
                    atividade = 'toileting'       
                if (z==5) & (k==5): #toileting 20-95
                    df_test = df_toileting_test2095.iloc[:, [3,4,5]].copy()
                    df_trein = df_toileting_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_toileting_test = df_toileting_test2095.copy()
                    variacao = '20-95'
                    atividade = 'toileting'                     
                    
                    
                #whandface    
                if (z==6) & (k==1): #whandface 20-35
                    df_test = df_whandface_test2035.iloc[:, [3,4,5]].copy()
                    df_trein = df_whandface_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_whandface_test = df_whandface_test2035.copy()
                    variacao = '20-35'
                    atividade = 'whandface'
                if (z==6) & (k==2): #whandface 40-55
                    df_test = df_whandface_test4055.iloc[:, [3,4,5]].copy()
                    df_trein = df_whandface_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_whandface_test = df_whandface_test4055.copy()
                    variacao = '40-55'
                    atividade = 'whandface'
                if (z==6) & (k==3): #whandface 60-75
                    df_test = df_whandface_test6075.iloc[:, [3,4,5]].copy()
                    df_trein = df_whandface_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_whandface_test = df_whandface_test6075.copy()
                    variacao = '60-75'
                    atividade = 'whandface'
                if (z==6) & (k==4): #whandface 80-95
                    df_test = df_whandface_test8095.iloc[:, [3,4,5]].copy()
                    df_trein = df_whandface_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_whandface_test = df_whandface_test8095.copy()
                    variacao = '80-95'
                    atividade = 'whandface'                       
                if (z==6) & (k==5): #whandface 20-95
                    df_test = df_whandface_test2095.iloc[:, [3,4,5]].copy()
                    df_trein = df_whandface_trein.iloc[0:semana*7].copy()
                    df_trein = df_trein.iloc[:, [3,4,5]].copy()
                    df_whandface_test = df_whandface_test2095.copy()
                    variacao = '20-95'
                    atividade = 'whandface'                          


                # standarização
                scaler = StandardScaler().fit(df_trein)
                dfs_trein = scaler.transform(df_trein).copy()
                dfs_test = scaler.transform(df_test).copy()

                #modelo
                # fit the model
                if y == 1:
                    clf = svm.OneClassSVM(nu=0.1, kernel='rbf', gamma='scale')
                    algoritmo = 'ocsvm'
                if y == 2:
                    clf = LocalOutlierFactor(n_neighbors=10, novelty=True)
                    algoritmo = 'lof'
                if y == 3:
                    clf = IsolationForest(contamination= 0.1, random_state=1)
                    algoritmo = 'iforest'
                if y == 4:
                    clf = EllipticEnvelope(contamination= 0.1, random_state=1, support_fraction= 0.9)
                    algoritmo = 'rce'

                # treinamento e predicao
                clf.fit(dfs_trein)
                y_pred_train = clf.predict(dfs_trein)
                y_pred_test = clf.predict(dfs_test)

                #calculando métricas
                if (z==1): #cclothes
                    df_cclothes_test['predicao'] = y_pred_test
                    df_cclothes_test['vp'] = np.where((df_cclothes_test['outlier'] == -1) & (df_cclothes_test['predicao'] == -1), 1,0)
                    df_cclothes_test['vn'] = np.where((df_cclothes_test['outlier'] == 1) & (df_cclothes_test['predicao'] == 1), 1,0)
                    df_cclothes_test['fp'] = np.where((df_cclothes_test['outlier'] == -1) & (df_cclothes_test['predicao'] == 1), 1,0)
                    df_cclothes_test['fn'] = np.where((df_cclothes_test['outlier'] == 1) & (df_cclothes_test['predicao'] == -1), 1,0)
                    VP = df_cclothes_test['vp'].sum()
                    VN = df_cclothes_test['vn'].sum()
                    FP = df_cclothes_test['fp'].sum()
                    FN = df_cclothes_test['fn'].sum()             

                if (z==2): #eating
                    df_eating_test['predicao'] = y_pred_test
                    df_eating_test['vp'] = np.where((df_eating_test['outlier'] == -1) & (df_eating_test['predicao'] == -1), 1,0)
                    df_eating_test['vn'] = np.where((df_eating_test['outlier'] == 1) & (df_eating_test['predicao'] == 1), 1,0)
                    df_eating_test['fp'] = np.where((df_eating_test['outlier'] == -1) & (df_eating_test['predicao'] == 1), 1,0)
                    df_eating_test['fn'] = np.where((df_eating_test['outlier'] == 1) & (df_eating_test['predicao'] == -1), 1,0)
                    VP = df_eating_test['vp'].sum()
                    VN = df_eating_test['vn'].sum()
                    FP = df_eating_test['fp'].sum()
                    FN = df_eating_test['fn'].sum()   

                if (z==3): #mcoffe
                    df_mcoffe_test['predicao'] = y_pred_test
                    df_mcoffe_test['vp'] = np.where((df_mcoffe_test['outlier'] == -1) & (df_mcoffe_test['predicao'] == -1), 1,0)
                    df_mcoffe_test['vn'] = np.where((df_mcoffe_test['outlier'] == 1) & (df_mcoffe_test['predicao'] == 1), 1,0)
                    df_mcoffe_test['fp'] = np.where((df_mcoffe_test['outlier'] == -1) & (df_mcoffe_test['predicao'] == 1), 1,0)
                    df_mcoffe_test['fn'] = np.where((df_mcoffe_test['outlier'] == 1) & (df_mcoffe_test['predicao'] == -1), 1,0)
                    VP = df_mcoffe_test['vp'].sum()
                    VN = df_mcoffe_test['vn'].sum()
                    FP = df_mcoffe_test['fp'].sum()
                    FN = df_mcoffe_test['fn'].sum()          

                if (z==4): #SpareTimeTV
                    df_SpareTimeTV_test['predicao'] = y_pred_test
                    df_SpareTimeTV_test['vp'] = np.where((df_SpareTimeTV_test['outlier'] == -1) & (df_SpareTimeTV_test['predicao'] == -1), 1,0)
                    df_SpareTimeTV_test['vn'] = np.where((df_SpareTimeTV_test['outlier'] == 1) & (df_SpareTimeTV_test['predicao'] == 1), 1,0)
                    df_SpareTimeTV_test['fp'] = np.where((df_SpareTimeTV_test['outlier'] == -1) & (df_SpareTimeTV_test['predicao'] == 1), 1,0)
                    df_SpareTimeTV_test['fn'] = np.where((df_SpareTimeTV_test['outlier'] == 1) & (df_SpareTimeTV_test['predicao'] == -1), 1,0)
                    VP = df_SpareTimeTV_test['vp'].sum()
                    VN = df_SpareTimeTV_test['vn'].sum()
                    FP = df_SpareTimeTV_test['fp'].sum()
                    FN = df_SpareTimeTV_test['fn'].sum()                   

                if (z==5): #toileting
                    df_toileting_test['predicao'] = y_pred_test
                    df_toileting_test['vp'] = np.where((df_toileting_test['outlier'] == -1) & (df_toileting_test['predicao'] == -1), 1,0)
                    df_toileting_test['vn'] = np.where((df_toileting_test['outlier'] == 1) & (df_toileting_test['predicao'] == 1), 1,0)
                    df_toileting_test['fp'] = np.where((df_toileting_test['outlier'] == -1) & (df_toileting_test['predicao'] == 1), 1,0)
                    df_toileting_test['fn'] = np.where((df_toileting_test['outlier'] == 1) & (df_toileting_test['predicao'] == -1), 1,0)
                    VP = df_toileting_test['vp'].sum()
                    VN = df_toileting_test['vn'].sum()
                    FP = df_toileting_test['fp'].sum()
                    FN = df_toileting_test['fn'].sum()                 

                if (z==6): #whandface
                    df_whandface_test['predicao'] = y_pred_test
                    df_whandface_test['vp'] = np.where((df_whandface_test['outlier'] == -1) & (df_whandface_test['predicao'] == -1), 1,0)
                    df_whandface_test['vn'] = np.where((df_whandface_test['outlier'] == 1) & (df_whandface_test['predicao'] == 1), 1,0)
                    df_whandface_test['fp'] = np.where((df_whandface_test['outlier'] == -1) & (df_whandface_test['predicao'] == 1), 1,0)
                    df_whandface_test['fn'] = np.where((df_whandface_test['outlier'] == 1) & (df_whandface_test['predicao'] == -1), 1,0)
                    VP = df_whandface_test['vp'].sum()
                    VN = df_whandface_test['vn'].sum()
                    FP = df_whandface_test['fp'].sum()
                    FN = df_whandface_test['fn'].sum()                        
                    
                    
                #calculo das metricas
                erro = (FP+FN)/(VP+VN+FP+FN) #erro
                acuracia =  (VP+VN)/(VP+VN+FP+FN) # accuracy
                precisao = (VP)/(FP+VP) # precision
                sensibilidade = VP/(FN+VP) #recall
                f1escore = 2 * ((precisao * sensibilidade)/(precisao + sensibilidade))
                #armazenando metricas temp
                cvp.append(VP)
                cvn.append(VN)
                cfp.append(FP)
                cfn.append(FN)
                cacuracia.append(acuracia)
                cprecisao.append(precisao)
                csensibilidade.append(sensibilidade)
                cf1escore.append(f1escore)
                
                #gerando dataset metricas
                zipped = list(zip(cvp,cvn,cfp,cfn,cacuracia, cprecisao, csensibilidade, cf1escore))  
                dft_metricas = pd.DataFrame(zipped, columns=['vp', 'vn', 'fp', 'fn','acuracia','precisao','sensibilidade','f1score'])
                dft_metricas['algoritmo'] = algoritmo
                dft_metricas['variacao'] = variacao
                dft_metricas['atividade'] = atividade
                dft_metricas['semana'] = semana
                #dft_metricas.to_csv(r'datasetaruba/results/armetricas-'+atividade+'-'+algoritmo+'-'+variacao+'-sem'+cont_semana+'.csv', sep=';', index=False, decimal=',')
                dfc_metricas = pd.concat([dfc_metricas, dft_metricas.copy()],ignore_index=True)

# print(dfc_metricas.shape)
# dfc_metricas.head(50)            
dfc_metricas.to_csv(r'dataseteh/results/armetricas-atividades-geral.csv', sep=';', index=False, decimal=',')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_lof.py:284: UserWarning: n_neighbors (10) is greater than the total number of samples (7). n_neighbors will be set to (n_samples - 1) for estimation.
#   warnings.warn(
# C:\Users\mauri\AppData\Local\Temp\ipykernel_21296\3163110368.py:346: RuntimeWarning: invalid value encountered in double_scalars
#   f1escore = 2 * ((precisao * sensibilidade)/(precisao + sensibilidade))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_lof.py:284: UserWarning: n_neighbors (10) is greater than the total number of samples (7). n_neighbors will be set to (n_samples - 1) for estimation.
#   warnings.warn(
# C:\Users\mauri\AppData\Local\Temp\ipykernel_21296\3163110368.py:346: RuntimeWarning: invalid value encountered in double_scalars
#   f1escore = 2 * ((precisao * sensibilidade)/(precisao + sensibilidade))
# ...

# %%
print('DONE')
# Out:
# DONE
