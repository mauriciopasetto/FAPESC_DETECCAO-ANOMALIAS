# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Importando dataset metricas para 9 atividades

# %%
#METRICAS LOF

# %%
## importando dataset
df_lof_2035 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-lof-var-20-35-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_2035.shape)
df_lof_2035.head()

df_lof_4055 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-lof-var-40-55-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_4055.shape)
df_lof_4055.head()

df_lof_6075 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-lof-var-60-75-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_6075.shape)
df_lof_6075.head()

df_lof_8095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-lof-var-80-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_8095.shape)
df_lof_8095.head()

df_lof_2095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-lof-var-20-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_2095.shape)
df_lof_2095.head()

df_lof_geral = pd.concat([df_lof_2035, df_lof_4055,df_lof_6075,df_lof_8095,df_lof_2095],ignore_index=True)
print(df_lof_geral.shape)
df_lof_geral.head()
# Out:
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (90, 11)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  32  35   3   0  0.957143  0.914286            1.0
# 1        2    20-35  32  35   3   0  0.957143  0.914286            1.0
# 2        3    20-35  32  35   3   0  0.957143  0.914286            1.0
# 3        4    20-35  32  35   3   0  0.957143  0.914286            1.0
# 4        5    20-35  33  35   2   0  0.971429  0.942857            1.0
#
#     f1score algoritmo
# 0  0.955224       lof
# 1  0.955224       lof
# 2  0.955224       lof
# 3  0.955224       lof
# 4  0.970588       lof

# %%
df_lof_2035.head(20)
df_lof_4055.head(20)
df_lof_6075.head(20)
df_lof_8095.head(20)
df_lof_2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  34  35   1   0  0.985714  0.971429            1.0
# 1         2    20-95  34  35   1   0  0.985714  0.971429            1.0
# 2         3    20-95  34  35   1   0  0.985714  0.971429            1.0
# 3         4    20-95  34  35   1   0  0.985714  0.971429            1.0
# 4         5    20-95  35  35   0   0  1.000000  1.000000            1.0
# 5         6    20-95  35  35   0   0  1.000000  1.000000            1.0
# 6         7    20-95  35  35   0   0  1.000000  1.000000            1.0
# 7         8    20-95  35  35   0   0  1.000000  1.000000            1.0
# 8         9    20-95  35  35   0   0  1.000000  1.000000            1.0
# 9        10    20-95  35  35   0   0  1.000000  1.000000            1.0
# 10       11    20-95  35  35   0   0  1.000000  1.000000            1.0
# 11       12    20-95  35  35   0   0  1.000000  1.000000            1.0
# ...

# %%
#METRICAS iFOREST

# %%
## importando dataset
df_if_2035 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-iforest-var-20-35-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_2035.shape)
df_if_2035.head()

df_if_4055 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-iforest-var-40-55-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_4055.shape)
df_if_4055.head()

df_if_6075 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-iforest-var-60-75-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_6075.shape)
df_if_6075.head()

df_if_8095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-iforest-var-80-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_8095.shape)
df_if_8095.head()

df_if_2095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-iforest-var-20-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_2095.shape)
df_if_2095.head()

df_if_geral = pd.concat([df_if_2035, df_if_4055,df_if_6075,df_if_8095,df_if_2095],ignore_index=True)
print(df_if_geral.shape)
df_if_geral.head()
# Out:
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (90, 11)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  15  29  20   6  0.628571  0.428571       0.714286
# 1        2    20-35  18  26  17   9  0.628571  0.514286       0.666667
# 2        3    20-35  12  35  23   0  0.671429  0.342857       1.000000
# 3        4    20-35   6  35  29   0  0.585714  0.171429       1.000000
# 4        5    20-35   8  35  27   0  0.614286  0.228571       1.000000
#
#     f1score algoritmo
# 0  0.535714   iforest
# 1  0.580645   iforest
# 2  0.510638   iforest
# 3  0.292683   iforest
# 4  0.372093   iforest

# %%
df_if_2035.head(20)
df_if_4055.head(20)
df_if_6075.head(20)
df_if_8095.head(20)
df_if_2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  27  29   8   6  0.800000  0.771429       0.818182
# 1         2    20-95  32  26   3   9  0.828571  0.914286       0.780488
# 2         3    20-95  28  35   7   0  0.900000  0.800000       1.000000
# 3         4    20-95  27  35   8   0  0.885714  0.771429       1.000000
# 4         5    20-95  27  35   8   0  0.885714  0.771429       1.000000
# 5         6    20-95  28  35   7   0  0.900000  0.800000       1.000000
# 6         7    20-95  30  35   5   0  0.928571  0.857143       1.000000
# 7         8    20-95  32  35   3   0  0.957143  0.914286       1.000000
# 8         9    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 9        10    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 10       11    20-95  33  35   2   0  0.971429  0.942857       1.000000
# 11       12    20-95  29  35   6   0  0.914286  0.828571       1.000000
# ...

# %%
#METRICAS OCSVM

# %%
## importando dataset
df_ocsvm_2035 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-ocsvm-var-20-35-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_2035.shape)
df_ocsvm_2035.head()

df_ocsvm_4055 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-ocsvm-var-40-55-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_4055.shape)
df_ocsvm_4055.head()

df_ocsvm_6075 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-ocsvm-var-60-75-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_6075.shape)
df_ocsvm_6075.head()

df_ocsvm_8095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-ocsvm-var-80-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_8095.shape)
df_ocsvm_8095.head()

df_ocsvm_2095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-ocsvm-var-20-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_2095.shape)
df_ocsvm_2095.head()

df_ocsvm_geral = pd.concat([df_ocsvm_2035, df_ocsvm_4055,df_ocsvm_6075,df_ocsvm_8095,df_ocsvm_2095],ignore_index=True)
print(df_ocsvm_geral.shape)
df_ocsvm_geral.head()
# Out:
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (90, 11)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  35   1   0  34  0.514286       1.0       0.507246
# 1        2    20-35  35   6   0  29  0.585714       1.0       0.546875
# 2        3    20-35  35  11   0  24  0.657143       1.0       0.593220
# 3        4    20-35  35  13   0  22  0.685714       1.0       0.614035
# 4        5    20-35  35  13   0  22  0.685714       1.0       0.614035
#
#     f1score algoritmo
# 0  0.673077     ocsvm
# 1  0.707071     ocsvm
# 2  0.744681     ocsvm
# 3  0.760870     ocsvm
# 4  0.760870     ocsvm

# %%
df_ocsvm_2035.head(20)
df_ocsvm_4055.head(20)
df_ocsvm_6075.head(20)
df_ocsvm_8095.head(20)
df_ocsvm_2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35   1   0  34  0.514286       1.0       0.507246
# 1         2    20-95  35   6   0  29  0.585714       1.0       0.546875
# 2         3    20-95  35  11   0  24  0.657143       1.0       0.593220
# 3         4    20-95  35  13   0  22  0.685714       1.0       0.614035
# 4         5    20-95  35  13   0  22  0.685714       1.0       0.614035
# 5         6    20-95  35  17   0  18  0.742857       1.0       0.660377
# 6         7    20-95  35  18   0  17  0.757143       1.0       0.673077
# 7         8    20-95  35  21   0  14  0.800000       1.0       0.714286
# 8         9    20-95  35  23   0  12  0.828571       1.0       0.744681
# 9        10    20-95  35  21   0  14  0.800000       1.0       0.714286
# 10       11    20-95  35  22   0  13  0.814286       1.0       0.729167
# 11       12    20-95  35  23   0  12  0.828571       1.0       0.744681
# ...

# %%
#METRICAS REC

# %%
## importando dataset
df_rce_2035 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-rce-var-20-35-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_2035.shape)
df_rce_2035.head()

df_rce_4055 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-rce-var-40-55-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_4055.shape)
df_rce_4055.head()

df_rce_6075 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-rce-var-60-75-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_6075.shape)
df_rce_6075.head()

df_rce_8095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-rce-var-80-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_8095.shape)
df_rce_8095.head()

df_rce_2095 = pd.read_csv('dataseteh/results/ehmetricas-unifatrib-rce-var-20-95-trein18.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_2095.shape)
df_rce_2095.head()

df_rce_geral = pd.concat([df_rce_2035, df_rce_4055,df_rce_6075,df_rce_8095,df_rce_2095],ignore_index=True)
print(df_rce_geral.shape)
df_rce_geral.head()
# Out:
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (18, 11)
# (90, 11)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  35  30   0   5  0.928571  1.000000       0.875000
# 1        2    20-35  35  25   0  10  0.857143  1.000000       0.777778
# 2        3    20-35  28  31   7   4  0.842857  0.800000       0.875000
# 3        4    20-35  34  35   1   0  0.985714  0.971429       1.000000
# 4        5    20-35  34  35   1   0  0.985714  0.971429       1.000000
#
#     f1score algoritmo
# 0  0.933333       rce
# 1  0.875000       rce
# 2  0.835821       rce
# 3  0.985507       rce
# 4  0.985507       rce

# %%
df_rce_2035.head(20)
df_rce_4055.head(20)
df_rce_6075.head(20)
df_rce_8095.head(20)
df_rce_2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35  30   0   5  0.928571       1.0       0.875000
# 1         2    20-95  35  25   0  10  0.857143       1.0       0.777778
# 2         3    20-95  35  31   0   4  0.942857       1.0       0.897436
# 3         4    20-95  35  35   0   0  1.000000       1.0       1.000000
# 4         5    20-95  35  35   0   0  1.000000       1.0       1.000000
# 5         6    20-95  35  35   0   0  1.000000       1.0       1.000000
# 6         7    20-95  35  35   0   0  1.000000       1.0       1.000000
# 7         8    20-95  35  35   0   0  1.000000       1.0       1.000000
# 8         9    20-95  35  35   0   0  1.000000       1.0       1.000000
# 9        10    20-95  35  35   0   0  1.000000       1.0       1.000000
# 10       11    20-95  35  35   0   0  1.000000       1.0       1.000000
# 11       12    20-95  35  34   0   1  0.985714       1.0       0.972222
# ...

# %% [markdown]
# ### Desempenho individual algoritmos

# %%
#LOF
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('all_lof_att.svg')

# %%
#iFOREST

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('all_if_att.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('all_oc_att.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#RCE

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('all_rce_att.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
print('DONE')
# Out:
# DONE
