# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ### Importando dataset metricas para 9 atividades

# %%
#METRICAS LOF

# %%
## importando dataset
df_lof_dur2035 = pd.read_csv('dataseteh/results/armetricas-lof-duracao-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur2035.shape)
df_lof_dur2035.head()

df_lof_dur4055 = pd.read_csv('dataseteh/results/armetricas-lof-duracao-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur4055.shape)
df_lof_dur4055.head()

df_lof_dur6075 = pd.read_csv('dataseteh/results/armetricas-lof-duracao-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur6075.shape)
df_lof_dur6075.head()

df_lof_dur8095 = pd.read_csv('dataseteh/results/armetricas-lof-duracao-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur8095.shape)
df_lof_dur8095.head()

df_lof_dur2095 = pd.read_csv('dataseteh/results/armetricas-lof-duracao-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dur2095.shape)
df_lof_dur2095.head()

df_lof_dur_geral = pd.concat([df_lof_dur2035, df_lof_dur4055,df_lof_dur6075,df_lof_dur8095,df_lof_dur2095],ignore_index=True)
print(df_lof_dur_geral.shape)
df_lof_dur_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   1  35  34   0  0.514286  0.028571            1.0
# 1        2    20-35   0  35  35   0  0.500000  0.000000            0.0
# 2        3    20-35   0  35  35   0  0.500000  0.000000            0.0
# 3        4    20-35   1  35  34   0  0.514286  0.028571            1.0
# 4        5    20-35   1  35  34   0  0.514286  0.028571            1.0
#
#     f1score algoritmo variavel
# 0  0.055556       lof  duracao
# 1  0.000000       lof  duracao
# 2  0.000000       lof  duracao
# 3  0.055556       lof  duracao
# 4  0.055556       lof  duracao

# %%
df_lof_dur2035.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-35   1  35  34   0  0.514286  0.028571       1.000000
# 1         2    20-35   0  35  35   0  0.500000  0.000000       0.000000
# 2         3    20-35   0  35  35   0  0.500000  0.000000       0.000000
# 3         4    20-35   1  35  34   0  0.514286  0.028571       1.000000
# 4         5    20-35   1  35  34   0  0.514286  0.028571       1.000000
# 5         6    20-35   1  35  34   0  0.514286  0.028571       1.000000
# 6         7    20-35   1  35  34   0  0.514286  0.028571       1.000000
# 7         8    20-35   2  35  33   0  0.528571  0.057143       1.000000
# 8         9    20-35   2  35  33   0  0.528571  0.057143       1.000000
# 9        10    20-35   3  35  32   0  0.542857  0.085714       1.000000
# 10       11    20-35   3  35  32   0  0.542857  0.085714       1.000000
# 11       12    20-35   2  35  33   0  0.528571  0.057143       1.000000
# 12       13    20-35   3  35  32   0  0.542857  0.085714       1.000000
# 13       14    20-35   3  35  32   0  0.542857  0.085714       1.000000
# 14       15    20-35   4  35  31   0  0.557143  0.114286       1.000000
# 15       16    20-35   7  35  28   0  0.600000  0.200000       1.000000
# 16       17    20-35   7  34  28   1  0.585714  0.200000       0.875000
# 17       18    20-35   6  34  29   1  0.571429  0.171429       0.857143
#
#      f1score algoritmo variavel
# 0   0.055556       lof  duracao
# 1   0.000000       lof  duracao
# 2   0.000000       lof  duracao
# 3   0.055556       lof  duracao
# 4   0.055556       lof  duracao
# 5   0.055556       lof  duracao
# 6   0.055556       lof  duracao
# 7   0.108108       lof  duracao
# 8   0.108108       lof  duracao
# 9   0.157895       lof  duracao
# 10  0.157895       lof  duracao
# 11  0.108108       lof  duracao
# 12  0.157895       lof  duracao
# 13  0.157895       lof  duracao
# 14  0.205128       lof  duracao
# 15  0.333333       lof  duracao
# 16  0.325581       lof  duracao
# 17  0.285714       lof  duracao

# %%
## importando dataset
df_lof_freq2035 = pd.read_csv('dataseteh/results/armetricas-lof-frequencia-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq2035.shape)
df_lof_freq2035.head()

df_lof_freq4055 = pd.read_csv('dataseteh/results/armetricas-lof-frequencia-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq4055.shape)
df_lof_freq4055.head()

df_lof_freq6075 = pd.read_csv('dataseteh/results/armetricas-lof-frequencia-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq6075.shape)
df_lof_freq6075.head()

df_lof_freq8095 = pd.read_csv('dataseteh/results/armetricas-lof-frequencia-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq8095.shape)
df_lof_freq8095.head()

df_lof_freq2095 = pd.read_csv('dataseteh/results/armetricas-lof-frequencia-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_freq2095.shape)
df_lof_freq2095.head()

df_lof_freq_geral = pd.concat([df_lof_freq2035, df_lof_freq4055,df_lof_freq6075,df_lof_freq8095,df_lof_freq2095],ignore_index=True)
print(df_lof_freq_geral.shape)
df_lof_freq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   3  35  32   0  0.542857  0.085714            1.0
# 1        2    20-35   7  35  28   0  0.600000  0.200000            1.0
# 2        3    20-35   9  35  26   0  0.628571  0.257143            1.0
# 3        4    20-35  11  35  24   0  0.657143  0.314286            1.0
# 4        5    20-35  18  35  17   0  0.757143  0.514286            1.0
#
#     f1score algoritmo    variavel
# 0  0.157895       lof  frequencia
# 1  0.333333       lof  frequencia
# 2  0.409091       lof  frequencia
# 3  0.478261       lof  frequencia
# 4  0.679245       lof  frequencia

# %%
df_lof_freq2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 1         2    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 2         3    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 3         4    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 4         5    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 5         6    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 6         7    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 7         8    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 8         9    20-95  35  34   0   1  0.985714  1.000000       0.972222
# 9        10    20-95  35  33   0   2  0.971429  1.000000       0.945946
# 10       11    20-95  35  33   0   2  0.971429  1.000000       0.945946
# 11       12    20-95  35  33   0   2  0.971429  1.000000       0.945946
# 12       13    20-95  35  30   0   5  0.928571  1.000000       0.875000
# 13       14    20-95  35  30   0   5  0.928571  1.000000       0.875000
# 14       15    20-95  35  30   0   5  0.928571  1.000000       0.875000
# 15       16    20-95  35  29   0   6  0.914286  1.000000       0.853659
# 16       17    20-95  35  21   0  14  0.800000  1.000000       0.714286
# 17       18    20-95  35  21   0  14  0.800000  1.000000       0.714286
#
#      f1score algoritmo    variavel
# 0   0.985507       lof  frequencia
# 1   1.000000       lof  frequencia
# 2   1.000000       lof  frequencia
# 3   1.000000       lof  frequencia
# 4   1.000000       lof  frequencia
# 5   1.000000       lof  frequencia
# 6   1.000000       lof  frequencia
# 7   1.000000       lof  frequencia
# 8   0.985915       lof  frequencia
# 9   0.972222       lof  frequencia
# 10  0.972222       lof  frequencia
# 11  0.972222       lof  frequencia
# 12  0.933333       lof  frequencia
# 13  0.933333       lof  frequencia
# 14  0.933333       lof  frequencia
# 15  0.921053       lof  frequencia
# 16  0.833333       lof  frequencia
# 17  0.833333       lof  frequencia

# %%
## importando dataset
df_lof_dfreq2035 = pd.read_csv('dataseteh/results/armetricas-lof-dfreq-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq2035.shape)
df_lof_dfreq2035.head()

df_lof_dfreq4055 = pd.read_csv('dataseteh/results/armetricas-lof-dfreq-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq4055.shape)
df_lof_dfreq4055.head()

df_lof_dfreq6075 = pd.read_csv('dataseteh/results/armetricas-lof-dfreq-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq6075.shape)
df_lof_dfreq6075.head()

df_lof_dfreq8095 = pd.read_csv('dataseteh/results/armetricas-lof-dfreq-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq8095.shape)
df_lof_dfreq8095.head()

df_lof_dfreq2095 = pd.read_csv('dataseteh/results/armetricas-lof-dfreq-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_lof_dfreq2095.shape)
df_lof_dfreq2095.head()

df_lof_dfreq_geral = pd.concat([df_lof_dfreq2035, df_lof_dfreq4055,df_lof_dfreq6075,df_lof_dfreq8095,df_lof_dfreq2095],ignore_index=True)
print(df_lof_dfreq_geral.shape)
df_lof_dfreq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  30  35   5   0  0.928571  0.857143            1.0
# 1        2    20-35  33  35   2   0  0.971429  0.942857            1.0
# 2        3    20-35  33  35   2   0  0.971429  0.942857            1.0
# 3        4    20-35  33  35   2   0  0.971429  0.942857            1.0
# 4        5    20-35  33  35   2   0  0.971429  0.942857            1.0
#
#     f1score algoritmo variavel
# 0  0.923077       lof    dfreq
# 1  0.970588       lof    dfreq
# 2  0.970588       lof    dfreq
# 3  0.970588       lof    dfreq
# 4  0.970588       lof    dfreq

# %%
df_lof_dfreq2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35  35   0   0  1.000000       1.0       1.000000
# 1         2    20-95  35  35   0   0  1.000000       1.0       1.000000
# 2         3    20-95  35  35   0   0  1.000000       1.0       1.000000
# 3         4    20-95  35  35   0   0  1.000000       1.0       1.000000
# 4         5    20-95  35  35   0   0  1.000000       1.0       1.000000
# 5         6    20-95  35  35   0   0  1.000000       1.0       1.000000
# 6         7    20-95  35  35   0   0  1.000000       1.0       1.000000
# 7         8    20-95  35  35   0   0  1.000000       1.0       1.000000
# 8         9    20-95  35  35   0   0  1.000000       1.0       1.000000
# 9        10    20-95  35  35   0   0  1.000000       1.0       1.000000
# 10       11    20-95  35  35   0   0  1.000000       1.0       1.000000
# 11       12    20-95  35  35   0   0  1.000000       1.0       1.000000
# 12       13    20-95  35  34   0   1  0.985714       1.0       0.972222
# 13       14    20-95  35  34   0   1  0.985714       1.0       0.972222
# 14       15    20-95  35  34   0   1  0.985714       1.0       0.972222
# 15       16    20-95  35  34   0   1  0.985714       1.0       0.972222
# 16       17    20-95  35  34   0   1  0.985714       1.0       0.972222
# 17       18    20-95  35  34   0   1  0.985714       1.0       0.972222
#
#      f1score algoritmo variavel
# 0   1.000000       lof    dfreq
# 1   1.000000       lof    dfreq
# 2   1.000000       lof    dfreq
# 3   1.000000       lof    dfreq
# 4   1.000000       lof    dfreq
# 5   1.000000       lof    dfreq
# 6   1.000000       lof    dfreq
# 7   1.000000       lof    dfreq
# 8   1.000000       lof    dfreq
# 9   1.000000       lof    dfreq
# 10  1.000000       lof    dfreq
# 11  1.000000       lof    dfreq
# 12  0.985915       lof    dfreq
# 13  0.985915       lof    dfreq
# 14  0.985915       lof    dfreq
# 15  0.985915       lof    dfreq
# 16  0.985915       lof    dfreq
# 17  0.985915       lof    dfreq

# %%
#METRICAS iFOREST

# %%
## importando dataset
df_if_dur2035 = pd.read_csv('dataseteh/results/armetricas-iforest-duracao-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur2035.shape)
df_if_dur2035.head()

df_if_dur4055 = pd.read_csv('dataseteh/results/armetricas-iforest-duracao-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur4055.shape)
df_if_dur4055.head()

df_if_dur6075 = pd.read_csv('dataseteh/results/armetricas-iforest-duracao-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur6075.shape)
df_if_dur6075.head()

df_if_dur8095 = pd.read_csv('dataseteh/results/armetricas-iforest-duracao-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur8095.shape)
df_if_dur8095.head()

df_if_dur2095 = pd.read_csv('dataseteh/results/armetricas-iforest-duracao-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dur2095.shape)
df_if_dur2095.head()

df_if_dur_geral = pd.concat([df_if_dur2035, df_if_dur4055,df_if_dur6075,df_if_dur8095,df_if_dur2095],ignore_index=True)
print(df_if_dur_geral.shape)
df_if_dur_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   8  27  27   8  0.500000  0.228571       0.500000
# 1        2    20-35   8  29  27   6  0.528571  0.228571       0.571429
# 2        3    20-35   1  34  34   1  0.500000  0.028571       0.500000
# 3        4    20-35   4  33  31   2  0.528571  0.114286       0.666667
# 4        5    20-35   2  33  33   2  0.500000  0.057143       0.500000
#
#     f1score algoritmo variavel
# 0  0.313725   iforest  duracao
# 1  0.326531   iforest  duracao
# 2  0.054054   iforest  duracao
# 3  0.195122   iforest  duracao
# 4  0.102564   iforest  duracao

# %%
df_if_dur2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  12  27  23   8  0.557143  0.342857       0.600000
# 1         2    20-95  14  29  21   6  0.614286  0.400000       0.700000
# 2         3    20-95  10  34  25   1  0.628571  0.285714       0.909091
# 3         4    20-95  10  33  25   2  0.614286  0.285714       0.833333
# 4         5    20-95  10  33  25   2  0.614286  0.285714       0.833333
# 5         6    20-95  10  33  25   2  0.614286  0.285714       0.833333
# 6         7    20-95   9  34  26   1  0.614286  0.257143       0.900000
# 7         8    20-95   9  34  26   1  0.614286  0.257143       0.900000
# 8         9    20-95  10  34  25   1  0.628571  0.285714       0.909091
# 9        10    20-95  11  33  24   2  0.628571  0.314286       0.846154
# 10       11    20-95  10  35  25   0  0.642857  0.285714       1.000000
# 11       12    20-95  11  35  24   0  0.657143  0.314286       1.000000
# 12       13    20-95  13  35  22   0  0.685714  0.371429       1.000000
# 13       14    20-95  15  35  20   0  0.714286  0.428571       1.000000
# 14       15    20-95  17  32  18   3  0.700000  0.485714       0.850000
# 15       16    20-95  16  32  19   3  0.685714  0.457143       0.842105
# 16       17    20-95  15  33  20   2  0.685714  0.428571       0.882353
# 17       18    20-95  15  33  20   2  0.685714  0.428571       0.882353
#
#      f1score algoritmo variavel
# 0   0.436364   iforest  duracao
# 1   0.509091   iforest  duracao
# 2   0.434783   iforest  duracao
# 3   0.425532   iforest  duracao
# 4   0.425532   iforest  duracao
# 5   0.425532   iforest  duracao
# 6   0.400000   iforest  duracao
# 7   0.400000   iforest  duracao
# 8   0.434783   iforest  duracao
# 9   0.458333   iforest  duracao
# 10  0.444444   iforest  duracao
# 11  0.478261   iforest  duracao
# 12  0.541667   iforest  duracao
# 13  0.600000   iforest  duracao
# 14  0.618182   iforest  duracao
# 15  0.592593   iforest  duracao
# 16  0.576923   iforest  duracao
# 17  0.576923   iforest  duracao

# %%
## importando dataset
df_if_freq2035 = pd.read_csv('dataseteh/results/armetricas-iforest-frequencia-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq2035.shape)
df_if_freq2035.head()

df_if_freq4055 = pd.read_csv('dataseteh/results/armetricas-iforest-frequencia-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq4055.shape)
df_if_freq4055.head()

df_if_freq6075 = pd.read_csv('dataseteh/results/armetricas-iforest-frequencia-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq6075.shape)
df_if_freq6075.head()

df_if_freq8095 = pd.read_csv('dataseteh/results/armetricas-iforest-frequencia-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq8095.shape)
df_if_freq8095.head()

df_if_freq2095 = pd.read_csv('dataseteh/results/armetricas-iforest-frequencia-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_freq2095.shape)
df_if_freq2095.head()

df_if_freq_geral = pd.concat([df_if_freq2035, df_if_freq4055,df_if_freq6075,df_if_freq8095,df_if_freq2095],ignore_index=True)
print(df_if_freq_geral.shape)
df_if_freq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35   1  32  34   3  0.471429  0.028571       0.250000
# 1        2    20-35   4  28  31   7  0.457143  0.114286       0.363636
# 2        3    20-35   1  33  34   2  0.485714  0.028571       0.333333
# 3        4    20-35   3  33  32   2  0.514286  0.085714       0.600000
# 4        5    20-35   3  32  32   3  0.500000  0.085714       0.500000
#
#     f1score algoritmo    variavel
# 0  0.051282   iforest  frequencia
# 1  0.173913   iforest  frequencia
# 2  0.052632   iforest  frequencia
# 3  0.150000   iforest  frequencia
# 4  0.146341   iforest  frequencia

# %%
df_if_freq2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95   2  32  33   3  0.485714  0.057143       0.400000
# 1         2    20-95  19  28  16   7  0.671429  0.542857       0.730769
# 2         3    20-95  15  33  20   2  0.685714  0.428571       0.882353
# 3         4    20-95  24  33  11   2  0.814286  0.685714       0.923077
# 4         5    20-95  23  32  12   3  0.785714  0.657143       0.884615
# 5         6    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 6         7    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 7         8    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 8         9    20-95  28  32   7   3  0.857143  0.800000       0.903226
# 9        10    20-95  29  34   6   1  0.900000  0.828571       0.966667
# 10       11    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 11       12    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 12       13    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 13       14    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 14       15    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 15       16    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 16       17    20-95  29  32   6   3  0.871429  0.828571       0.906250
# 17       18    20-95  29  32   6   3  0.871429  0.828571       0.906250
#
#      f1score algoritmo    variavel
# 0   0.100000   iforest  frequencia
# 1   0.622951   iforest  frequencia
# 2   0.576923   iforest  frequencia
# 3   0.786885   iforest  frequencia
# 4   0.754098   iforest  frequencia
# 5   0.865672   iforest  frequencia
# 6   0.865672   iforest  frequencia
# 7   0.865672   iforest  frequencia
# 8   0.848485   iforest  frequencia
# 9   0.892308   iforest  frequencia
# 10  0.865672   iforest  frequencia
# 11  0.865672   iforest  frequencia
# 12  0.865672   iforest  frequencia
# 13  0.865672   iforest  frequencia
# 14  0.865672   iforest  frequencia
# 15  0.865672   iforest  frequencia
# 16  0.865672   iforest  frequencia
# 17  0.865672   iforest  frequencia

# %%
## importando dataset
df_if_dfreq2035 = pd.read_csv('dataseteh/results/armetricas-iforest-dfreq-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq2035.shape)
df_if_dfreq2035.head()

df_if_dfreq4055 = pd.read_csv('dataseteh/results/armetricas-iforest-dfreq-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq4055.shape)
df_if_dfreq4055.head()

df_if_dfreq6075 = pd.read_csv('dataseteh/results/armetricas-iforest-dfreq-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq6075.shape)
df_if_dfreq6075.head()

df_if_dfreq8095 = pd.read_csv('dataseteh/results/armetricas-iforest-dfreq-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq8095.shape)
df_if_dfreq8095.head()

df_if_dfreq2095 = pd.read_csv('dataseteh/results/armetricas-iforest-dfreq-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_if_dfreq2095.shape)
df_if_dfreq2095.head()

df_if_dfreq_geral = pd.concat([df_if_dfreq2035, df_if_dfreq4055,df_if_dfreq6075,df_if_dfreq8095,df_if_dfreq2095],ignore_index=True)
print(df_if_dfreq_geral.shape)
df_if_dfreq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  14  35  21   0  0.700000  0.400000            1.0
# 1        2    20-35  27  35   8   0  0.885714  0.771429            1.0
# 2        3    20-35  25  35  10   0  0.857143  0.714286            1.0
# 3        4    20-35  22  35  13   0  0.814286  0.628571            1.0
# 4        5    20-35  21  35  14   0  0.800000  0.600000            1.0
#
#     f1score algoritmo variavel
# 0  0.571429   iforest    dfreq
# 1  0.870968   iforest    dfreq
# 2  0.833333   iforest    dfreq
# 3  0.771930   iforest    dfreq
# 4  0.750000   iforest    dfreq

# %%
df_if_dfreq2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  16  35  19   0  0.728571  0.457143       1.000000
# 1         2    20-95  24  35  11   0  0.842857  0.685714       1.000000
# 2         3    20-95  23  35  12   0  0.828571  0.657143       1.000000
# 3         4    20-95  20  35  15   0  0.785714  0.571429       1.000000
# 4         5    20-95  19  35  16   0  0.771429  0.542857       1.000000
# 5         6    20-95  20  35  15   0  0.785714  0.571429       1.000000
# 6         7    20-95  24  35  11   0  0.842857  0.685714       1.000000
# 7         8    20-95  25  35  10   0  0.857143  0.714286       1.000000
# 8         9    20-95  27  35   8   0  0.885714  0.771429       1.000000
# 9        10    20-95  26  35   9   0  0.871429  0.742857       1.000000
# 10       11    20-95  29  35   6   0  0.914286  0.828571       1.000000
# 11       12    20-95  29  35   6   0  0.914286  0.828571       1.000000
# 12       13    20-95  29  35   6   0  0.914286  0.828571       1.000000
# 13       14    20-95  28  35   7   0  0.900000  0.800000       1.000000
# 14       15    20-95  30  35   5   0  0.928571  0.857143       1.000000
# 15       16    20-95  30  34   5   1  0.914286  0.857143       0.967742
# 16       17    20-95  30  35   5   0  0.928571  0.857143       1.000000
# 17       18    20-95  30  35   5   0  0.928571  0.857143       1.000000
#
#      f1score algoritmo variavel
# 0   0.627451   iforest    dfreq
# 1   0.813559   iforest    dfreq
# 2   0.793103   iforest    dfreq
# 3   0.727273   iforest    dfreq
# 4   0.703704   iforest    dfreq
# 5   0.727273   iforest    dfreq
# 6   0.813559   iforest    dfreq
# 7   0.833333   iforest    dfreq
# 8   0.870968   iforest    dfreq
# 9   0.852459   iforest    dfreq
# 10  0.906250   iforest    dfreq
# 11  0.906250   iforest    dfreq
# 12  0.906250   iforest    dfreq
# 13  0.888889   iforest    dfreq
# 14  0.923077   iforest    dfreq
# 15  0.909091   iforest    dfreq
# 16  0.923077   iforest    dfreq
# 17  0.923077   iforest    dfreq

# %%
#METRICAS OCSVM

# %%
## importando dataset
df_ocsvm_dur2035 = pd.read_csv('dataseteh/results/armetricas-ocsvm-duracao-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur2035.shape)
df_ocsvm_dur2035.head()

df_ocsvm_dur4055 = pd.read_csv('dataseteh/results/armetricas-ocsvm-duracao-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur4055.shape)
df_ocsvm_dur4055.head()

df_ocsvm_dur6075 = pd.read_csv('dataseteh/results/armetricas-ocsvm-duracao-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur6075.shape)
df_ocsvm_dur6075.head()

df_ocsvm_dur8095 = pd.read_csv('dataseteh/results/armetricas-ocsvm-duracao-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur8095.shape)
df_ocsvm_dur8095.head()

df_ocsvm_dur2095 = pd.read_csv('dataseteh/results/armetricas-ocsvm-duracao-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dur2095.shape)
df_ocsvm_dur2095.head()

df_ocsvm_dur_geral = pd.concat([df_ocsvm_dur2035, df_ocsvm_dur4055,df_ocsvm_dur6075,df_ocsvm_dur8095,df_ocsvm_dur2095],ignore_index=True)
print(df_ocsvm_dur_geral.shape)
df_ocsvm_dur_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  34   5   1  30  0.557143  0.971429       0.531250
# 1        2    20-35  30   9   5  26  0.557143  0.857143       0.535714
# 2        3    20-35  26  14   9  21  0.571429  0.742857       0.553191
# 3        4    20-35  23  18  12  17  0.585714  0.657143       0.575000
# 4        5    20-35  24  20  11  15  0.628571  0.685714       0.615385
#
#     f1score algoritmo variavel
# 0  0.686869     ocsvm  duracao
# 1  0.659341     ocsvm  duracao
# 2  0.634146     ocsvm  duracao
# 3  0.613333     ocsvm  duracao
# 4  0.648649     ocsvm  duracao

# %%
df_ocsvm_dur2035.head(50)
df_ocsvm_dur4055.head(50)
df_ocsvm_dur6075.head(50)
df_ocsvm_dur8095.head(50)
df_ocsvm_dur2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35   5   0  30  0.571429  1.000000       0.538462
# 1         2    20-95  34   9   1  26  0.614286  0.971429       0.566667
# 2         3    20-95  33  14   2  21  0.671429  0.942857       0.611111
# 3         4    20-95  31  18   4  17  0.700000  0.885714       0.645833
# 4         5    20-95  31  20   4  15  0.728571  0.885714       0.673913
# 5         6    20-95  29  19   6  16  0.685714  0.828571       0.644444
# 6         7    20-95  28  20   7  15  0.685714  0.800000       0.651163
# 7         8    20-95  28  22   7  13  0.714286  0.800000       0.682927
# 8         9    20-95  28  22   7  13  0.714286  0.800000       0.682927
# 9        10    20-95  28  23   7  12  0.728571  0.800000       0.700000
# 10       11    20-95  28  24   7  11  0.742857  0.800000       0.717949
# 11       12    20-95  28  24   7  11  0.742857  0.800000       0.717949
# 12       13    20-95  28  24   7  11  0.742857  0.800000       0.717949
# 13       14    20-95  29  25   6  10  0.771429  0.828571       0.743590
# 14       15    20-95  29  25   6  10  0.771429  0.828571       0.743590
# 15       16    20-95  29  25   6  10  0.771429  0.828571       0.743590
# 16       17    20-95  29  25   6  10  0.771429  0.828571       0.743590
# 17       18    20-95  29  25   6  10  0.771429  0.828571       0.743590
#
#      f1score algoritmo variavel
# 0   0.700000     ocsvm  duracao
# 1   0.715789     ocsvm  duracao
# 2   0.741573     ocsvm  duracao
# 3   0.746988     ocsvm  duracao
# 4   0.765432     ocsvm  duracao
# 5   0.725000     ocsvm  duracao
# 6   0.717949     ocsvm  duracao
# 7   0.736842     ocsvm  duracao
# 8   0.736842     ocsvm  duracao
# 9   0.746667     ocsvm  duracao
# 10  0.756757     ocsvm  duracao
# 11  0.756757     ocsvm  duracao
# 12  0.756757     ocsvm  duracao
# 13  0.783784     ocsvm  duracao
# 14  0.783784     ocsvm  duracao
# 15  0.783784     ocsvm  duracao
# 16  0.783784     ocsvm  duracao
# 17  0.783784     ocsvm  duracao

# %%
## importando dataset
df_ocsvm_freq2035 = pd.read_csv('dataseteh/results/armetricas-ocsvm-frequencia-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq2035.shape)
df_ocsvm_freq2035.head()

df_ocsvm_freq4055 = pd.read_csv('dataseteh/results/armetricas-ocsvm-frequencia-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq4055.shape)
df_ocsvm_freq4055.head()

df_ocsvm_freq6075 = pd.read_csv('dataseteh/results/armetricas-ocsvm-frequencia-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq6075.shape)
df_ocsvm_freq6075.head()

df_ocsvm_freq8095 = pd.read_csv('dataseteh/results/armetricas-ocsvm-frequencia-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq8095.shape)
df_ocsvm_freq8095.head()

df_ocsvm_freq2095 = pd.read_csv('dataseteh/results/armetricas-ocsvm-frequencia-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_freq2095.shape)
df_ocsvm_freq2095.head()

df_ocsvm_freq_geral = pd.concat([df_ocsvm_freq2035, df_ocsvm_freq4055,df_ocsvm_freq6075,df_ocsvm_freq8095,df_ocsvm_freq2095],ignore_index=True)
print(df_ocsvm_freq_geral.shape)
df_ocsvm_freq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  35   3   0  32  0.542857  1.000000       0.522388
# 1        2    20-35  32  10   3  25  0.600000  0.914286       0.561404
# 2        3    20-35  32  19   3  16  0.728571  0.914286       0.666667
# 3        4    20-35  32  21   3  14  0.757143  0.914286       0.695652
# 4        5    20-35  32  20   3  15  0.742857  0.914286       0.680851
#
#     f1score algoritmo    variavel
# 0  0.686275     ocsvm  frequencia
# 1  0.695652     ocsvm  frequencia
# 2  0.771084     ocsvm  frequencia
# 3  0.790123     ocsvm  frequencia
# 4  0.780488     ocsvm  frequencia

# %%
df_ocsvm_freq2035.head(50)
df_ocsvm_freq4055.head(50)
df_ocsvm_freq6075.head(50)
df_ocsvm_freq8095.head(50)
df_ocsvm_freq2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35   3   0  32  0.542857       1.0       0.522388
# 1         2    20-95  35  10   0  25  0.642857       1.0       0.583333
# 2         3    20-95  35  19   0  16  0.771429       1.0       0.686275
# 3         4    20-95  35  21   0  14  0.800000       1.0       0.714286
# 4         5    20-95  35  20   0  15  0.785714       1.0       0.700000
# 5         6    20-95  35  23   0  12  0.828571       1.0       0.744681
# 6         7    20-95  35  22   0  13  0.814286       1.0       0.729167
# 7         8    20-95  35  26   0   9  0.871429       1.0       0.795455
# 8         9    20-95  35  26   0   9  0.871429       1.0       0.795455
# 9        10    20-95  35  26   0   9  0.871429       1.0       0.795455
# 10       11    20-95  35  29   0   6  0.914286       1.0       0.853659
# 11       12    20-95  35  29   0   6  0.914286       1.0       0.853659
# 12       13    20-95  35  30   0   5  0.928571       1.0       0.875000
# 13       14    20-95  35  30   0   5  0.928571       1.0       0.875000
# 14       15    20-95  35  30   0   5  0.928571       1.0       0.875000
# 15       16    20-95  35  30   0   5  0.928571       1.0       0.875000
# 16       17    20-95  35  30   0   5  0.928571       1.0       0.875000
# 17       18    20-95  35  30   0   5  0.928571       1.0       0.875000
#
#      f1score algoritmo    variavel
# 0   0.686275     ocsvm  frequencia
# 1   0.736842     ocsvm  frequencia
# 2   0.813953     ocsvm  frequencia
# 3   0.833333     ocsvm  frequencia
# 4   0.823529     ocsvm  frequencia
# 5   0.853659     ocsvm  frequencia
# 6   0.843373     ocsvm  frequencia
# 7   0.886076     ocsvm  frequencia
# 8   0.886076     ocsvm  frequencia
# 9   0.886076     ocsvm  frequencia
# 10  0.921053     ocsvm  frequencia
# 11  0.921053     ocsvm  frequencia
# 12  0.933333     ocsvm  frequencia
# 13  0.933333     ocsvm  frequencia
# 14  0.933333     ocsvm  frequencia
# 15  0.933333     ocsvm  frequencia
# 16  0.933333     ocsvm  frequencia
# 17  0.933333     ocsvm  frequencia

# %%
## importando dataset
df_ocsvm_dfreq2035 = pd.read_csv('dataseteh/results/armetricas-ocsvm-dfreq-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq2035.shape)
df_ocsvm_dfreq2035.head()

df_ocsvm_dfreq4055 = pd.read_csv('dataseteh/results/armetricas-ocsvm-dfreq-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq4055.shape)
df_ocsvm_dfreq4055.head()

df_ocsvm_dfreq6075 = pd.read_csv('dataseteh/results/armetricas-ocsvm-dfreq-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq6075.shape)
df_ocsvm_dfreq6075.head()

df_ocsvm_dfreq8095 = pd.read_csv('dataseteh/results/armetricas-ocsvm-dfreq-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq8095.shape)
df_ocsvm_dfreq8095.head()

df_ocsvm_dfreq2095 = pd.read_csv('dataseteh/results/armetricas-ocsvm-dfreq-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_ocsvm_dfreq2095.shape)
df_ocsvm_dfreq2095.head()

df_ocsvm_dfreq_geral = pd.concat([df_ocsvm_dfreq2035, df_ocsvm_dfreq4055,df_ocsvm_dfreq6075,df_ocsvm_dfreq8095,df_ocsvm_dfreq2095],ignore_index=True)
print(df_ocsvm_dfreq_geral.shape)
df_ocsvm_dfreq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  35   2   0  33  0.528571  1.000000       0.514706
# 1        2    20-35  35   6   0  29  0.585714  1.000000       0.546875
# 2        3    20-35  35  15   0  20  0.714286  1.000000       0.636364
# 3        4    20-35  35  21   0  14  0.800000  1.000000       0.714286
# 4        5    20-35  34  21   1  14  0.785714  0.971429       0.708333
#
#     f1score algoritmo variavel
# 0  0.679612     ocsvm    dfreq
# 1  0.707071     ocsvm    dfreq
# 2  0.777778     ocsvm    dfreq
# 3  0.833333     ocsvm    dfreq
# 4  0.819277     ocsvm    dfreq

# %%
df_ocsvm_dfreq2035.head(50)
df_ocsvm_dfreq4055.head(50)
df_ocsvm_dfreq6075.head(50)
df_ocsvm_dfreq8095.head(50)
df_ocsvm_dfreq2095.head(50)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35   2   0  33  0.528571       1.0       0.514706
# 1         2    20-95  35   6   0  29  0.585714       1.0       0.546875
# 2         3    20-95  35  15   0  20  0.714286       1.0       0.636364
# 3         4    20-95  35  21   0  14  0.800000       1.0       0.714286
# 4         5    20-95  35  21   0  14  0.800000       1.0       0.714286
# 5         6    20-95  35  24   0  11  0.842857       1.0       0.760870
# 6         7    20-95  35  23   0  12  0.828571       1.0       0.744681
# 7         8    20-95  35  24   0  11  0.842857       1.0       0.760870
# 8         9    20-95  35  25   0  10  0.857143       1.0       0.777778
# 9        10    20-95  35  25   0  10  0.857143       1.0       0.777778
# 10       11    20-95  35  25   0  10  0.857143       1.0       0.777778
# 11       12    20-95  35  25   0  10  0.857143       1.0       0.777778
# 12       13    20-95  35  26   0   9  0.871429       1.0       0.795455
# 13       14    20-95  35  28   0   7  0.900000       1.0       0.833333
# 14       15    20-95  35  29   0   6  0.914286       1.0       0.853659
# 15       16    20-95  35  30   0   5  0.928571       1.0       0.875000
# 16       17    20-95  35  29   0   6  0.914286       1.0       0.853659
# 17       18    20-95  35  30   0   5  0.928571       1.0       0.875000
#
#      f1score algoritmo variavel
# 0   0.679612     ocsvm    dfreq
# 1   0.707071     ocsvm    dfreq
# 2   0.777778     ocsvm    dfreq
# 3   0.833333     ocsvm    dfreq
# 4   0.833333     ocsvm    dfreq
# 5   0.864198     ocsvm    dfreq
# 6   0.853659     ocsvm    dfreq
# 7   0.864198     ocsvm    dfreq
# 8   0.875000     ocsvm    dfreq
# 9   0.875000     ocsvm    dfreq
# 10  0.875000     ocsvm    dfreq
# 11  0.875000     ocsvm    dfreq
# 12  0.886076     ocsvm    dfreq
# 13  0.909091     ocsvm    dfreq
# 14  0.921053     ocsvm    dfreq
# 15  0.933333     ocsvm    dfreq
# 16  0.921053     ocsvm    dfreq
# 17  0.933333     ocsvm    dfreq

# %%
#METRICAS REC

# %%
## importando dataset
df_rce_dur2035 = pd.read_csv('dataseteh/results/armetricas-rce-duracao-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur2035.shape)
df_rce_dur2035.head()

df_rce_dur4055 = pd.read_csv('dataseteh/results/armetricas-rce-duracao-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur4055.shape)
df_rce_dur4055.head()

df_rce_dur6075 = pd.read_csv('dataseteh/results/armetricas-rce-duracao-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur6075.shape)
df_rce_dur6075.head()

df_rce_dur8095 = pd.read_csv('dataseteh/results/armetricas-rce-duracao-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur8095.shape)
df_rce_dur8095.head()

df_rce_dur2095 = pd.read_csv('dataseteh/results/armetricas-rce-duracao-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dur2095.shape)
df_rce_dur2095.head()

df_rce_dur_geral = pd.concat([df_rce_dur2035, df_rce_dur4055,df_rce_dur6075,df_rce_dur8095,df_rce_dur2095],ignore_index=True)
print(df_rce_dur_geral.shape)
df_rce_dur_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  15  26  20   9  0.585714  0.428571          0.625
# 1        2    20-35  12  31  23   4  0.614286  0.342857          0.750
# 2        3    20-35   2  35  33   0  0.528571  0.057143          1.000
# 3        4    20-35   0  35  35   0  0.500000  0.000000          0.000
# 4        5    20-35   2  35  33   0  0.528571  0.057143          1.000
#
#     f1score algoritmo variavel
# 0  0.508475       rce  duracao
# 1  0.470588       rce  duracao
# 2  0.108108       rce  duracao
# 3  0.000000       rce  duracao
# 4  0.108108       rce  duracao

# %%
df_rce_dur2035.head(20)
df_rce_dur4055.head(20)
df_rce_dur6075.head(20)
df_rce_dur8095.head(20)
df_rce_dur2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  17  26  18   9  0.614286  0.485714       0.653846
# 1         2    20-95  16  31  19   4  0.671429  0.457143       0.800000
# 2         3    20-95   8  35  27   0  0.614286  0.228571       1.000000
# 3         4    20-95   6  35  29   0  0.585714  0.171429       1.000000
# 4         5    20-95  10  35  25   0  0.642857  0.285714       1.000000
# 5         6    20-95   7  35  28   0  0.600000  0.200000       1.000000
# 6         7    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 7         8    20-95   8  35  27   0  0.614286  0.228571       1.000000
# 8         9    20-95   8  35  27   0  0.614286  0.228571       1.000000
# 9        10    20-95   8  35  27   0  0.614286  0.228571       1.000000
# 10       11    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 11       12    20-95   7  35  28   0  0.600000  0.200000       1.000000
# 12       13    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 13       14    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 14       15    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 15       16    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 16       17    20-95   9  35  26   0  0.628571  0.257143       1.000000
# 17       18    20-95   9  35  26   0  0.628571  0.257143       1.000000
#
#      f1score algoritmo variavel
# 0   0.557377       rce  duracao
# 1   0.581818       rce  duracao
# 2   0.372093       rce  duracao
# 3   0.292683       rce  duracao
# 4   0.444444       rce  duracao
# 5   0.333333       rce  duracao
# 6   0.409091       rce  duracao
# 7   0.372093       rce  duracao
# 8   0.372093       rce  duracao
# 9   0.372093       rce  duracao
# 10  0.409091       rce  duracao
# 11  0.333333       rce  duracao
# 12  0.409091       rce  duracao
# 13  0.409091       rce  duracao
# 14  0.409091       rce  duracao
# 15  0.409091       rce  duracao
# 16  0.409091       rce  duracao
# 17  0.409091       rce  duracao

# %%
## importando dataset
df_rce_freq2035 = pd.read_csv('dataseteh/results/armetricas-rce-frequencia-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq2035.shape)
df_rce_freq2035.head()

df_rce_freq4055 = pd.read_csv('dataseteh/results/armetricas-rce-frequencia-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq4055.shape)
df_rce_freq4055.head()

df_rce_freq6075 = pd.read_csv('dataseteh/results/armetricas-rce-frequencia-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq6075.shape)
df_rce_freq6075.head()

df_rce_freq8095 = pd.read_csv('dataseteh/results/armetricas-rce-frequencia-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq8095.shape)
df_rce_freq8095.head()

df_rce_freq2095 = pd.read_csv('dataseteh/results/armetricas-rce-frequencia-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_freq2095.shape)
df_rce_freq2095.head()

df_rce_freq_geral = pd.concat([df_rce_freq2035, df_rce_freq4055,df_rce_freq6075,df_rce_freq8095,df_rce_freq2095],ignore_index=True)
print(df_rce_freq_geral.shape)
df_rce_freq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  35   5   0  30  0.571429  1.000000       0.538462
# 1        2    20-35  20  35  15   0  0.785714  0.571429       1.000000
# 2        3    20-35  20  33  15   2  0.757143  0.571429       0.909091
# 3        4    20-35  17  35  18   0  0.742857  0.485714       1.000000
# 4        5    20-35  17  35  18   0  0.742857  0.485714       1.000000
#
#     f1score algoritmo    variavel
# 0  0.700000       rce  frequencia
# 1  0.727273       rce  frequencia
# 2  0.701754       rce  frequencia
# 3  0.653846       rce  frequencia
# 4  0.653846       rce  frequencia

# %%
df_rce_freq2035.head(20)
df_rce_freq4055.head(20)
df_rce_freq6075.head(20)
df_rce_freq8095.head(20)
df_rce_freq2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  35   5   0  30  0.571429  1.000000       0.538462
# 1         2    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 2         3    20-95  35  33   0   2  0.971429  1.000000       0.945946
# 3         4    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 4         5    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 5         6    20-95  34  35   1   0  0.985714  0.971429       1.000000
# 6         7    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 7         8    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 8         9    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 9        10    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 10       11    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 11       12    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 12       13    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 13       14    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 14       15    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 15       16    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 16       17    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 17       18    20-95  35  35   0   0  1.000000  1.000000       1.000000
#
#      f1score algoritmo    variavel
# 0   0.700000       rce  frequencia
# 1   0.985507       rce  frequencia
# 2   0.972222       rce  frequencia
# 3   0.985507       rce  frequencia
# 4   0.985507       rce  frequencia
# 5   0.985507       rce  frequencia
# 6   1.000000       rce  frequencia
# 7   1.000000       rce  frequencia
# 8   1.000000       rce  frequencia
# 9   1.000000       rce  frequencia
# 10  1.000000       rce  frequencia
# 11  1.000000       rce  frequencia
# 12  1.000000       rce  frequencia
# 13  1.000000       rce  frequencia
# 14  1.000000       rce  frequencia
# 15  1.000000       rce  frequencia
# 16  1.000000       rce  frequencia
# 17  1.000000       rce  frequencia

# %%
## importando dataset
df_rce_dfreq2035 = pd.read_csv('dataseteh/results/armetricas-rce-dfreq-var-20-35-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq2035.shape)
df_rce_dfreq2035.head()

df_rce_dfreq4055 = pd.read_csv('dataseteh/results/armetricas-rce-dfreq-var-40-55-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq4055.shape)
df_rce_dfreq4055.head()

df_rce_dfreq6075 = pd.read_csv('dataseteh/results/armetricas-rce-dfreq-var-60-75-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq6075.shape)
df_rce_dfreq6075.head()

df_rce_dfreq8095 = pd.read_csv('dataseteh/results/armetricas-rce-dfreq-var-80-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq8095.shape)
df_rce_dfreq8095.head()

df_rce_dfreq2095 = pd.read_csv('dataseteh/results/armetricas-rce-dfreq-var-20-95-trein126.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
print(df_rce_dfreq2095.shape)
df_rce_dfreq2095.head()

df_rce_dfreq_geral = pd.concat([df_rce_dfreq2035, df_rce_dfreq4055,df_rce_dfreq6075,df_rce_dfreq8095,df_rce_dfreq2095],ignore_index=True)
print(df_rce_dfreq_geral.shape)
df_rce_dfreq_geral.head()
# Out:
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (18, 12)
# (90, 12)
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  30  25   5  10  0.785714  0.857143       0.750000
# 1        2    20-35  34  32   1   3  0.942857  0.971429       0.918919
# 2        3    20-35  34  35   1   0  0.985714  0.971429       1.000000
# 3        4    20-35  34  25   1  10  0.842857  0.971429       0.772727
# 4        5    20-35  34  32   1   3  0.942857  0.971429       0.918919
#
#     f1score algoritmo variavel
# 0  0.800000       rce    dfreq
# 1  0.944444       rce    dfreq
# 2  0.985507       rce    dfreq
# 3  0.860759       rce    dfreq
# 4  0.944444       rce    dfreq

# %%
df_rce_dfreq2035.head(20)
df_rce_dfreq4055.head(20)
df_rce_dfreq6075.head(20)
df_rce_dfreq8095.head(20)
df_rce_dfreq2095.head(20)
# Out:
#     semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0         1    20-95  32  25   3  10  0.814286  0.914286       0.761905
# 1         2    20-95  35  32   0   3  0.957143  1.000000       0.921053
# 2         3    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 3         4    20-95  35  25   0  10  0.857143  1.000000       0.777778
# 4         5    20-95  35  32   0   3  0.957143  1.000000       0.921053
# 5         6    20-95  35  34   0   1  0.985714  1.000000       0.972222
# 6         7    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 7         8    20-95  35  34   0   1  0.985714  1.000000       0.972222
# 8         9    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 9        10    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 10       11    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 11       12    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 12       13    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 13       14    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 14       15    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 15       16    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 16       17    20-95  35  35   0   0  1.000000  1.000000       1.000000
# 17       18    20-95  35  34   0   1  0.985714  1.000000       0.972222
#
#      f1score algoritmo variavel
# 0   0.831169       rce    dfreq
# 1   0.958904       rce    dfreq
# 2   1.000000       rce    dfreq
# 3   0.875000       rce    dfreq
# 4   0.958904       rce    dfreq
# 5   0.985915       rce    dfreq
# 6   1.000000       rce    dfreq
# 7   0.985915       rce    dfreq
# 8   1.000000       rce    dfreq
# 9   1.000000       rce    dfreq
# 10  1.000000       rce    dfreq
# 11  1.000000       rce    dfreq
# 12  1.000000       rce    dfreq
# 13  1.000000       rce    dfreq
# 14  1.000000       rce    dfreq
# 15  1.000000       rce    dfreq
# 16  1.000000       rce    dfreq
# 17  0.985915       rce    dfreq

# %% [markdown]
# ### Desempenho individual algoritmos

# %%
#LOF
#ACURACIA

sns.set_theme(font_scale=1.3)

ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dur2095, color='brown')
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('lod_eh_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('lod_eh_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_lof_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('lof_eh_dfreq.svg')

# %%
cores = ["red","green", "blue", "magenta", "brown"]
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_lof_freq_geral, palette= cores)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
#plt.legend([], [], frameon=False)
# ax.set_xlim(-5, 75)
# ax.set_ylim(0, 10)
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_lof_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
plt.legend([], [], frameon=False)
plt.savefig('lod_eh_dur.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_lof_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
plt.legend([], [], frameon=False)
plt.savefig('lod_eh_dfreq.svg')

# %%
#iFOREST

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('if_eh_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('if_eh_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_if_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('if_eh_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_if_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('oc_eh_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('oc_eh_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_ocsvm_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('oc_eh_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_ocsvm_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#RCE

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dur2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('rce_eh_dur.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_freq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('rce_eh_freq.svg')

# %%
#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq2035, color='red')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq4055, color='green')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq6075, color='blue')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq8095, color='magenta')
ax = sns.lineplot(x="semanas", y="acuracia", data=df_rce_dfreq2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('rce_eh_dfreq.svg')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_freq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_dur_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
ax = sns.barplot(x="semanas", y="acuracia", hue='variacao', data=df_rce_dfreq_geral)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
df_rce_dfreq_geral.head()
# Out:
#    semanas variacao  vp  vn  fp  fn  acuracia  precisao  sensibilidade  \
# 0        1    20-35  30  25   5  10  0.785714  0.857143       0.750000
# 1        2    20-35  34  32   1   3  0.942857  0.971429       0.918919
# 2        3    20-35  34  35   1   0  0.985714  0.971429       1.000000
# 3        4    20-35  34  25   1  10  0.842857  0.971429       0.772727
# 4        5    20-35  34  32   1   3  0.942857  0.971429       0.918919
#
#     f1score algoritmo variavel
# 0  0.800000       rce    dfreq
# 1  0.944444       rce    dfreq
# 2  0.985507       rce    dfreq
# 3  0.860759       rce    dfreq
# 4  0.944444       rce    dfreq

# %%
print('DONE')
# Out:
# DONE
