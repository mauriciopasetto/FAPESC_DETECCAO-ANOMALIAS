# %%
##importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ### Importando dataset metricas para 9 atividades

# %%
## importando dataset
df_metricas = pd.read_csv('dataseteh/results/armetricas-atividades-geral.csv',delimiter=';',decimal=',',thousands=".",encoding='ANSI')
df_metricas = df_metricas.fillna(0)
print(df_metricas.shape)
df_metricas.head()
# Out:
# (2160, 12)
#    vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 0  29  10   0  31  0.557143  1.000000       0.483333  0.651685     ocsvm
# 1  26  17   3  24  0.614286  0.896552       0.520000  0.658228     ocsvm
# 2  26  20   3  21  0.657143  0.896552       0.553191  0.684211     ocsvm
# 3  22  25   7  16  0.671429  0.758621       0.578947  0.656716     ocsvm
# 4  23  24   6  17  0.671429  0.793103       0.575000  0.666667     ocsvm
#
#   variacao atividade  semana
# 0    20-35  cclothes       1
# 1    20-35  cclothes       2
# 2    20-35  cclothes       3
# 3    20-35  cclothes       4
# 4    20-35  cclothes       5

# %% [markdown]
# ## Atividade cclothes

# %%
#LOF

# %%
dfm_cclothes_lof = df_metricas[(df_metricas['atividade'] == "cclothes") & (df_metricas['algoritmo'] == "lof")]
print(dfm_cclothes_lof.shape)
dfm_cclothes_lof.head(18)
# Out:
# (90, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 18  17  40  12   1  0.814286  0.586207       0.944444  0.723404       lof
# 19  16  41  13   0  0.814286  0.551724       1.000000  0.711111       lof
# 20  16  40  13   1  0.800000  0.551724       0.941176  0.695652       lof
# 21  16  41  13   0  0.814286  0.551724       1.000000  0.711111       lof
# 22  16  38  13   3  0.771429  0.551724       0.842105  0.666667       lof
# 23  17  36  12   5  0.757143  0.586207       0.772727  0.666667       lof
# 24  17  32  12   9  0.700000  0.586207       0.653846  0.618182       lof
# 25  17  31  12  10  0.685714  0.586207       0.629630  0.607143       lof
# 26  17  30  12  11  0.671429  0.586207       0.607143  0.596491       lof
# 27  19  29  10  12  0.685714  0.655172       0.612903  0.633333       lof
# 28  19  31  10  10  0.714286  0.655172       0.655172  0.655172       lof
# ...

# %%
sns.set_theme(font_scale=1.3)
cores = ["red","green", "blue", "magenta", "brown"]

ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_cclothes_lof,  palette= cores)

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.savefig('ai_cc_lof.svg')

# %%
#iFOREST

# %%
dfm_cclothes_if = df_metricas[(df_metricas['atividade'] == "cclothes") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_cclothes_if.shape)
dfm_cclothes_if.head()
# Out:
# (90, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 36   0  38  29   3  0.542857  0.000000       0.000000  0.000000   iforest
# 37   8  39  21   2  0.671429  0.275862       0.800000  0.410256   iforest
# 38   6  37  23   4  0.614286  0.206897       0.600000  0.307692   iforest
# 39  10  39  19   2  0.700000  0.344828       0.833333  0.487805   iforest
# 40   9  39  20   2  0.685714  0.310345       0.818182  0.450000   iforest
#
#    variacao atividade  semana
# 36    20-35  cclothes       1
# 37    20-35  cclothes       2
# 38    20-35  cclothes       3
# 39    20-35  cclothes       4
# 40    20-35  cclothes       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_cclothes_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
dfm_cclothes_ocsvm = df_metricas[(df_metricas['atividade'] == "cclothes") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_cclothes_ocsvm.shape)
dfm_cclothes_ocsvm.head()
# Out:
# (90, 12)
#    vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 0  29  10   0  31  0.557143  1.000000       0.483333  0.651685     ocsvm
# 1  26  17   3  24  0.614286  0.896552       0.520000  0.658228     ocsvm
# 2  26  20   3  21  0.657143  0.896552       0.553191  0.684211     ocsvm
# 3  22  25   7  16  0.671429  0.758621       0.578947  0.656716     ocsvm
# 4  23  24   6  17  0.671429  0.793103       0.575000  0.666667     ocsvm
#
#   variacao atividade  semana
# 0    20-35  cclothes       1
# 1    20-35  cclothes       2
# 2    20-35  cclothes       3
# 3    20-35  cclothes       4
# 4    20-35  cclothes       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_cclothes_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
dfm_cclothes_rce = df_metricas[(df_metricas['atividade'] == "cclothes") & (df_metricas['algoritmo'] == "rce")]
print(dfm_cclothes_rce.shape)

dfm_cclothes_rce.head()
# Out:
# (90, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 54  23  24   6  17  0.671429  0.793103       0.575000  0.666667       rce
# 55  15  32  14   9  0.671429  0.517241       0.625000  0.566038       rce
# 56  15  36  14   5  0.728571  0.517241       0.750000  0.612245       rce
# 57  15  37  14   4  0.742857  0.517241       0.789474  0.625000       rce
# 58  15  38  14   3  0.757143  0.517241       0.833333  0.638298       rce
#
#    variacao atividade  semana
# 54    20-35  cclothes       1
# 55    20-35  cclothes       2
# 56    20-35  cclothes       3
# 57    20-35  cclothes       4
# 58    20-35  cclothes       5

# %%
sns.set_theme(font_scale=1.3)
cores = ["red","green", "blue", "magenta", "brown"]

ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_cclothes_rce, palette= cores)

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")

plt.legend([], [], frameon=False)
plt.savefig('ai_cc_ac_lof.svg')

# %% [markdown]
# ## Atividade eating

# %%
#LOF

# %%
dfm_eating_lof = df_metricas[(df_metricas['atividade'] == "eating") & (df_metricas['algoritmo'] == "lof")]
print(dfm_eating_lof.shape)
dfm_eating_lof.head()
# Out:
# (90, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 90   8  46  16   0  0.771429  0.333333       1.000000  0.500000       lof
# 91   9  46  15   0  0.785714  0.375000       1.000000  0.545455       lof
# 92  10  45  14   1  0.785714  0.416667       0.909091  0.571429       lof
# 93  18  43   6   3  0.871429  0.750000       0.857143  0.800000       lof
# 94  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
#
#    variacao atividade  semana
# 90    20-35    eating       1
# 91    20-35    eating       2
# 92    20-35    eating       3
# 93    20-35    eating       4
# 94    20-35    eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_eating_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#iFOREST

# %%
dfm_eating_if = df_metricas[(df_metricas['atividade'] == "eating") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_eating_if.shape)
dfm_eating_if.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 108   0  41  24   5  0.585714  0.000000       0.000000  0.000000   iforest
# 109  22  38   2   8  0.857143  0.916667       0.733333  0.814815   iforest
# 110  15  38   9   8  0.757143  0.625000       0.652174  0.638298   iforest
# 111  17  43   7   3  0.857143  0.708333       0.850000  0.772727   iforest
# 112  17  41   7   5  0.828571  0.708333       0.772727  0.739130   iforest
#
#     variacao atividade  semana
# 108    20-35    eating       1
# 109    20-35    eating       2
# 110    20-35    eating       3
# 111    20-35    eating       4
# 112    20-35    eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_eating_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
dfm_eating_ocsvm = df_metricas[(df_metricas['atividade'] == "eating") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_eating_ocsvm.shape)
dfm_eating_ocsvm.head()
# Out:
# (90, 12)
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 72  24  33   0  13  0.814286       1.0       0.648649  0.786885     ocsvm
# 73  24  34   0  12  0.828571       1.0       0.666667  0.800000     ocsvm
# 74  24  38   0   8  0.885714       1.0       0.750000  0.857143     ocsvm
# 75  24  40   0   6  0.914286       1.0       0.800000  0.888889     ocsvm
# 76  24  39   0   7  0.900000       1.0       0.774194  0.872727     ocsvm
#
#    variacao atividade  semana
# 72    20-35    eating       1
# 73    20-35    eating       2
# 74    20-35    eating       3
# 75    20-35    eating       4
# 76    20-35    eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_eating_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#RCE

# %%
dfm_eating_rce = df_metricas[(df_metricas['atividade'] == "eating") & (df_metricas['algoritmo'] == "rce")]
print(dfm_eating_rce.shape)
dfm_eating_rce.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 126  23  38   1   8  0.871429  0.958333       0.741935  0.836364       rce
# 127   9  39  15   7  0.685714  0.375000       0.562500  0.450000       rce
# 128  24  39   0   7  0.900000  1.000000       0.774194  0.872727       rce
# 129  24  43   0   3  0.957143  1.000000       0.888889  0.941176       rce
# 130  12  43  12   3  0.785714  0.500000       0.800000  0.615385       rce
#
#     variacao atividade  semana
# 126    20-35    eating       1
# 127    20-35    eating       2
# 128    20-35    eating       3
# 129    20-35    eating       4
# 130    20-35    eating       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_eating_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## Atividade MealPreparation

# %%
#LOF

# %%
# mcoffe
dfm_mcoffe_lof = df_metricas[(df_metricas['atividade'] == "mcoffe") & (df_metricas['algoritmo'] == "lof")]
print(dfm_mcoffe_lof.shape)
dfm_mcoffe_lof.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 162  12  44  14   0  0.800000  0.461538         1.0000  0.631579       lof
# 163  13  44  13   0  0.814286  0.500000         1.0000  0.666667       lof
# 164  13  44  13   0  0.814286  0.500000         1.0000  0.666667       lof
# 165  16  44  10   0  0.857143  0.615385         1.0000  0.761905       lof
# 166  15  43  11   1  0.828571  0.576923         0.9375  0.714286       lof
#
#     variacao atividade  semana
# 162    20-35    mcoffe       1
# 163    20-35    mcoffe       2
# 164    20-35    mcoffe       3
# 165    20-35    mcoffe       4
# 166    20-35    mcoffe       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mcoffe_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#iFOREST

# %%
# mcoffe - IFOREST
dfm_mcoffe_if = df_metricas[(df_metricas['atividade'] == "mcoffe") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_mcoffe_if.shape)
dfm_mcoffe_if.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 180   8  36  18   8  0.628571  0.307692       0.500000  0.380952   iforest
# 181   1  40  25   4  0.585714  0.038462       0.200000  0.064516   iforest
# 182   3  40  23   4  0.614286  0.115385       0.428571  0.181818   iforest
# 183   1  41  25   3  0.600000  0.038462       0.250000  0.066667   iforest
# 184   2  41  24   3  0.614286  0.076923       0.400000  0.129032   iforest
#
#     variacao atividade  semana
# 180    20-35    mcoffe       1
# 181    20-35    mcoffe       2
# 182    20-35    mcoffe       3
# 183    20-35    mcoffe       4
# 184    20-35    mcoffe       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mcoffe_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# mcoffe - OCSVM
dfm_mcoffe_ocsvm = df_metricas[(df_metricas['atividade'] == "mcoffe") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_mcoffe_ocsvm.shape)
dfm_mcoffe_ocsvm.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 144  24  20   2  24  0.628571  0.923077       0.500000  0.648649     ocsvm
# 145  24  24   2  20  0.685714  0.923077       0.545455  0.685714     ocsvm
# 146  24  25   2  19  0.700000  0.923077       0.558140  0.695652     ocsvm
# 147  24  28   2  16  0.742857  0.923077       0.600000  0.727273     ocsvm
# 148  24  28   2  16  0.742857  0.923077       0.600000  0.727273     ocsvm
#
#     variacao atividade  semana
# 144    20-35    mcoffe       1
# 145    20-35    mcoffe       2
# 146    20-35    mcoffe       3
# 147    20-35    mcoffe       4
# 148    20-35    mcoffe       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mcoffe_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#RCE

# %%
# mcoffe - RCE
dfm_mcoffe_rce = df_metricas[(df_metricas['atividade'] == "mcoffe") & (df_metricas['algoritmo'] == "rce")]
print(dfm_mcoffe_rce.shape)
dfm_mcoffe_rce.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 198  16  23  10  21  0.557143  0.615385       0.432432  0.507937       rce
# 199  19  32   7  12  0.728571  0.730769       0.612903  0.666667       rce
# 200  14  42  12   2  0.800000  0.538462       0.875000  0.666667       rce
# 201  13  44  13   0  0.814286  0.500000       1.000000  0.666667       rce
# 202  15  44  11   0  0.842857  0.576923       1.000000  0.731707       rce
#
#     variacao atividade  semana
# 198    20-35    mcoffe       1
# 199    20-35    mcoffe       2
# 200    20-35    mcoffe       3
# 201    20-35    mcoffe       4
# 202    20-35    mcoffe       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mcoffe_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## Atividade mhotfood

# %%
#LOF

# %%
# mhotfood - LOF
dfm_mhotfood_lof = df_metricas[(df_metricas['atividade'] == "mhotfood") & (df_metricas['algoritmo'] == "lof")]
print(dfm_mhotfood_lof.shape)
dfm_mhotfood_lof.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 234  16  42  12   0  0.828571  0.571429       1.000000  0.727273       lof
# 235  16  42  12   0  0.828571  0.571429       1.000000  0.727273       lof
# 236  21  42   7   0  0.900000  0.750000       1.000000  0.857143       lof
# 237  28  39   0   3  0.957143  1.000000       0.903226  0.949153       lof
# 238  28  40   0   2  0.971429  1.000000       0.933333  0.965517       lof
#
#     variacao atividade  semana
# 234    20-35  mhotfood       1
# 235    20-35  mhotfood       2
# 236    20-35  mhotfood       3
# 237    20-35  mhotfood       4
# 238    20-35  mhotfood       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mhotfood_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#iFOREST

# %%
# mhotfood
dfm_mhotfood_if = df_metricas[(df_metricas['atividade'] == "mhotfood") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_mhotfood_if.shape)
dfm_mhotfood_if.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 252   8  27  20  15  0.500000  0.285714       0.347826  0.313725   iforest
# 253   8  32  20  10  0.571429  0.285714       0.444444  0.347826   iforest
# 254  15  34  13   8  0.700000  0.535714       0.652174  0.588235   iforest
# 255  10  34  18   8  0.628571  0.357143       0.555556  0.434783   iforest
# 256  15  36  13   6  0.728571  0.535714       0.714286  0.612245   iforest
#
#     variacao atividade  semana
# 252    20-35  mhotfood       1
# 253    20-35  mhotfood       2
# 254    20-35  mhotfood       3
# 255    20-35  mhotfood       4
# 256    20-35  mhotfood       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mhotfood_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
# Relax - OCSVM
dfm_mhotfood_ocsvm = df_metricas[(df_metricas['atividade'] == "mhotfood") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_mhotfood_ocsvm.shape)
dfm_mhotfood_ocsvm.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 216  28  20   0  22  0.685714       1.0       0.560000  0.717949     ocsvm
# 217  28  29   0  13  0.814286       1.0       0.682927  0.811594     ocsvm
# 218  28  33   0   9  0.871429       1.0       0.756757  0.861538     ocsvm
# 219  28  34   0   8  0.885714       1.0       0.777778  0.875000     ocsvm
# 220  28  38   0   4  0.942857       1.0       0.875000  0.933333     ocsvm
#
#     variacao atividade  semana
# 216    20-35  mhotfood       1
# 217    20-35  mhotfood       2
# 218    20-35  mhotfood       3
# 219    20-35  mhotfood       4
# 220    20-35  mhotfood       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mhotfood_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#RCE

# %%
# mhotfood - RCE
dfm_mhotfood_rce = df_metricas[(df_metricas['atividade'] == "mhotfood") & (df_metricas['algoritmo'] == "rce")]
print(dfm_mhotfood_rce.shape)
dfm_mhotfood_rce.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 270  28  32   0  10  0.857143  1.000000       0.736842  0.848485       rce
# 271  22  30   6  12  0.742857  0.785714       0.647059  0.709677       rce
# 272  21  37   7   5  0.828571  0.750000       0.807692  0.777778       rce
# 273  21  36   7   6  0.814286  0.750000       0.777778  0.763636       rce
# 274  21  37   7   5  0.828571  0.750000       0.807692  0.777778       rce
#
#     variacao atividade  semana
# 270    20-35  mhotfood       1
# 271    20-35  mhotfood       2
# 272    20-35  mhotfood       3
# 273    20-35  mhotfood       4
# 274    20-35  mhotfood       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_mhotfood_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## Atividade toileting

# %%
# toileting - LOF
dfm_toileting_lof = df_metricas[(df_metricas['atividade'] == "toileting") & (df_metricas['algoritmo'] == "lof")]
print(dfm_toileting_lof.shape)
dfm_toileting_lof.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 306  14  45  11   0  0.842857      0.56       1.000000  0.717949       lof
# 307  17  45   8   0  0.885714      0.68       1.000000  0.809524       lof
# 308  23  43   2   2  0.942857      0.92       0.920000  0.920000       lof
# 309  24  43   1   2  0.957143      0.96       0.923077  0.941176       lof
# 310  24  41   1   4  0.928571      0.96       0.857143  0.905660       lof
#
#     variacao  atividade  semana
# 306    20-35  toileting       1
# 307    20-35  toileting       2
# 308    20-35  toileting       3
# 309    20-35  toileting       4
# 310    20-35  toileting       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_toileting_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#iFOREST

# %%
# Sleeping - IFOREST
dfm_toileting_if = df_metricas[(df_metricas['atividade'] == "toileting") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_toileting_if.shape)
dfm_toileting_if.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 324   9  45  16   0  0.771429      0.36       1.000000  0.529412   iforest
# 325   8  43  17   2  0.728571      0.32       0.800000  0.457143   iforest
# 326   8  41  17   4  0.700000      0.32       0.666667  0.432432   iforest
# 327  21  41   4   4  0.885714      0.84       0.840000  0.840000   iforest
# 328  21  38   4   7  0.842857      0.84       0.750000  0.792453   iforest
#
#     variacao  atividade  semana
# 324    20-35  toileting       1
# 325    20-35  toileting       2
# 326    20-35  toileting       3
# 327    20-35  toileting       4
# 328    20-35  toileting       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_toileting_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
# toileting - OCSVM
dfm_toileting_ocsvm = df_metricas[(df_metricas['atividade'] == "toileting") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_toileting_ocsvm.shape)
dfm_toileting_ocsvm.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 288  25  30   0  15  0.785714       1.0       0.625000  0.769231     ocsvm
# 289  25  25   0  20  0.714286       1.0       0.555556  0.714286     ocsvm
# 290  25  26   0  19  0.728571       1.0       0.568182  0.724638     ocsvm
# 291  25  32   0  13  0.814286       1.0       0.657895  0.793651     ocsvm
# 292  25  34   0  11  0.842857       1.0       0.694444  0.819672     ocsvm
#
#     variacao  atividade  semana
# 288    20-35  toileting       1
# 289    20-35  toileting       2
# 290    20-35  toileting       3
# 291    20-35  toileting       4
# 292    20-35  toileting       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_toileting_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# RCE

# %%
# toileting - RCE
dfm_toileting_rce = df_metricas[(df_metricas['atividade'] == "toileting") & (df_metricas['algoritmo'] == "rce")]
print(dfm_toileting_rce.shape)
dfm_toileting_rce.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 342  23  44   2   1  0.957143      0.92       0.958333  0.938776       rce
# 343  25  44   0   1  0.985714      1.00       0.961538  0.980392       rce
# 344  25  44   0   1  0.985714      1.00       0.961538  0.980392       rce
# 345  24  37   1   8  0.871429      0.96       0.750000  0.842105       rce
# 346  24  36   1   9  0.857143      0.96       0.727273  0.827586       rce
#
#     variacao  atividade  semana
# 342    20-35  toileting       1
# 343    20-35  toileting       2
# 344    20-35  toileting       3
# 345    20-35  toileting       4
# 346    20-35  toileting       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_toileting_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## Atividade whandface

# %%
# whandface - LOF
dfm_whandface_lof = df_metricas[(df_metricas['atividade'] == "whandface") & (df_metricas['algoritmo'] == "lof")]
print(dfm_whandface_lof.shape)
dfm_whandface_lof.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 378  25  44   1   0  0.985714  0.961538       1.000000  0.980392       lof
# 379  25  44   1   0  0.985714  0.961538       1.000000  0.980392       lof
# 380  25  44   1   0  0.985714  0.961538       1.000000  0.980392       lof
# 381  25  44   1   0  0.985714  0.961538       1.000000  0.980392       lof
# 382  26  40   0   4  0.942857  1.000000       0.866667  0.928571       lof
#
#     variacao  atividade  semana
# 378    20-35  whandface       1
# 379    20-35  whandface       2
# 380    20-35  whandface       3
# 381    20-35  whandface       4
# 382    20-35  whandface       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_whandface_lof)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#iFOREST

# %%
# whandface - IFOREST
dfm_whandface_if = df_metricas[(df_metricas['atividade'] == "whandface") & (df_metricas['algoritmo'] == "iforest")]
print(dfm_whandface_if.shape)
dfm_whandface_if.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 396   5  42  21   2  0.671429  0.192308       0.714286  0.303030   iforest
# 397  20  36   6   8  0.800000  0.769231       0.714286  0.740741   iforest
# 398  21  34   5  10  0.785714  0.807692       0.677419  0.736842   iforest
# 399  22  35   4   9  0.814286  0.846154       0.709677  0.771930   iforest
# 400  24  34   2  10  0.828571  0.923077       0.705882  0.800000   iforest
#
#     variacao  atividade  semana
# 396    20-35  whandface       1
# 397    20-35  whandface       2
# 398    20-35  whandface       3
# 399    20-35  whandface       4
# 400    20-35  whandface       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_whandface_if)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
#OCSVM

# %%
# whandface - OCSVM
dfm_whandface_ocsvm = df_metricas[(df_metricas['atividade'] == "whandface") & (df_metricas['algoritmo'] == "ocsvm")]
print(dfm_whandface_ocsvm.shape)
dfm_whandface_ocsvm.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 360  26   8   0  36  0.485714       1.0       0.419355  0.590909     ocsvm
# 361  26  12   0  32  0.542857       1.0       0.448276  0.619048     ocsvm
# 362  26  16   0  28  0.600000       1.0       0.481481  0.650000     ocsvm
# 363  26  24   0  20  0.714286       1.0       0.565217  0.722222     ocsvm
# 364  26  26   0  18  0.742857       1.0       0.590909  0.742857     ocsvm
#
#     variacao  atividade  semana
# 360    20-35  whandface       1
# 361    20-35  whandface       2
# 362    20-35  whandface       3
# 363    20-35  whandface       4
# 364    20-35  whandface       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_whandface_ocsvm)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %%
# RCE

# %%
# whandface - RCE
dfm_whandface_rce = df_metricas[(df_metricas['atividade'] == "whandface") & (df_metricas['algoritmo'] == "rce")]
print(dfm_whandface_rce.shape)
dfm_whandface_rce.head()
# Out:
# (90, 12)
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 414  25  34   1  10  0.842857  0.961538       0.714286  0.819672       rce
# 415  26  33   0  11  0.842857  1.000000       0.702703  0.825397       rce
# 416  26  39   0   5  0.928571  1.000000       0.838710  0.912281       rce
# 417  26  36   0   8  0.885714  1.000000       0.764706  0.866667       rce
# 418  26  35   0   9  0.871429  1.000000       0.742857  0.852459       rce
#
#     variacao  atividade  semana
# 414    20-35  whandface       1
# 415    20-35  whandface       2
# 416    20-35  whandface       3
# 417    20-35  whandface       4
# 418    20-35  whandface       5

# %%
ax = sns.barplot(x="semana", y="acuracia", hue='variacao', data=dfm_whandface_rce)
ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
# Out:
# Text(0, 0.5, 'Acurácia')

# %% [markdown]
# ## EXTRACAO METRICAS

# %%
#CCLOTHES LOF
dfm_cclothes_lof_2035 = dfm_cclothes_lof[(dfm_cclothes_lof['variacao'] == "20-35")]
dfm_cclothes_lof_4055 = dfm_cclothes_lof[(dfm_cclothes_lof['variacao'] == "40-55")]
dfm_cclothes_lof_6075 = dfm_cclothes_lof[(dfm_cclothes_lof['variacao'] == "60-75")]
dfm_cclothes_lof_8095 = dfm_cclothes_lof[(dfm_cclothes_lof['variacao'] == "80-95")]
dfm_cclothes_lof_2095 = dfm_cclothes_lof[(dfm_cclothes_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_cc_lof.svg')

# %%
dfm_cclothes_lof_2035.head(18)
dfm_cclothes_lof_4055.head(18)
dfm_cclothes_lof_6075.head(18)
dfm_cclothes_lof_8095.head(18)
dfm_cclothes_lof_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1746  24  45   0   1  0.985714  1.000000       0.960000  0.979592       lof
# 1747  24  46   0   0  1.000000  1.000000       1.000000  1.000000       lof
# 1748  24  45   0   1  0.985714  1.000000       0.960000  0.979592       lof
# 1749  24  46   0   0  1.000000  1.000000       1.000000  1.000000       lof
# 1750  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
# 1751  24  41   0   5  0.928571  1.000000       0.827586  0.905660       lof
# 1752  24  38   0   8  0.885714  1.000000       0.750000  0.857143       lof
# 1753  24  37   0   9  0.871429  1.000000       0.727273  0.842105       lof
# 1754  24  36   0  10  0.857143  1.000000       0.705882  0.827586       lof
# 1755  24  34   0  12  0.828571  1.000000       0.666667  0.800000       lof
# 1756  24  35   0  11  0.842857  1.000000       0.685714  0.813559       lof
# ...

# %%
#CCLOTHES if
dfm_cclothes_if_2035 = dfm_cclothes_if[(dfm_cclothes_if['variacao'] == "20-35")]
dfm_cclothes_if_4055 = dfm_cclothes_if[(dfm_cclothes_if['variacao'] == "40-55")]
dfm_cclothes_if_6075 = dfm_cclothes_if[(dfm_cclothes_if['variacao'] == "60-75")]
dfm_cclothes_if_8095 = dfm_cclothes_if[(dfm_cclothes_if['variacao'] == "80-95")]
dfm_cclothes_if_2095 = dfm_cclothes_if[(dfm_cclothes_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_cc_if.svg')

# %%
dfm_cclothes_if_2035.head(18)
dfm_cclothes_if_4055.head(18)
dfm_cclothes_if_6075.head(18)
dfm_cclothes_if_8095.head(18)
dfm_cclothes_if_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1764   5  41  19   5  0.657143  0.208333       0.500000  0.294118   iforest
# 1765  13  43  11   3  0.800000  0.541667       0.812500  0.650000   iforest
# 1766  18  42   6   4  0.857143  0.750000       0.818182  0.782609   iforest
# 1767  20  44   4   2  0.914286  0.833333       0.909091  0.869565   iforest
# 1768  17  44   7   2  0.871429  0.708333       0.894737  0.790698   iforest
# 1769  24  39   0   7  0.900000  1.000000       0.774194  0.872727   iforest
# 1770  24  44   0   2  0.971429  1.000000       0.923077  0.960000   iforest
# 1771  24  44   0   2  0.971429  1.000000       0.923077  0.960000   iforest
# 1772  24  44   0   2  0.971429  1.000000       0.923077  0.960000   iforest
# 1773  24  43   0   3  0.957143  1.000000       0.888889  0.941176   iforest
# 1774  24  42   0   4  0.942857  1.000000       0.857143  0.923077   iforest
# ...

# %%
#CCLOTHES ocsvm
dfm_cclothes_ocsvm_2035 = dfm_cclothes_ocsvm[(dfm_cclothes_ocsvm['variacao'] == "20-35")]
dfm_cclothes_ocsvm_4055 = dfm_cclothes_ocsvm[(dfm_cclothes_ocsvm['variacao'] == "40-55")]
dfm_cclothes_ocsvm_6075 = dfm_cclothes_ocsvm[(dfm_cclothes_ocsvm['variacao'] == "60-75")]
dfm_cclothes_ocsvm_8095 = dfm_cclothes_ocsvm[(dfm_cclothes_ocsvm['variacao'] == "80-95")]
dfm_cclothes_ocsvm_2095 = dfm_cclothes_ocsvm[(dfm_cclothes_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_cc_oc.svg')

# %%
#CCLOTHES ocsvm
dfm_cclothes_ocsvm_2035.head(18)
dfm_cclothes_ocsvm_4055.head(18)
# dfm_cclothes_ocsvm_6075.head(18)
# dfm_cclothes_ocsvm_8095.head(18)
# dfm_cclothes_ocsvm_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 432  23  10   0  37  0.471429       1.0       0.383333  0.554217     ocsvm
# 433  23  20   0  27  0.614286       1.0       0.460000  0.630137     ocsvm
# 434  23  24   0  23  0.671429       1.0       0.500000  0.666667     ocsvm
# 435  23  31   0  16  0.771429       1.0       0.589744  0.741935     ocsvm
# 436  23  30   0  17  0.757143       1.0       0.575000  0.730159     ocsvm
# 437  23  30   0  17  0.757143       1.0       0.575000  0.730159     ocsvm
# 438  23  40   0   7  0.900000       1.0       0.766667  0.867925     ocsvm
# 439  23  38   0   9  0.871429       1.0       0.718750  0.836364     ocsvm
# 440  23  37   0  10  0.857143       1.0       0.696970  0.821429     ocsvm
# 441  23  37   0  10  0.857143       1.0       0.696970  0.821429     ocsvm
# 442  23  40   0   7  0.900000       1.0       0.766667  0.867925     ocsvm
# ...

# %%
#CCLOTHES rce
dfm_cclothes_rce_2035 = dfm_cclothes_rce[(dfm_cclothes_rce['variacao'] == "20-35")]
dfm_cclothes_rce_4055 = dfm_cclothes_rce[(dfm_cclothes_rce['variacao'] == "40-55")]
dfm_cclothes_rce_6075 = dfm_cclothes_rce[(dfm_cclothes_rce['variacao'] == "60-75")]
dfm_cclothes_rce_8095 = dfm_cclothes_rce[(dfm_cclothes_rce['variacao'] == "80-95")]
dfm_cclothes_rce_2095 = dfm_cclothes_rce[(dfm_cclothes_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_cclothes_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_cc_rce.svg')

# %%
#CCLOTHES rce
dfm_cclothes_rce_2035.head(18)
dfm_cclothes_rce_4055.head(18)
dfm_cclothes_rce_6075.head(18)
dfm_cclothes_rce_8095.head(18)
dfm_cclothes_rce_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1782  24  26   0  20  0.714286  1.000000       0.545455  0.705882       rce
# 1783  23  38   1   8  0.871429  0.958333       0.741935  0.836364       rce
# 1784  23  41   1   5  0.914286  0.958333       0.821429  0.884615       rce
# 1785  23  42   1   4  0.928571  0.958333       0.851852  0.901961       rce
# 1786  23  44   1   2  0.957143  0.958333       0.920000  0.938776       rce
# 1787  23  42   1   4  0.928571  0.958333       0.851852  0.901961       rce
# 1788  23  45   1   1  0.971429  0.958333       0.958333  0.958333       rce
# 1789  24  44   0   2  0.971429  1.000000       0.923077  0.960000       rce
# 1790  24  45   0   1  0.985714  1.000000       0.960000  0.979592       rce
# 1791  24  45   0   1  0.985714  1.000000       0.960000  0.979592       rce
# 1792  24  45   0   1  0.985714  1.000000       0.960000  0.979592       rce
# ...

# %%
#eating LOF
dfm_eating_lof_2035 = dfm_eating_lof[(dfm_eating_lof['variacao'] == "20-35")]
dfm_eating_lof_4055 = dfm_eating_lof[(dfm_eating_lof['variacao'] == "40-55")]
dfm_eating_lof_6075 = dfm_eating_lof[(dfm_eating_lof['variacao'] == "60-75")]
dfm_eating_lof_8095 = dfm_eating_lof[(dfm_eating_lof['variacao'] == "80-95")]
dfm_eating_lof_2095 = dfm_eating_lof[(dfm_eating_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_eat_lof.svg')

# %%
dfm_eating_lof_2035.head(18)
dfm_eating_lof_4055.head(18)
dfm_eating_lof_6075.head(18)
dfm_eating_lof_8095.head(18)
dfm_eating_lof_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1818  16  46   8   0  0.885714  0.666667       1.000000  0.800000       lof
# 1819  24  46   0   0  1.000000  1.000000       1.000000  1.000000       lof
# 1820  24  44   0   2  0.971429  1.000000       0.923077  0.960000       lof
# 1821  24  42   0   4  0.942857  1.000000       0.857143  0.923077       lof
# 1822  24  42   0   4  0.942857  1.000000       0.857143  0.923077       lof
# 1823  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
# 1824  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
# 1825  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
# 1826  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
# 1827  24  43   0   3  0.957143  1.000000       0.888889  0.941176       lof
# 1828  24  41   0   5  0.928571  1.000000       0.827586  0.905660       lof
# ...

# %%
#eating if
dfm_eating_if_2035 = dfm_eating_if[(dfm_eating_if['variacao'] == "20-35")]
dfm_eating_if_4055 = dfm_eating_if[(dfm_eating_if['variacao'] == "40-55")]
dfm_eating_if_6075 = dfm_eating_if[(dfm_eating_if['variacao'] == "60-75")]
dfm_eating_if_8095 = dfm_eating_if[(dfm_eating_if['variacao'] == "80-95")]
dfm_eating_if_2095 = dfm_eating_if[(dfm_eating_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_eat_if.svg')

# %%
dfm_eating_if_2035.head(18)
# dfm_eating_if_4055.head(18)
# dfm_eating_if_6075.head(18)
# dfm_eating_if_8095.head(18)
# dfm_eating_if_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 108   0  41  24   5  0.585714  0.000000       0.000000  0.000000   iforest
# 109  22  38   2   8  0.857143  0.916667       0.733333  0.814815   iforest
# 110  15  38   9   8  0.757143  0.625000       0.652174  0.638298   iforest
# 111  17  43   7   3  0.857143  0.708333       0.850000  0.772727   iforest
# 112  17  41   7   5  0.828571  0.708333       0.772727  0.739130   iforest
# 113  22  39   2   7  0.871429  0.916667       0.758621  0.830189   iforest
# 114  24  40   0   6  0.914286  1.000000       0.800000  0.888889   iforest
# 115  24  41   0   5  0.928571  1.000000       0.827586  0.905660   iforest
# 116  24  41   0   5  0.928571  1.000000       0.827586  0.905660   iforest
# 117  24  40   0   6  0.914286  1.000000       0.800000  0.888889   iforest
# 118  24  40   0   6  0.914286  1.000000       0.800000  0.888889   iforest
# ...

# %%
#eating ocsvm
dfm_eating_ocsvm_2035 = dfm_eating_ocsvm[(dfm_eating_ocsvm['variacao'] == "20-35")]
dfm_eating_ocsvm_4055 = dfm_eating_ocsvm[(dfm_eating_ocsvm['variacao'] == "40-55")]
dfm_eating_ocsvm_6075 = dfm_eating_ocsvm[(dfm_eating_ocsvm['variacao'] == "60-75")]
dfm_eating_ocsvm_8095 = dfm_eating_ocsvm[(dfm_eating_ocsvm['variacao'] == "80-95")]
dfm_eating_ocsvm_2095 = dfm_eating_ocsvm[(dfm_eating_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_eat_oc.svg')

# %%
dfm_eating_ocsvm_2035.head(18)
# dfm_eating_ocsvm_4055.head(18)
# dfm_eating_ocsvm_6075.head(18)
# dfm_eating_ocsvm_8095.head(18)
# dfm_eating_ocsvm_2095.head(18)
# Out:
#     vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 72  24  33   0  13  0.814286       1.0       0.648649  0.786885     ocsvm
# 73  24  34   0  12  0.828571       1.0       0.666667  0.800000     ocsvm
# 74  24  38   0   8  0.885714       1.0       0.750000  0.857143     ocsvm
# 75  24  40   0   6  0.914286       1.0       0.800000  0.888889     ocsvm
# 76  24  39   0   7  0.900000       1.0       0.774194  0.872727     ocsvm
# 77  24  42   0   4  0.942857       1.0       0.857143  0.923077     ocsvm
# 78  24  42   0   4  0.942857       1.0       0.857143  0.923077     ocsvm
# 79  24  36   0  10  0.857143       1.0       0.705882  0.827586     ocsvm
# 80  24  41   0   5  0.928571       1.0       0.827586  0.905660     ocsvm
# 81  24  40   0   6  0.914286       1.0       0.800000  0.888889     ocsvm
# 82  24  41   0   5  0.928571       1.0       0.827586  0.905660     ocsvm
# 83  24  41   0   5  0.928571       1.0       0.827586  0.905660     ocsvm
# ...

# %%
#eating rce
dfm_eating_rce_2035 = dfm_eating_rce[(dfm_eating_rce['variacao'] == "20-35")]
dfm_eating_rce_4055 = dfm_eating_rce[(dfm_eating_rce['variacao'] == "40-55")]
dfm_eating_rce_6075 = dfm_eating_rce[(dfm_eating_rce['variacao'] == "60-75")]
dfm_eating_rce_8095 = dfm_eating_rce[(dfm_eating_rce['variacao'] == "80-95")]
dfm_eating_rce_2095 = dfm_eating_rce[(dfm_eating_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_eating_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_eat_rce.svg')

# %%
#eating rce
dfm_eating_rce_2035.head(18)
dfm_eating_rce_4055.head(18)
dfm_eating_rce_6075.head(18)
dfm_eating_rce_8095.head(18)
dfm_eating_rce_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1854  24  38   0   8  0.885714  1.000000       0.750000  0.857143       rce
# 1855  22  37   2   9  0.842857  0.916667       0.709677  0.800000       rce
# 1856  24  37   0   9  0.871429  1.000000       0.727273  0.842105       rce
# 1857  24  42   0   4  0.942857  1.000000       0.857143  0.923077       rce
# 1858  24  42   0   4  0.942857  1.000000       0.857143  0.923077       rce
# 1859  24  41   0   5  0.928571  1.000000       0.827586  0.905660       rce
# 1860  24  41   0   5  0.928571  1.000000       0.827586  0.905660       rce
# 1861  24  41   0   5  0.928571  1.000000       0.827586  0.905660       rce
# 1862  24  41   0   5  0.928571  1.000000       0.827586  0.905660       rce
# 1863  24  41   0   5  0.928571  1.000000       0.827586  0.905660       rce
# 1864  24  41   0   5  0.928571  1.000000       0.827586  0.905660       rce
# ...

# %%
#mcoffe LOF
dfm_mcoffe_lof_2035 = dfm_mcoffe_lof[(dfm_mcoffe_lof['variacao'] == "20-35")]
dfm_mcoffe_lof_4055 = dfm_mcoffe_lof[(dfm_mcoffe_lof['variacao'] == "40-55")]
dfm_mcoffe_lof_6075 = dfm_mcoffe_lof[(dfm_mcoffe_lof['variacao'] == "60-75")]
dfm_mcoffe_lof_8095 = dfm_mcoffe_lof[(dfm_mcoffe_lof['variacao'] == "80-95")]
dfm_mcoffe_lof_2095 = dfm_mcoffe_lof[(dfm_mcoffe_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mcof_lof.svg')

# %%
dfm_mcoffe_lof_2035.head(18)
dfm_mcoffe_lof_4055.head(18)
dfm_mcoffe_lof_6075.head(18)
dfm_mcoffe_lof_8095.head(18)
dfm_mcoffe_lof_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1890  17  46   7   0  0.900000  0.708333       1.000000  0.829268       lof
# 1891  20  46   4   0  0.942857  0.833333       1.000000  0.909091       lof
# 1892  20  46   4   0  0.942857  0.833333       1.000000  0.909091       lof
# 1893  21  46   3   0  0.957143  0.875000       1.000000  0.933333       lof
# 1894  21  45   3   1  0.942857  0.875000       0.954545  0.913043       lof
# 1895  21  43   3   3  0.914286  0.875000       0.875000  0.875000       lof
# 1896  21  43   3   3  0.914286  0.875000       0.875000  0.875000       lof
# 1897  21  42   3   4  0.900000  0.875000       0.840000  0.857143       lof
# 1898  21  43   3   3  0.914286  0.875000       0.875000  0.875000       lof
# 1899  21  42   3   4  0.900000  0.875000       0.840000  0.857143       lof
# 1900  21  41   3   5  0.885714  0.875000       0.807692  0.840000       lof
# ...

# %%
#mcoffe if
dfm_mcoffe_if_2035 = dfm_mcoffe_if[(dfm_mcoffe_if['variacao'] == "20-35")]
dfm_mcoffe_if_4055 = dfm_mcoffe_if[(dfm_mcoffe_if['variacao'] == "40-55")]
dfm_mcoffe_if_6075 = dfm_mcoffe_if[(dfm_mcoffe_if['variacao'] == "60-75")]
dfm_mcoffe_if_8095 = dfm_mcoffe_if[(dfm_mcoffe_if['variacao'] == "80-95")]
dfm_mcoffe_if_2095 = dfm_mcoffe_if[(dfm_mcoffe_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mcof_if.svg')

# %%
dfm_mcoffe_if_2035.head(18)
# dfm_mcoffe_if_4055.head(18)
# dfm_mcoffe_if_6075.head(18)
# dfm_mcoffe_if_8095.head(18)
# dfm_mcoffe_if_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 180   8  36  18   8  0.628571  0.307692       0.500000  0.380952   iforest
# 181   1  40  25   4  0.585714  0.038462       0.200000  0.064516   iforest
# 182   3  40  23   4  0.614286  0.115385       0.428571  0.181818   iforest
# 183   1  41  25   3  0.600000  0.038462       0.250000  0.066667   iforest
# 184   2  41  24   3  0.614286  0.076923       0.400000  0.129032   iforest
# 185   2  41  24   3  0.614286  0.076923       0.400000  0.129032   iforest
# 186  11  42  15   2  0.757143  0.423077       0.846154  0.564103   iforest
# 187  13  42  13   2  0.785714  0.500000       0.866667  0.634146   iforest
# 188  19  39   7   5  0.828571  0.730769       0.791667  0.760000   iforest
# 189  19  41   7   3  0.857143  0.730769       0.863636  0.791667   iforest
# 190  19  43   7   1  0.885714  0.730769       0.950000  0.826087   iforest
# ...

# %%
#mcoffe ocsvm
dfm_mcoffe_ocsvm_2035 = dfm_mcoffe_ocsvm[(dfm_mcoffe_ocsvm['variacao'] == "20-35")]
dfm_mcoffe_ocsvm_4055 = dfm_mcoffe_ocsvm[(dfm_mcoffe_ocsvm['variacao'] == "40-55")]
dfm_mcoffe_ocsvm_6075 = dfm_mcoffe_ocsvm[(dfm_mcoffe_ocsvm['variacao'] == "60-75")]
dfm_mcoffe_ocsvm_8095 = dfm_mcoffe_ocsvm[(dfm_mcoffe_ocsvm['variacao'] == "80-95")]
dfm_mcoffe_ocsvm_2095 = dfm_mcoffe_ocsvm[(dfm_mcoffe_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mcof_oc.svg')

# %%
dfm_mcoffe_ocsvm_2035.head(18)
# dfm_mcoffe_ocsvm_4055.head(18)
# dfm_mcoffe_ocsvm_6075.head(18)
# dfm_mcoffe_ocsvm_8095.head(18)
# dfm_mcoffe_ocsvm_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 144  24  20   2  24  0.628571  0.923077       0.500000  0.648649     ocsvm
# 145  24  24   2  20  0.685714  0.923077       0.545455  0.685714     ocsvm
# 146  24  25   2  19  0.700000  0.923077       0.558140  0.695652     ocsvm
# 147  24  28   2  16  0.742857  0.923077       0.600000  0.727273     ocsvm
# 148  24  28   2  16  0.742857  0.923077       0.600000  0.727273     ocsvm
# 149  24  29   2  15  0.757143  0.923077       0.615385  0.738462     ocsvm
# 150  24  35   2   9  0.842857  0.923077       0.727273  0.813559     ocsvm
# 151  24  36   2   8  0.857143  0.923077       0.750000  0.827586     ocsvm
# 152  21  35   5   9  0.800000  0.807692       0.700000  0.750000     ocsvm
# 153  21  36   5   8  0.814286  0.807692       0.724138  0.763636     ocsvm
# 154  21  40   5   4  0.871429  0.807692       0.840000  0.823529     ocsvm
# ...

# %%
#mcoffe rce
dfm_mcoffe_rce_2035 = dfm_mcoffe_rce[(dfm_mcoffe_rce['variacao'] == "20-35")]
dfm_mcoffe_rce_4055 = dfm_mcoffe_rce[(dfm_mcoffe_rce['variacao'] == "40-55")]
dfm_mcoffe_rce_6075 = dfm_mcoffe_rce[(dfm_mcoffe_rce['variacao'] == "60-75")]
dfm_mcoffe_rce_8095 = dfm_mcoffe_rce[(dfm_mcoffe_rce['variacao'] == "80-95")]
dfm_mcoffe_rce_2095 = dfm_mcoffe_rce[(dfm_mcoffe_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mcoffe_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mcof_rce.svg')

# %%
dfm_mcoffe_rce_2035.head(18)
dfm_mcoffe_rce_4055.head(18)
dfm_mcoffe_rce_6075.head(18)
dfm_mcoffe_rce_8095.head(18)
dfm_mcoffe_rce_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1926  24  24   0  22  0.685714  1.000000       0.521739  0.685714       rce
# 1927  24  33   0  13  0.814286  1.000000       0.648649  0.786885       rce
# 1928  24  43   0   3  0.957143  1.000000       0.888889  0.941176       rce
# 1929  24  45   0   1  0.985714  1.000000       0.960000  0.979592       rce
# 1930  24  46   0   0  1.000000  1.000000       1.000000  1.000000       rce
# 1931  24  45   0   1  0.985714  1.000000       0.960000  0.979592       rce
# 1932  23  45   1   1  0.971429  0.958333       0.958333  0.958333       rce
# 1933  23  45   1   1  0.971429  0.958333       0.958333  0.958333       rce
# 1934  23  45   1   1  0.971429  0.958333       0.958333  0.958333       rce
# 1935  24  45   0   1  0.985714  1.000000       0.960000  0.979592       rce
# 1936  23  45   1   1  0.971429  0.958333       0.958333  0.958333       rce
# ...

# %%
#mhotfood LOF
dfm_mhotfood_lof_2035 = dfm_mhotfood_lof[(dfm_mhotfood_lof['variacao'] == "20-35")]
dfm_mhotfood_lof_4055 = dfm_mhotfood_lof[(dfm_mhotfood_lof['variacao'] == "40-55")]
dfm_mhotfood_lof_6075 = dfm_mhotfood_lof[(dfm_mhotfood_lof['variacao'] == "60-75")]
dfm_mhotfood_lof_8095 = dfm_mhotfood_lof[(dfm_mhotfood_lof['variacao'] == "80-95")]
dfm_mhotfood_lof_2095 = dfm_mhotfood_lof[(dfm_mhotfood_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mhot_lof.svg')

# %%
dfm_mhotfood_lof_2035.head(18)
dfm_mhotfood_lof_4055.head(18)
dfm_mhotfood_lof_6075.head(18)
dfm_mhotfood_lof_8095.head(18)
dfm_mhotfood_lof_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1962  25  45   0   0  1.000000       1.0       1.000000  1.000000       lof
# 1963  25  45   0   0  1.000000       1.0       1.000000  1.000000       lof
# 1964  25  44   0   1  0.985714       1.0       0.961538  0.980392       lof
# 1965  25  40   0   5  0.928571       1.0       0.833333  0.909091       lof
# 1966  25  41   0   4  0.942857       1.0       0.862069  0.925926       lof
# 1967  25  41   0   4  0.942857       1.0       0.862069  0.925926       lof
# 1968  25  40   0   5  0.928571       1.0       0.833333  0.909091       lof
# 1969  25  38   0   7  0.900000       1.0       0.781250  0.877193       lof
# 1970  25  40   0   5  0.928571       1.0       0.833333  0.909091       lof
# 1971  25  39   0   6  0.914286       1.0       0.806452  0.892857       lof
# 1972  25  41   0   4  0.942857       1.0       0.862069  0.925926       lof
# ...

# %%
#mhotfood if
dfm_mhotfood_if_2035 = dfm_mhotfood_if[(dfm_mhotfood_if['variacao'] == "20-35")]
dfm_mhotfood_if_4055 = dfm_mhotfood_if[(dfm_mhotfood_if['variacao'] == "40-55")]
dfm_mhotfood_if_6075 = dfm_mhotfood_if[(dfm_mhotfood_if['variacao'] == "60-75")]
dfm_mhotfood_if_8095 = dfm_mhotfood_if[(dfm_mhotfood_if['variacao'] == "80-95")]
dfm_mhotfood_if_2095 = dfm_mhotfood_if[(dfm_mhotfood_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mhot_if.svg')

# %%
#mhotfood if
dfm_mhotfood_if_2035.head(18)
dfm_mhotfood_if_4055.head(18)
# dfm_mhotfood_if_6075.head(18)
# dfm_mhotfood_if_8095.head(18)
# dfm_mhotfood_if_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 684  10  29  17  14  0.557143  0.370370       0.416667  0.392157   iforest
# 685  10  33  17  10  0.614286  0.370370       0.500000  0.425532   iforest
# 686  20  36   7   7  0.800000  0.740741       0.740741  0.740741   iforest
# 687  15  36  12   7  0.728571  0.555556       0.681818  0.612245   iforest
# 688  22  37   5   6  0.842857  0.814815       0.785714  0.800000   iforest
# 689  22  37   5   6  0.842857  0.814815       0.785714  0.800000   iforest
# 690  23  37   4   6  0.857143  0.851852       0.793103  0.821429   iforest
# 691  23  37   4   6  0.857143  0.851852       0.793103  0.821429   iforest
# 692  23  37   4   6  0.857143  0.851852       0.793103  0.821429   iforest
# 693  22  37   5   6  0.842857  0.814815       0.785714  0.800000   iforest
# 694  23  37   4   6  0.857143  0.851852       0.793103  0.821429   iforest
# ...

# %%
#mhotfood ocsvm
dfm_mhotfood_ocsvm_2035 = dfm_mhotfood_ocsvm[(dfm_mhotfood_ocsvm['variacao'] == "20-35")]
dfm_mhotfood_ocsvm_4055 = dfm_mhotfood_ocsvm[(dfm_mhotfood_ocsvm['variacao'] == "40-55")]
dfm_mhotfood_ocsvm_6075 = dfm_mhotfood_ocsvm[(dfm_mhotfood_ocsvm['variacao'] == "60-75")]
dfm_mhotfood_ocsvm_8095 = dfm_mhotfood_ocsvm[(dfm_mhotfood_ocsvm['variacao'] == "80-95")]
dfm_mhotfood_ocsvm_2095 = dfm_mhotfood_ocsvm[(dfm_mhotfood_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mhot_oc.svg')

# %%
dfm_mhotfood_ocsvm_2035.head(18)
# dfm_mhotfood_ocsvm_4055.head(18)
# dfm_mhotfood_ocsvm_6075.head(18)
# dfm_mhotfood_ocsvm_8095.head(18)
# dfm_mhotfood_ocsvm_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 216  28  20   0  22  0.685714       1.0       0.560000  0.717949     ocsvm
# 217  28  29   0  13  0.814286       1.0       0.682927  0.811594     ocsvm
# 218  28  33   0   9  0.871429       1.0       0.756757  0.861538     ocsvm
# 219  28  34   0   8  0.885714       1.0       0.777778  0.875000     ocsvm
# 220  28  38   0   4  0.942857       1.0       0.875000  0.933333     ocsvm
# 221  28  38   0   4  0.942857       1.0       0.875000  0.933333     ocsvm
# 222  28  38   0   4  0.942857       1.0       0.875000  0.933333     ocsvm
# 223  28  34   0   8  0.885714       1.0       0.777778  0.875000     ocsvm
# 224  28  36   0   6  0.914286       1.0       0.823529  0.903226     ocsvm
# 225  28  37   0   5  0.928571       1.0       0.848485  0.918033     ocsvm
# 226  28  37   0   5  0.928571       1.0       0.848485  0.918033     ocsvm
# ...

# %%
#mhotfood rce
dfm_mhotfood_rce_2035 = dfm_mhotfood_rce[(dfm_mhotfood_rce['variacao'] == "20-35")]
dfm_mhotfood_rce_4055 = dfm_mhotfood_rce[(dfm_mhotfood_rce['variacao'] == "40-55")]
dfm_mhotfood_rce_6075 = dfm_mhotfood_rce[(dfm_mhotfood_rce['variacao'] == "60-75")]
dfm_mhotfood_rce_8095 = dfm_mhotfood_rce[(dfm_mhotfood_rce['variacao'] == "80-95")]
dfm_mhotfood_rce_2095 = dfm_mhotfood_rce[(dfm_mhotfood_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_mhotfood_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_mhot_rce.svg')

# %%
dfm_mhotfood_rce_2035.head(18)
dfm_mhotfood_rce_4055.head(18)
dfm_mhotfood_rce_6075.head(18)
dfm_mhotfood_rce_8095.head(18)
dfm_mhotfood_rce_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 1998  25  34   0  11  0.842857      1.00       0.694444  0.819672       rce
# 1999  24  32   1  13  0.800000      0.96       0.648649  0.774194       rce
# 2000  25  40   0   5  0.928571      1.00       0.833333  0.909091       rce
# 2001  25  39   0   6  0.914286      1.00       0.806452  0.892857       rce
# 2002  25  40   0   5  0.928571      1.00       0.833333  0.909091       rce
# 2003  25  39   0   6  0.914286      1.00       0.806452  0.892857       rce
# 2004  25  40   0   5  0.928571      1.00       0.833333  0.909091       rce
# 2005  25  35   0  10  0.857143      1.00       0.714286  0.833333       rce
# 2006  25  36   0   9  0.871429      1.00       0.735294  0.847458       rce
# 2007  25  35   0  10  0.857143      1.00       0.714286  0.833333       rce
# 2008  25  36   0   9  0.871429      1.00       0.735294  0.847458       rce
# ...

# %%
#toileting LOF
dfm_toileting_lof_2035 = dfm_toileting_lof[(dfm_toileting_lof['variacao'] == "20-35")]
dfm_toileting_lof_4055 = dfm_toileting_lof[(dfm_toileting_lof['variacao'] == "40-55")]
dfm_toileting_lof_6075 = dfm_toileting_lof[(dfm_toileting_lof['variacao'] == "60-75")]
dfm_toileting_lof_8095 = dfm_toileting_lof[(dfm_toileting_lof['variacao'] == "80-95")]
dfm_toileting_lof_2095 = dfm_toileting_lof[(dfm_toileting_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_toi_lof.svg')

# %%
dfm_toileting_lof_2035.head(18)
dfm_toileting_lof_4055.head(18)
dfm_toileting_lof_6075.head(18)
dfm_toileting_lof_8095.head(18)
dfm_toileting_lof_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 2034  21  42   7   0  0.900000  0.750000       1.000000  0.857143       lof
# 2035  21  42   7   0  0.900000  0.750000       1.000000  0.857143       lof
# 2036  25  41   3   1  0.942857  0.892857       0.961538  0.925926       lof
# 2037  25  41   3   1  0.942857  0.892857       0.961538  0.925926       lof
# 2038  27  39   1   3  0.942857  0.964286       0.900000  0.931034       lof
# 2039  26  40   2   2  0.942857  0.928571       0.928571  0.928571       lof
# 2040  27  39   1   3  0.942857  0.964286       0.900000  0.931034       lof
# 2041  25  40   3   2  0.928571  0.892857       0.925926  0.909091       lof
# 2042  27  39   1   3  0.942857  0.964286       0.900000  0.931034       lof
# 2043  24  41   4   1  0.928571  0.857143       0.960000  0.905660       lof
# 2044  24  41   4   1  0.928571  0.857143       0.960000  0.905660       lof
# ...

# %%
#toileting if
dfm_toileting_if_2035 = dfm_toileting_if[(dfm_toileting_if['variacao'] == "20-35")]
dfm_toileting_if_4055 = dfm_toileting_if[(dfm_toileting_if['variacao'] == "40-55")]
dfm_toileting_if_6075 = dfm_toileting_if[(dfm_toileting_if['variacao'] == "60-75")]
dfm_toileting_if_8095 = dfm_toileting_if[(dfm_toileting_if['variacao'] == "80-95")]
dfm_toileting_if_2095 = dfm_toileting_if[(dfm_toileting_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_toi_if.svg')

# %%
dfm_toileting_if_2035.head(18)
# dfm_toileting_if_4055.head(18)
# dfm_toileting_if_6075.head(18)
# dfm_toileting_if_8095.head(18)
# dfm_toileting_if_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 324   9  45  16   0  0.771429      0.36       1.000000  0.529412   iforest
# 325   8  43  17   2  0.728571      0.32       0.800000  0.457143   iforest
# 326   8  41  17   4  0.700000      0.32       0.666667  0.432432   iforest
# 327  21  41   4   4  0.885714      0.84       0.840000  0.840000   iforest
# 328  21  38   4   7  0.842857      0.84       0.750000  0.792453   iforest
# 329  20  41   5   4  0.871429      0.80       0.833333  0.816327   iforest
# 330  21  42   4   3  0.900000      0.84       0.875000  0.857143   iforest
# 331  21  40   4   5  0.871429      0.84       0.807692  0.823529   iforest
# 332  21  38   4   7  0.842857      0.84       0.750000  0.792453   iforest
# 333  24  39   1   6  0.900000      0.96       0.800000  0.872727   iforest
# 334  24  40   1   5  0.914286      0.96       0.827586  0.888889   iforest
# ...

# %%
#toileting ocsvm
dfm_toileting_ocsvm_2035 = dfm_toileting_ocsvm[(dfm_toileting_ocsvm['variacao'] == "20-35")]
dfm_toileting_ocsvm_4055 = dfm_toileting_ocsvm[(dfm_toileting_ocsvm['variacao'] == "40-55")]
dfm_toileting_ocsvm_6075 = dfm_toileting_ocsvm[(dfm_toileting_ocsvm['variacao'] == "60-75")]
dfm_toileting_ocsvm_8095 = dfm_toileting_ocsvm[(dfm_toileting_ocsvm['variacao'] == "80-95")]
dfm_toileting_ocsvm_2095 = dfm_toileting_ocsvm[(dfm_toileting_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_toi_oc.svg')

# %%
dfm_toileting_ocsvm_2035.head(18)
# dfm_toileting_ocsvm_4055.head(18)
# dfm_toileting_ocsvm_6075.head(18)
# dfm_toileting_ocsvm_8095.head(18)
# dfm_toileting_ocsvm_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 288  25  30   0  15  0.785714       1.0       0.625000  0.769231     ocsvm
# 289  25  25   0  20  0.714286       1.0       0.555556  0.714286     ocsvm
# 290  25  26   0  19  0.728571       1.0       0.568182  0.724638     ocsvm
# 291  25  32   0  13  0.814286       1.0       0.657895  0.793651     ocsvm
# 292  25  34   0  11  0.842857       1.0       0.694444  0.819672     ocsvm
# 293  25  30   0  15  0.785714       1.0       0.625000  0.769231     ocsvm
# 294  25  36   0   9  0.871429       1.0       0.735294  0.847458     ocsvm
# 295  25  36   0   9  0.871429       1.0       0.735294  0.847458     ocsvm
# 296  25  34   0  11  0.842857       1.0       0.694444  0.819672     ocsvm
# 297  25  34   0  11  0.842857       1.0       0.694444  0.819672     ocsvm
# 298  25  30   0  15  0.785714       1.0       0.625000  0.769231     ocsvm
# ...

# %%
#toileting rce
dfm_toileting_rce_2035 = dfm_toileting_rce[(dfm_toileting_rce['variacao'] == "20-35")]
dfm_toileting_rce_4055 = dfm_toileting_rce[(dfm_toileting_rce['variacao'] == "40-55")]
dfm_toileting_rce_6075 = dfm_toileting_rce[(dfm_toileting_rce['variacao'] == "60-75")]
dfm_toileting_rce_8095 = dfm_toileting_rce[(dfm_toileting_rce['variacao'] == "80-95")]
dfm_toileting_rce_2095 = dfm_toileting_rce[(dfm_toileting_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_toileting_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_toi_rce.svg')

# %%
dfm_toileting_rce_2035.head(18)
dfm_toileting_rce_4055.head(18)
dfm_toileting_rce_6075.head(18)
dfm_toileting_rce_8095.head(18)
dfm_toileting_rce_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 2070  22  41   6   1  0.900000  0.785714       0.956522  0.862745       rce
# 2071  25  41   3   1  0.942857  0.892857       0.961538  0.925926       rce
# 2072  24  41   4   1  0.928571  0.857143       0.960000  0.905660       rce
# 2073  26  38   2   4  0.914286  0.928571       0.866667  0.896552       rce
# 2074  26  36   2   6  0.885714  0.928571       0.812500  0.866667       rce
# 2075  26  39   2   3  0.928571  0.928571       0.896552  0.912281       rce
# 2076  26  40   2   2  0.942857  0.928571       0.928571  0.928571       rce
# 2077  26  39   2   3  0.928571  0.928571       0.896552  0.912281       rce
# 2078  26  39   2   3  0.928571  0.928571       0.896552  0.912281       rce
# 2079  24  41   4   1  0.928571  0.857143       0.960000  0.905660       rce
# 2080  24  41   4   1  0.928571  0.857143       0.960000  0.905660       rce
# ...

# %%
#whandface LOF
dfm_whandface_lof_2035 = dfm_whandface_lof[(dfm_whandface_lof['variacao'] == "20-35")]
dfm_whandface_lof_4055 = dfm_whandface_lof[(dfm_whandface_lof['variacao'] == "40-55")]
dfm_whandface_lof_6075 = dfm_whandface_lof[(dfm_whandface_lof['variacao'] == "60-75")]
dfm_whandface_lof_8095 = dfm_whandface_lof[(dfm_whandface_lof['variacao'] == "80-95")]
dfm_whandface_lof_2095 = dfm_whandface_lof[(dfm_whandface_lof['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_lof_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_lof_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_lof_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_lof_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_lof_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_whf_lof.svg')

# %%
dfm_whandface_lof_2035.head(18)
dfm_whandface_lof_4055.head(18)
dfm_whandface_lof_6075.head(18)
dfm_whandface_lof_8095.head(18)
dfm_whandface_lof_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 2106  25  40   5   0  0.928571  0.833333       1.000000  0.909091       lof
# 2107  26  40   4   0  0.942857  0.866667       1.000000  0.928571       lof
# 2108  26  40   4   0  0.942857  0.866667       1.000000  0.928571       lof
# 2109  27  40   3   0  0.957143  0.900000       1.000000  0.947368       lof
# 2110  28  35   2   5  0.900000  0.933333       0.848485  0.888889       lof
# 2111  28  37   2   3  0.928571  0.933333       0.903226  0.918033       lof
# 2112  28  35   2   5  0.900000  0.933333       0.848485  0.888889       lof
# 2113  28  35   2   5  0.900000  0.933333       0.848485  0.888889       lof
# 2114  28  35   2   5  0.900000  0.933333       0.848485  0.888889       lof
# 2115  28  35   2   5  0.900000  0.933333       0.848485  0.888889       lof
# 2116  28  35   2   5  0.900000  0.933333       0.848485  0.888889       lof
# ...

# %%
#whandface if
dfm_whandface_if_2035 = dfm_whandface_if[(dfm_whandface_if['variacao'] == "20-35")]
dfm_whandface_if_4055 = dfm_whandface_if[(dfm_whandface_if['variacao'] == "40-55")]
dfm_whandface_if_6075 = dfm_whandface_if[(dfm_whandface_if['variacao'] == "60-75")]
dfm_whandface_if_8095 = dfm_whandface_if[(dfm_whandface_if['variacao'] == "80-95")]
dfm_whandface_if_2095 = dfm_whandface_if[(dfm_whandface_if['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_if_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_if_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_if_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_if_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_if_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_whf_if.svg')

# %%
dfm_whandface_if_2035.head(18)
# dfm_whandface_if_4055.head(18)
# dfm_whandface_if_6075.head(18)
# dfm_whandface_if_8095.head(18)
# dfm_whandface_if_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 396   5  42  21   2  0.671429  0.192308       0.714286  0.303030   iforest
# 397  20  36   6   8  0.800000  0.769231       0.714286  0.740741   iforest
# 398  21  34   5  10  0.785714  0.807692       0.677419  0.736842   iforest
# 399  22  35   4   9  0.814286  0.846154       0.709677  0.771930   iforest
# 400  24  34   2  10  0.828571  0.923077       0.705882  0.800000   iforest
# 401  26  38   0   6  0.914286  1.000000       0.812500  0.896552   iforest
# 402  26  37   0   7  0.900000  1.000000       0.787879  0.881356   iforest
# 403  25  39   1   5  0.914286  0.961538       0.833333  0.892857   iforest
# 404  26  36   0   8  0.885714  1.000000       0.764706  0.866667   iforest
# 405  26  38   0   6  0.914286  1.000000       0.812500  0.896552   iforest
# 406  26  39   0   5  0.928571  1.000000       0.838710  0.912281   iforest
# ...

# %%
#whandface ocsvm
dfm_whandface_ocsvm_2035 = dfm_whandface_ocsvm[(dfm_whandface_ocsvm['variacao'] == "20-35")]
dfm_whandface_ocsvm_4055 = dfm_whandface_ocsvm[(dfm_whandface_ocsvm['variacao'] == "40-55")]
dfm_whandface_ocsvm_6075 = dfm_whandface_ocsvm[(dfm_whandface_ocsvm['variacao'] == "60-75")]
dfm_whandface_ocsvm_8095 = dfm_whandface_ocsvm[(dfm_whandface_ocsvm['variacao'] == "80-95")]
dfm_whandface_ocsvm_2095 = dfm_whandface_ocsvm[(dfm_whandface_ocsvm['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_ocsvm_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_ocsvm_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_ocsvm_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_ocsvm_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_ocsvm_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_whf_oc.svg')

# %%
dfm_whandface_ocsvm_2035.head(18)
# dfm_whandface_ocsvm_4055.head(18)
# dfm_whandface_ocsvm_6075.head(18)
# dfm_whandface_ocsvm_8095.head(18)
# dfm_whandface_ocsvm_2095.head(18)
# Out:
#      vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 360  26   8   0  36  0.485714       1.0       0.419355  0.590909     ocsvm
# 361  26  12   0  32  0.542857       1.0       0.448276  0.619048     ocsvm
# 362  26  16   0  28  0.600000       1.0       0.481481  0.650000     ocsvm
# 363  26  24   0  20  0.714286       1.0       0.565217  0.722222     ocsvm
# 364  26  26   0  18  0.742857       1.0       0.590909  0.742857     ocsvm
# 365  26  30   0  14  0.800000       1.0       0.650000  0.787879     ocsvm
# 366  26  32   0  12  0.828571       1.0       0.684211  0.812500     ocsvm
# 367  26  33   0  11  0.842857       1.0       0.702703  0.825397     ocsvm
# 368  26  34   0  10  0.857143       1.0       0.722222  0.838710     ocsvm
# 369  26  37   0   7  0.900000       1.0       0.787879  0.881356     ocsvm
# 370  26  36   0   8  0.885714       1.0       0.764706  0.866667     ocsvm
# ...

# %%
#whandface rce
dfm_whandface_rce_2035 = dfm_whandface_rce[(dfm_whandface_rce['variacao'] == "20-35")]
dfm_whandface_rce_4055 = dfm_whandface_rce[(dfm_whandface_rce['variacao'] == "40-55")]
dfm_whandface_rce_6075 = dfm_whandface_rce[(dfm_whandface_rce['variacao'] == "60-75")]
dfm_whandface_rce_8095 = dfm_whandface_rce[(dfm_whandface_rce['variacao'] == "80-95")]
dfm_whandface_rce_2095 = dfm_whandface_rce[(dfm_whandface_rce['variacao'] == "20-95")]

#ACURACIA
sns.set_theme(font_scale=1.3)
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_rce_2035, color='red')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_rce_4055, color='green')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_rce_6075, color='blue')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_rce_8095, color='magenta')
ax = sns.lineplot(x="semana", y="acuracia", data=dfm_whandface_rce_2095, color='brown')

ax.set_xlabel("Semanas")
ax.set_ylabel("Acurácia")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('ai_whf_rce.svg')

# %%
dfm_whandface_rce_2035.head(18)
dfm_whandface_rce_4055.head(18)
dfm_whandface_rce_6075.head(18)
dfm_whandface_rce_8095.head(18)
dfm_whandface_rce_2095.head(18)
# Out:
#       vp  vn  fp  fn  acuracia  precisao  sensibilidade   f1score algoritmo  \
# 2142  27  31   3   9  0.828571  0.900000       0.750000  0.818182       rce
# 2143  29  30   1  10  0.842857  0.966667       0.743590  0.840580       rce
# 2144  28  36   2   4  0.914286  0.933333       0.875000  0.903226       rce
# 2145  29  33   1   7  0.885714  0.966667       0.805556  0.878788       rce
# 2146  29  32   1   8  0.871429  0.966667       0.783784  0.865672       rce
# 2147  28  35   2   5  0.900000  0.933333       0.848485  0.888889       rce
# 2148  28  34   2   6  0.885714  0.933333       0.823529  0.875000       rce
# 2149  28  35   2   5  0.900000  0.933333       0.848485  0.888889       rce
# 2150  28  34   2   6  0.885714  0.933333       0.823529  0.875000       rce
# 2151  28  34   2   6  0.885714  0.933333       0.823529  0.875000       rce
# 2152  28  34   2   6  0.885714  0.933333       0.823529  0.875000       rce
# ...
